# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://bigblue_user:3MmY2&PE@49.12.227.17:27017/?authSource=admin')

# %%
collection = client ['learn']['business']

# %%
cursor = collection.distinct ('categories')
res = list(cursor)
res
# Out:
# [None,
#  '3D Printing, Graphic Design, Local Services, Printing Services, Professional Services',
#  '3D Printing, Printing Services, Local Services, Mass Media, Marketing, Print Media, Professional Services, Signmaking, Screen Printing',
#  'ATV Rentals/Tours, Kids Activities, Horseback Riding, Local Flavor, Venues & Event Spaces, Event Planning & Services, Active Life',
#  'Acai Bowls, Brazilian, Restaurants, Food, Barbeque, Sandwiches, Cafes, Bubble Tea',
#  'Acai Bowls, Brazilian, Vegan, Organic Stores, Juice Bars & Smoothies, Restaurants, Food',
#  'Acai Bowls, Breakfast & Brunch, Food, Juice Bars & Smoothies, Coffee & Tea, Restaurants, Vegan, Gluten-Free',
#  'Acai Bowls, Breakfast & Brunch, Food, Juice Bars & Smoothies, Restaurants',
#  'Acai Bowls, Coffee & Tea, Food, Breakfast & Brunch, Juice Bars & Smoothies, Food Trucks, Restaurants',
#  'Acai Bowls, Coffee & Tea, Gelato, Restaurants, Juice Bars & Smoothies, Live/Raw Food, Food',
# ...

# %%
res = collection.aggregate([{'$sample': {'size': 1 }}])

# %%
res

# %%
collection.find('food': "Ice Cream")
# Out:
#   Input In [136]
#     collection.find('food': "Ice Cream")
#                           ^
# SyntaxError: invalid syntax

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('60491ea71f81d22fdd165af0'),
#  'business_id': '6iYb2HFDywm3zjuRg0shjw',
#  'name': 'Oskar Blues Taproom',
#  'address': '921 Pearl St',
#  'city': 'Boulder',
#  'state': 'CO',
#  'postal_code': '80302',
#  'latitude': 40.0175444,
#  'longitude': -105.2833481,
#  'stars': 4.0,
#  'review_count': 86,
#  'is_open': 1,
#  'attributes': {'RestaurantsTableService': 'True',
#   'WiFi': "u'free'",
#   'BikeParking': 'True',
#   'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#   'BusinessAcceptsCreditCards': 'True',
#   'RestaurantsReservations': 'False',
#   'WheelchairAccessible': 'True',
#   'Caters': 'True',
#   'OutdoorSeating': 'True',
#   'RestaurantsGoodForGroups': 'True',
#   'HappyHour': 'True',
#   'BusinessAcceptsBitcoin': 'False',
#   'RestaurantsPriceRange2': '2',
# ...

# %%
cursor = collection.find({'categories': {'$regex':"(?i)P(?-i)izza"}, '$and':[{'hours.Sunday':"11:0-21:0"}]},{'_id':0, 'name':1,'hours':1})
res = list(cursor)
res
# Out:
# [{'name': "Gigi's Roast Beef & Pizza",
#   'hours': {'Monday': '11:0-21:0',
#    'Tuesday': '11:0-21:0',
#    'Wednesday': '11:0-21:0',
#    'Thursday': '11:0-21:0',
#    'Friday': '11:0-22:0',
#    'Saturday': '11:0-22:0',
#    'Sunday': '11:0-21:0'}},
#  {'name': 'Chuck E. Cheese',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '11:0-21:0',
#    'Wednesday': '11:0-21:0',
#    'Thursday': '11:0-21:0',
#    'Friday': '11:0-21:0',
#    'Saturday': '11:0-21:0',
#    'Sunday': '11:0-21:0'}},
#  {'name': 'Freshslice Pizza',
#   'hours': {'Monday': '11:0-21:0',
#    'Tuesday': '11:0-21:0',
#    'Wednesday': '11:0-21:0',
#    'Thursday': '11:0-22:0',
#    'Friday': '11:0-22:0',
#    'Saturday': '11:0-22:0',
#    'Sunday': '11:0-21:0'}},
#  {'name': 'Mellow Mushroom Atlanta - Buckhead',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '11:0-22:30',
#    'Wednesday': '11:0-22:30',
#    'Thursday': '11:0-21:0',
#    'Friday': '11:0-22:0',
#    'Saturday': '11:0-22:0',
# ...

# %%
cursor = collection.find({'categories': {'$regex':"(?i)P(?-i)izza"}, '$and':[{'hours.Sunday':"11:0-21:0"}]},{'_id':0, 'name':1,'hours':1})
res = list(cursor)
len(res)
# Out:
# 395

# %% [markdown]
# # How many of those serve Ice Cream?

# %%
cursor = collection.find({"categories":{"$regex":"Pizza.Ice Cream|Ice Cream.Pizza"},"$and":[{"hours.Sunday":"11:0-21:0"}]},{"_id": 0, "name":1})
result = list(cursor)
result
# Out:
# []

# %%
cursor = collection.find({"categories":{"$regex":"(?i)Pizza(?-i)Ice Cream"},"$and":[{"hours.Sunday":"11:0-21:0"}]},{"_id": 0, "name":1})
result = list(cursor)
result
# Out:
# []

# %% [markdown]
# # Are steakhouses higher rated than Italian restaurants?

# %%
cursor = collection.find({'categories':{'$regex':"Italian"}}, {"_id": 0, "name":1,'review_count': 1})

# %%
list(cursor)
# Out:
# [{'name': 'Legal Sea Foods', 'review_count': 856},
#  {'name': 'Magical Pizza Express', 'review_count': 8},
#  {'name': 'The Primavera Restaurant', 'review_count': 19},
#  {'name': "Bill's Pizzeria", 'review_count': 205},
#  {'name': 'Colossus Pizza', 'review_count': 58},
#  {'name': "Johnny Carino's", 'review_count': 136},
#  {'name': 'Pizza Pie-er', 'review_count': 72},
#  {'name': 'Regina Pizzeria', 'review_count': 10},
#  {'name': 'Family Kitchen', 'review_count': 14},
#  {'name': 'Olive Garden Italian Restaurant', 'review_count': 87},
#  {'name': 'Tuscan Kitchen', 'review_count': 462},
#  {'name': 'Bistro 20', 'review_count': 80},
#  {'name': 'Ristorante L', 'review_count': 80},
#  {'name': 'Firenza Pizza', 'review_count': 119},
#  {'name': 'Gallo Nero', 'review_count': 78},
#  {'name': 'Bambolina Restaurant', 'review_count': 360},
#  {'name': 'The Venetian Weymouth', 'review_count': 28},
#  {'name': 'Alberello Pizzeria', 'review_count': 62},
# ...
