# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://bigblue_user:3MmY2&PE@49.12.227.17:27017/?authSource=admin')

# %%
collection = client ['learn']['restaurants']

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('6049400e32c9cd22009c629c'),
#  'address': {'building': '469',
#   'coord': [-73.961704, 40.662942],
#   'street': 'Flatbush Avenue',
#   'zipcode': '11225'},
#  'borough': 'Brooklyn',
#  'cuisine': 'Hamburgers',
#  'grades': [{'date': datetime.datetime(2014, 12, 30, 0, 0),
#    'grade': 'A',
#    'score': 8},
#   {'date': datetime.datetime(2014, 7, 1, 0, 0), 'grade': 'B', 'score': 23},
#   {'date': datetime.datetime(2013, 4, 30, 0, 0), 'grade': 'A', 'score': 12},
#   {'date': datetime.datetime(2012, 5, 8, 0, 0), 'grade': 'A', 'score': 12}],
#  'name': "Wendy'S",
#  'restaurant_id': '30112340'}

# %%
cursor = collection.find({'name':"Wendy'S"})
res = list(cursor)
res [:2]
# Out:
# [{'_id': ObjectId('6049400e32c9cd22009c629c'),
#   'address': {'building': '469',
#    'coord': [-73.961704, 40.662942],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11225'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': datetime.datetime(2014, 12, 30, 0, 0),
#     'grade': 'A',
#     'score': 8},
#    {'date': datetime.datetime(2014, 7, 1, 0, 0), 'grade': 'B', 'score': 23},
#    {'date': datetime.datetime(2013, 4, 30, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2012, 5, 8, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': "Wendy'S",
#   'restaurant_id': '30112340'},
#  {'_id': ObjectId('6049400e32c9cd22009c6502'),
#   'address': {'building': '3636',
#    'coord': [-73.8421735, 40.8794229],
#    'street': 'Boston Road',
#    'zipcode': '10469'},
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': datetime.datetime(2014, 11, 17, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 6, 25, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2013, 6, 14, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 6, 6, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2012, 1, 27, 0, 0), 'grade': 'A', 'score': 7}],
#   'name': "Wendy'S",
#   'restaurant_id': '40386062'}]

# %%
cursor = collection.distinct ('borough')
res = list(cursor)
res
# Out:
# ['Bronx', 'Brooklyn', 'Manhattan', 'Missing', 'Queens', 'Staten Island']

# %%
cursor = collection.find({'name':"Wendy'S", 'borough':"Bronx"})
res = list(cursor)
res [:1]
# Out:
# [{'_id': ObjectId('6049400e32c9cd22009c6502'),
#   'address': {'building': '3636',
#    'coord': [-73.8421735, 40.8794229],
#    'street': 'Boston Road',
#    'zipcode': '10469'},
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': datetime.datetime(2014, 11, 17, 0, 0),
#     'grade': 'A',
#     'score': 9},
#    {'date': datetime.datetime(2014, 6, 25, 0, 0), 'grade': 'A', 'score': 3},
#    {'date': datetime.datetime(2013, 6, 14, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 6, 6, 0, 0), 'grade': 'A', 'score': 6},
#    {'date': datetime.datetime(2012, 1, 27, 0, 0), 'grade': 'A', 'score': 7}],
#   'name': "Wendy'S",
#   'restaurant_id': '40386062'}]

# %%
cursor = collection.find({'name':"Wendy'S"},{'borough':1, 'cuisine':1, '_id':0}) #include: 1, exclude:0
res = list(cursor)
res [:10]
# Out:
# [{'borough': 'Brooklyn', 'cuisine': 'Hamburgers'},
#  {'borough': 'Bronx', 'cuisine': 'Hamburgers'},
#  {'borough': 'Bronx', 'cuisine': 'Hamburgers'},
#  {'borough': 'Manhattan', 'cuisine': 'Hamburgers'},
#  {'borough': 'Queens', 'cuisine': 'Hamburgers'},
#  {'borough': 'Queens', 'cuisine': 'Hamburgers'},
#  {'borough': 'Queens', 'cuisine': 'Hamburgers'},
#  {'borough': 'Brooklyn', 'cuisine': 'Hamburgers'},
#  {'borough': 'Brooklyn', 'cuisine': 'Hamburgers'},
#  {'borough': 'Brooklyn', 'cuisine': 'Hamburgers'}]

# %%
cursor = collection.distinct ('cuisine')
res = list(cursor)
res
# Out:
# ['Afghan',
#  'African',
#  'American',
#  'Armenian',
#  'Asian',
#  'Australian',
#  'Bagels/Pretzels',
#  'Bakery',
#  'Bangladeshi',
#  'Barbecue',
#  'Bottled beverages, including water, sodas, juices, etc.',
#  'Brazilian',
#  'CafÃ©/Coffee/Tea',
#  'Café/Coffee/Tea',
#  'Cajun',
#  'Californian',
#  'Caribbean',
#  'Chicken',
#  'Chilean',
#  'Chinese',
#  'Chinese/Cuban',
#  'Chinese/Japanese',
#  'Continental',
#  'Creole',
#  'Creole/Cajun',
#  'Czech',
#  'Delicatessen',
#  'Donuts',
#  'Eastern European',
#  'Egyptian',
#  'English',
#  'Ethiopian',
#  'Filipino',
#  'French',
#  'Fruits/Vegetables',
#  'German',
#  'Greek',
#  'Hamburgers',
#  'Hawaiian',
#  'Hotdogs',
#  'Hotdogs/Pretzels',
#  'Ice Cream, Gelato, Yogurt, Ices',
#  'Indian',
#  'Indonesian',
#  'Iranian',
#  'Irish',
#  'Italian',
#  'Japanese',
#  'Jewish/Kosher',
#  'Juice, Smoothies, Fruit Salads',
#  'Korean',
#  'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'Mediterranean',
#  'Mexican',
#  'Middle Eastern',
#  'Moroccan',
#  'Not Listed/Not Applicable',
#  'Nuts/Confectionary',
#  'Other',
#  'Pakistani',
#  'Pancakes/Waffles',
#  'Peruvian',
#  'Pizza',
#  'Pizza/Italian',
#  'Polish',
#  'Polynesian',
#  'Portuguese',
#  'Russian',
#  'Salads',
#  'Sandwiches',
#  'Sandwiches/Salads/Mixed Buffet',
#  'Scandinavian',
#  'Seafood',
#  'Soul Food',
#  'Soups',
#  'Soups & Sandwiches',
#  'Southwestern',
#  'Spanish',
#  'Steak',
#  'Tapas',
#  'Tex-Mex',
#  'Thai',
#  'Turkish',
#  'Vegetarian',
#  'Vietnamese/Cambodian/Malaysia']

# %%
cursor = collection.find({'borough':"Brooklyn", 'cuisine':"American"},{'name':1, '_id':0}) #include: 1, exclude:0
res = list(cursor)
res
# Out:
# [{'name': 'Riviera Caterer'},
#  {'name': 'Regina Caterers'},
#  {'name': 'C & C Catering Service'},
#  {'name': 'The Movable Feast'},
#  {'name': 'Mejlander & Mulgannon'},
#  {'name': "Sonny'S Heros"},
#  {'name': "Junior'S"},
#  {'name': 'Towne Cafe'},
#  {'name': 'Melody Lanes'},
#  {'name': 'Shell Lanes'},
#  {'name': 'Palace Cafe'},
#  {'name': 'Reben Luncheonette'},
#  {'name': 'Fifth Avenue Bingo'},
#  {'name': 'Three Star Restaurant'},
#  {'name': 'Roll-N-Roaster'},
#  {'name': 'Brennan & Carr'},
#  {'name': 'Tamaqua'},
#  {'name': 'New Floridian Diner'},
#  {'name': 'Narrows Coffee Shop'},
#  {'name': "Denny'S Pub"},
#  {'name': 'New Parkway Restaurant'},
#  {'name': 'The Hytes Bar'},
#  {'name': 'The River Cafe'},
#  {'name': 'Greenpoint Tavern'},
#  {'name': 'Mariner Inn'},
#  {'name': 'Green House Cafe'},
#  {'name': 'Veterans Of Foreign Wars Post #107 Canteen'},
#  {'name': "Henry'S End"},
#  {'name': 'Bridgeview Diner'},
#  {'name': "Turkey'S Nest Tavern"},
#  {'name': 'Vegas Diner'},
#  {'name': 'Knights Of Baron Dekalb'},
#  {'name': 'Rex Manor'},
#  {'name': "Clark'S Restaurant"},
#  {'name': 'Dyker Beach Golf (Grill Room)'},
#  {'name': "My Father'S Place"},
#  {'name': "O'Sullivan'S Pub"},
#  {'name': 'Grand Canyon'},
#  {'name': 'Cappuccino Cafe'},
#  {'name': '200 Fifth Avenue Restaurant & Sports Bar'},
#  {'name': 'Academy Restauraunt'},
#  {'name': 'Park Plaza Restaurant'},
#  {'name': "Tina'S Restaurant"},
#  {'name': "Teddy'S Bar And Grill"},
#  {'name': 'Green Pavilion Restaurant & Sports Lounge'},
#  {'name': 'Brooklyn Botanic Catering Hall'},
#  {'name': "Queen Bee'S Tavern"},
#  {'name': "Chadwick'S"},
#  {'name': "Dennis' Place"},
#  {'name': 'Bay Ridge Manor Catering'},
#  {'name': 'Bergen Beach Cafe'},
#  {'name': 'Metrostar Cafe'},
#  {'name': "Cody'S Ale House Grill"},
#  {'name': 'J.J. Bubbles'},
#  {'name': 'Faros Restaurant'},
#  {'name': 'My Three Sons Restaurant'},
#  {'name': 'Mcdonald Avenue Diner'},
#  {'name': "Frank'S Place"},
#  {'name': 'Sugar Hill Restaurant, Supper Club And Disco'},
#  {'name': 'Europa Night Club'},
#  {'name': "Perry'S Restaurant"},
#  {'name': 'Hanson Restaurant And Pizzeria'},
#  {'name': 'Mugs Ale House Bar'},
#  {'name': 'Coffee Shop'},
#  {'name': "Mike'S Coffee Shop"},
#  {'name': 'Fifth Ave Cafe /Diner'},
#  {'name': "Circle'S Grill"},
#  {'name': 'Wheelers'},
#  {'name': "T.G.I. Friday'S"},
#  {'name': 'The Arch Diner'},
#  {'name': "Johnny Mack'S Bar"},
#  {'name': 'Quick Stop Restaurant'},
#  {'name': 'Shenanigans Pub'},
#  {'name': 'Heights Cafe'},
#  {'name': 'Jp Morgan Chase Bank Cafeteria'},
#  {'name': 'Henry St. Ale House'},
#  {'name': 'Wood Bine Caterers'},
#  {'name': 'Glen Terrace'},
#  {'name': 'Anopoli Family Restaurant'},
#  {'name': 'Atlantis Diner'},
#  {'name': 'The Bras & Pail Bar'},
#  {'name': 'Pit Stop Bar'},
#  {'name': "Nora'S Park Bench Cafe"},
#  {'name': "Pc'S Bar And Grill"},
#  {'name': "Jp'S Bar"},
#  {'name': 'Metropolitan Food Cafe Of Brooklyn College'},
#  {'name': 'Paradise Caterers'},
#  {'name': 'Alibi Club'},
#  {'name': 'Night Light Cafe'},
#  {'name': 'Am'},
#  {'name': 'La Bagel Delight'},
#  {'name': "Connie O'S"},
#  {'name': 'Crystal Manor'},
#  {'name': 'Georges Restaurant'},
#  {'name': 'The Gate'},
#  {'name': 'Imperial Biker Bar'},
#  {'name': "Anna'S Cafe"},
#  {'name': "Jake'S"},
#  {'name': "Cranberry'S"},
#  {'name': 'Kings County Cafeteria Bldg T'},
#  {'name': 'Pumps Exotic Bar'},
#  {'name': 'Salty Dog Restaurant'},
#  {'name': "Peter'S Waterfront Ale House"},
#  {'name': 'Bassett Caterers'},
#  {'name': 'Puritan Restaurant'},
#  {'name': 'Off Shore Restaurant'},
#  {'name': 'Sea Gate Beach Club'},
#  {'name': 'Taco Bell, Au Bon Pain'},
#  {'name': "Dizzy'S Restaurant"},
#  {'name': 'Garden Grill'},
#  {'name': 'Kent Theatre'},
#  {'name': 'Costco Wholesale'},
#  {'name': 'The Blue Zoo Lounge'},
#  {'name': 'The Grand Prospect Hall'},
#  {'name': "Defonte'S Sandwich Shop"},
#  {'name': 'Diner'},
#  {'name': 'Burger King'},
#  {'name': 'New Dyker Restaurant'},
#  {'name': 'Archives'},
#  {'name': 'Lite Bites & Grill'},
#  {'name': "Andrew'S Coffee Shop"},
#  {'name': "Manny'S Grill"},
#  {'name': 'Union Cafe Restaurant'},
#  {'name': 'Park Slope Ale House'},
#  {'name': 'Lindenwood Diner'},
#  {'name': 'Delias Lounge Cafe'},
#  {'name': 'The Grocery'},
#  {'name': 'Le Petit Cafe'},
#  {'name': "Phoebe'S"},
#  {'name': 'Sheepshead Bay Yacht Club Bar'},
#  {'name': 'Loki Bar & Benchmark Restaurant'},
#  {'name': "Bonnie'S Grill"},
#  {'name': 'Munchinette'},
#  {'name': "Evodio'S Place"},
#  {'name': 'Hanson Gourmet Deli & Cafe'},
#  {'name': 'Estelle'},
#  {'name': "John'S Donut & Coffee Shop"},
#  {'name': 'Rythym & Booze'},
#  {'name': 'John Hughes Knights Of Columbus Club'},
#  {'name': "Pete'S Candy Store"},
#  {'name': 'Hero Champ'},
#  {'name': 'Pizza Bagel Burger'},
#  {'name': "Iona'S Bar"},
#  {'name': 'Albany Manor'},
#  {'name': 'Best Deli Cafe'},
#  {'name': 'Angry Wades'},
#  {'name': 'The Brazen Head'},
#  {'name': 'Boston Market'},
#  {'name': "Kelly'S Tavern"},
#  {'name': 'Union Pool'},
#  {'name': 'Rose Water'},
#  {'name': 'Plymouth Cafe'},
#  {'name': 'Metropolitan'},
#  {'name': 'Ua Court Street #12'},
#  {'name': 'Homestretch Bar'},
#  {'name': "Manny'S Cafe Family Restaurant"},
#  {'name': 'Blue Ribbon Brasserie'},
#  {'name': 'Yb Food Market'},
#  {'name': 'Bull Shots'},
#  {'name': 'Concession # 110'},
#  {'name': 'Concession # 120/ The Bullpen'},
#  {'name': 'Stand # 326'},
#  {'name': 'Concession Stand  330'},
#  {'name': 'Stand # 210'},
#  {'name': 'Tip-Top Bar & Grill'},
#  {'name': 'Abir Halal Restaurant'},
#  {'name': "O'Keefes Bar & Grill"},
#  {'name': 'Lighthouse Cafe Restaurant'},
#  {'name': 'Sunset Park Diner & Donuts'},
#  {'name': 'Donut Stop'},
#  {'name': 'Surf & Turf Restaurant'},
#  {'name': 'Cafe Luluc'},
#  {'name': 'Cebu'},
#  {'name': 'Purity Diner'},
#  {'name': 'Spiros Restautrant'},
#  {'name': 'Almar'},
#  {'name': 'Sideshows By The Seashore'},
#  {'name': "Bijan'S"},
#  {'name': "Daddy'S"},
#  {'name': 'Don Pedro Restaurant'},
#  {'name': 'The Trash Bar'},
#  {'name': 'Soda Bar'},
#  {'name': "Applebee'S Neighborhood Grill & Bar"},
#  {'name': "Harry'O"},
#  {'name': 'Johnny Pumps'},
#  {'name': 'Barbes'},
#  {'name': 'Pencil Factory'},
#  {'name': 'The Usual Restaurant'},
#  {'name': 'Mirage Diner Restauraunt'},
#  {'name': 'Court Order'},
#  {'name': 'Fuel'},
#  {'name': "Peggy O'Neill'S"},
#  {'name': "Applebee'S Neighborhood Grill & Bar"},
#  {'name': 'Essence Bar & Restaurant'},
#  {'name': "Buckley'S Bar & Restauran"},
#  {'name': 'Bon Soir Caterers'},
#  {'name': 'Dram'},
#  {'name': 'The Royal Restaurant'},
#  {'name': "Lorri'S Bikini Lounge"},
#  {'name': 'Bembe'},
#  {'name': 'Fada'},
#  {'name': 'Visions Cocktail Lounge'},
#  {'name': 'Smith Tavern'},
#  {'name': "Redd'S"},
#  {'name': 'Superfine'},
#  {'name': 'New Country House'},
#  {'name': 'National Grid'},
#  {'name': "Joe'S Bar & Grill"},
#  {'name': "Tommy'S Tavern"},
#  {'name': 'Farragut Cafe'},
#  {'name': 'Spuyten Duyvul'},
#  {'name': "Clem'S"},
#  {'name': 'Buttermilk Bar'},
#  {'name': 'Boat Bar'},
#  {'name': 'Old Carriage Inn'},
#  {'name': 'Kings County Cafeteria'},
#  {'name': 'R Bar'},
#  {'name': 'Bar Matchless'},
#  {'name': 'Starlite Lounge'},
#  {'name': 'The Mark Bar'},
#  {'name': '68 Jay Street Bar'},
#  {'name': 'Long Island University - Luntey Commons'},
#  {'name': 'Sample'},
#  {'name': 'B.A.M. Cafe/Great Performances'},
#  {'name': 'Temptations'},
#  {'name': 'Stonehome Wine Bar'},
#  {'name': 'T & L Luncheonette'},
#  {'name': "Marco'S"},
#  {'name': 'Yankari Square Soul 2 Soul'},
#  {'name': 'Lucky 13 Saloon'},
#  {'name': 'Spike Hill'},
#  {'name': 'Marlow And Sons'},
#  {'name': 'The Brooklyn Tabernacle'},
#  {'name': 'Bar Sepia'},
#  {'name': 'Billiard Club'},
#  {'name': 'Pratt Institute North'},
#  {'name': 'East River'},
#  {'name': 'Brooklyn Social'},
#  {'name': 'Floyd, Ny'},
#  {'name': 'Stone Park Cafe'},
#  {'name': 'Zablozkis'},
#  {'name': "Luciano'S"},
#  {'name': 'Barbara Blum Residence / Good Shepherd Services'},
#  {'name': "Frankie'S Cocktail Lounge"},
#  {'name': 'Mini Bar'},
#  {'name': 'The Kettle Black'},
#  {'name': "Sunny'S"},
#  {'name': 'Bagelsmith'},
#  {'name': 'Bingo Bingo Bingo'},
#  {'name': 'Sunrise Of Mill Basin'},
#  {'name': 'Gerrittsen Beach Property Owners Association'},
#  {'name': 'Larry And Lawrence'},
#  {'name': 'Brooklyn Exposure'},
#  {'name': 'Sweetwater Grill'},
#  {'name': 'Commonwealth'},
#  {'name': 'Bean Post Pub'},
#  {'name': 'Barcade'},
#  {'name': 'Brooklyn Law School'},
#  {'name': 'Applewood'},
#  {'name': 'Park Cafe'},
#  {'name': 'Parade Grounds Snack Bar'},
#  {'name': 'Paphos Diner'},
#  {'name': 'Capri Social Club'},
#  {'name': 'Red Hook Bait And Tackle'},
#  {'name': "Eddie Jr'S Sport Lounge"},
#  {'name': 'Bed Stuy Diner'},
#  {'name': 'The Levee'},
#  {'name': 'Lodge'},
#  {'name': 'Roebling Tea Room'},
#  {'name': "Bill'S Bar"},
#  {'name': 'The Pour House Of Bayridge'},
#  {'name': 'Soft Spot'},
#  {'name': 'Skyline Billard'},
#  {'name': 'Cafe 101'},
#  {'name': 'Emphasis'},
#  {'name': 'Coco 66'},
#  {'name': "Pipin'S Pub"},
#  {'name': "Dunkin' Donuts/Baskin Robbins"},
#  {'name': 'Tazza'},
#  {'name': "Siggy'S Good Food"},
#  {'name': 'H.Q. Lounge'},
#  {'name': 'Bushwick Country Club'},
#  {'name': 'Gotham City Lounge'},
#  {'name': "Jimmy'S Place"},
#  {'name': 'Canal Bar'},
#  {'name': 'Museum Cafe'},
#  {'name': 'Fuel'},
#  {'name': 'New Heights Bar And Restaurant'},
#  {'name': "Sal'S Restaurant"},
#  {'name': '3 In 1 Kitchen'},
#  {'name': "Freddy'S Deli"},
#  {'name': 'Bushbaby'},
#  {'name': 'St. Francis Acquista Food Service'},
#  {'name': 'Northeast Kingdom'},
#  {'name': 'Burger King'},
#  {'name': 'Camp'},
#  {'name': "Feeney'S Pub"},
#  {'name': "Peyton'S All Nude Play Pen"},
#  {'name': 'Happiness Lounge'},
#  {'name': 'Naturally Delicious Caterers'},
#  {'name': 'Union Hall'},
#  {'name': 'Hanks Saloon'},
#  {'name': 'Roebling Sporting Club'},
#  {'name': 'Carroll Gardens Classic Diner'},
#  {'name': 'Boulevard Tavern'},
#  {'name': "Applebee'S Neighborhood Grill & Bar"},
#  {'name': 'Abilene'},
#  {'name': 'U & I Restaurant'},
#  {'name': 'The Cookie House'},
#  {'name': "Tony'S Pizza"},
#  {'name': 'Body By Brooklyn'},
#  {'name': 'Fort Hamilton Diner'},
#  {'name': 'Harefield Road Pub'},
#  {'name': '12Th Street Bar & Grill'},
#  {'name': 'Zombie Hut'},
#  {'name': 'Borough Restaurant'},
#  {'name': "Deno'S Sweet Shoppe"},
#  {'name': "Deno'S Snack Bar/Famiglia"},
#  {'name': "Pal'S Hero Shop"},
#  {'name': "Cheryl'S Global Soul"},
#  {'name': 'Old Fashion Coney Island Food'},
#  {'name': 'Flatbush Farms'},
#  {'name': "Mcdonald'S"},
#  {'name': 'The Cherry Tree Bar/ South Brooklyn Pizza'},
#  {'name': 'The Farm On Adderley'},
#  {'name': 'Alpine Cinemas'},
#  {'name': 'Lassen & Hennigs'},
#  {'name': 'Lola'},
#  {'name': 'Choice Market'},
#  {'name': 'Mac Cafe'},
#  {'name': 'Beach Cafe'},
#  {'name': 'Fourth Avenue Pub'},
#  {'name': 'Mullanes Bar & Grill'},
#  {'name': 'Sunset Diner'},
#  {'name': 'South 4Th Bar & Cafe'},
#  {'name': 'Heavenly Crumbs'},
#  {'name': 'Cobblestone Food'},
#  {'name': 'Subway'},
#  {'name': 'Charleston'},
#  {'name': "Mike'S Diner"},
#  {'name': 'Brooklyn Label'},
#  {'name': 'Sidecar'},
#  {'name': 'Azylum Bar & Lounge'},
#  {'name': "Roman'S"},
#  {'name': 'Nita Nita'},
#  {'name': 'Yellow Hook Grille'},
#  {'name': 'Brooklyn Fire Proof East'},
#  {'name': 'Velvet Lounge'},
#  {'name': '9Th Street Luncheonette'},
#  {'name': 'Wow Bridge Cafe'},
#  {'name': 'Pillow'},
#  {'name': 'Jr & Son'},
#  {'name': "Dunkin' Donuts"},
#  {'name': 'Best Western Gregory Hotel'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Ceol'},
#  {'name': 'Alchemy'},
#  {'name': 'Beach Bar'},
#  {'name': '940 Flushing Lounge/Arancini Bros'},
#  {'name': 'Cafe Colette'},
#  {'name': 'Vikki Restaurant'},
#  {'name': 'The Place Bar & Lounge'},
#  {'name': 'Crown Fried Chicken'},
#  {'name': 'Wing Wagon'},
#  {'name': 'Cobble Hill Cinemas'},
#  {'name': 'Ocean 8 At Brownstone Billiards'},
#  {'name': 'Willburg Cafe'},
#  {'name': 'The Brooklyn Inn'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Black Rabbit Bar'},
#  {'name': 'Red Karaoke Lounge'},
#  {'name': 'Circles Cafe'},
#  {'name': 'Bullseye Sports Pub'},
#  {'name': 'Dunkin Donuts/Baskin Robbins'},
#  {'name': "Dunkin' Donuts"},
#  {'name': 'The Diamond'},
#  {'name': 'Adventures Amusements Park'},
#  {'name': 'The Gutter Bar'},
#  {'name': "Mulholland'S"},
#  {'name': 'Legion'},
#  {'name': 'Macri Park'},
#  {'name': 'Korzo'},
#  {'name': 'Pacific Standard'},
#  {'name': 'Music Hall Of Williamsburg'},
#  {'name': 'Grant Ca'},
#  {'name': "Naidre'S"},
#  {'name': 'Picket Fence'},
#  {'name': "Mother'S"},
#  {'name': 'Huckleberry Bar'},
#  {'name': "Jimmy'S Diner"},
#  {'name': "Mike'S Cafeteria"},
#  {'name': 'Quarter'},
#  {'name': 'This & That'},
#  {'name': "Peter'S Since 1969"},
#  {'name': "Pablo'S Restaurant"},
#  {'name': 'Tbd Bar'},
#  {'name': 'Trophy'},
#  {'name': 'Ihop'},
#  {'name': "Foxy Gentlemen'S Club"},
#  {'name': 'Little Purity'},
#  {'name': 'The Rabbit Hole'},
#  {'name': 'Deity'},
#  {'name': 'Crossroads Cafe'},
#  {'name': 'Urban Rustic'},
#  {'name': "Kevin'S"},
#  {'name': 'Dram Shop'},
#  {'name': 'Hotel Delmano'},
#  {'name': 'Buttermilk Channel'},
#  {'name': 'The Second Chance Saloon'},
#  {'name': '95 South'},
#  {'name': "Rocky Sullivan'S Of Red Hook"},
#  {'name': 'The Habitat'},
#  {'name': 'Rustik 471'},
#  {'name': 'Weather Up'},
#  {'name': 'Oxcart Tavern'},
#  {'name': 'The Moxie Spot'},
#  {'name': 'Oasis Diner/Restaurant'},
#  {'name': 'Plan B'},
#  {'name': 'Adventures Amusement Park'},
#  {'name': 'The Jake Walk'},
#  {'name': 'Rmr Cafe (Bowling Alley)'},
#  {'name': 'Brooklyn Ice House'},
#  {'name': 'Blue Cafe/3 In 1 Deli Restaurant'},
#  {'name': 'Peaches'},
#  {'name': 'Franklin Park/Dutch Boy Burger'},
#  {'name': 'Cocoa Bar'},
#  {'name': 'Montauk Club'},
#  {'name': 'Sheepshead Bay Regal Cinemas Theatre'},
#  {'name': 'Lox'},
#  {'name': 'Bar Olivino'},
#  {'name': 'Ikea'},
#  {'name': 'The Good Fork'},
#  {'name': 'James Restaurant'},
#  {'name': 'The Spot'},
#  {'name': 'Black Bear Bar'},
#  {'name': 'Ted & Honey'},
#  {'name': 'Kouros Bay Diner'},
#  {'name': 'East Market Diner'},
#  {'name': 'Mirrors On Grand'},
#  {'name': 'The Chocolate Room'},
#  {'name': 'New Apollo Diner'},
#  {'name': 'Jayse Catering'},
#  {'name': 'Galapagos Art Space'},
#  {'name': 'Grill On Lee'},
#  {'name': 'The Bell House'},
#  {'name': 'Two 80 Cafe And Lounge'},
#  {'name': "Brooklyn Children'S Museum Cafe/Forest City Ratner Cafe"},
#  {'name': 'The Richardson'},
#  {'name': 'Walter Foods'},
#  {'name': 'Kennedy Fried Chicken'},
#  {'name': 'Five Leaves'},
#  {'name': 'Char No 4'},
#  {'name': 'Cookieroad'},
#  {'name': 'The Gibson'},
#  {'name': "Clover'S"},
#  {'name': 'Mr. Fulton'},
#  {'name': 'Vinegar Hill House'},
#  {'name': 'Building On Bond'},
#  {'name': "Pop'S"},
#  {'name': 'Boulevard Cafe'},
#  {'name': "Charles' Ale House"},
#  {'name': "Eddie'S Hero Place"},
#  {'name': "Duff'S Brooklyn"},
#  {'name': 'Choice Cooking Company'},
#  {'name': 'Skinflints Restaurant'},
#  {'name': "King'S Clam Bar"},
#  {'name': "Applebee'S Neighborhood Grill & Bar"},
#  {'name': "Daddy'S Cafe"},
#  {'name': 'Moon Palace Deli'},
#  {'name': "Sam'S Bagel"},
#  {'name': 'Pegusus Coffee Shop'},
#  {'name': '773 Lounge'},
#  {'name': 'Crown Fried Chicken'},
#  {'name': 'Prime Meats'},
#  {'name': 'New Shama Restaurant'},
#  {'name': "Dunkin' Donuts"},
#  {'name': 'Brooklyn Heights Wine Bar'},
#  {'name': 'Botanica/Cacao Prieto'},
#  {'name': 'Fulton Grill'},
#  {'name': 'The Village Luncheonette'},
#  {'name': "Cathy'S Place Diner"},
#  {'name': 'One Last Shag'},
#  {'name': 'Subway'},
#  {'name': 'Cafe Pedlar'},
#  {'name': 'Washington Commons'},
#  {'name': 'Brooklyn Tavern'},
#  {'name': 'Sycamore'},
#  {'name': 'Black Swan'},
#  {'name': 'The Grand Victory'},
#  {'name': 'Rye'},
#  {'name': 'Watty & Meg'},
#  {'name': 'Towers Cafe'},
#  {'name': 'Shayz Lounge'},
#  {'name': "Sharlene'S"},
#  {'name': 'High Dive'},
#  {'name': 'Homemade'},
#  {'name': '3Rd & 7'},
#  {'name': 'Towers Cafe'},
#  {'name': 'The Woods'},
#  {'name': 'Cake Ambiance'},
#  {'name': 'Tandem'},
#  {'name': 'Farrells'},
#  {'name': 'Double Windsor'},
#  {'name': "Nature'S Grill"},
#  {'name': 'Littlefield'},
#  {'name': 'Habana Outpost'},
#  {'name': "Two Tom'S Restaurant Ii"},
#  {'name': 'Black Horse Pub'},
#  {'name': 'Cafe Grumpy'},
#  {'name': "Samantha'S Southern Cuisine"},
#  {'name': "Paul'S Daughter"},
#  {'name': "Nathan'S Famous Carvel Ice Cream"},
#  {'name': 'Lot 2'},
#  {'name': "Tom'S Restaurant"},
#  {'name': 'Fort Defiance'},
#  {'name': 'Brooklyn Bowl'},
#  {'name': 'Kennedy Fried Chicken'},
#  {'name': 'Healthy Nibbles'},
#  {'name': "Uncle Louie G'S"},
#  {'name': 'The Wing Bar'},
#  {'name': 'Bakeri'},
#  {'name': 'Polytechnic University'},
#  {'name': 'Milk Bar'},
#  {'name': 'Gordon Bennett'},
#  {'name': "Mario'S Deli"},
#  {'name': 'Ontario Bar'},
#  {'name': 'Lucky Dog'},
#  {'name': 'Energy Fuel'},
#  {'name': 'Therapy Wine Bar'},
#  {'name': 'D.B.A'},
#  {'name': 'Berry Park'},
#  {'name': "Frank'S Tavern"},
#  {'name': 'Prb 24-7'},
#  {'name': 'Die Stanmkneipe'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Henry Public'},
#  {'name': 'Mile End'},
#  {'name': 'Project Parlor'},
#  {'name': 'The Sackett'},
#  {'name': "Pop'S Restaurant"},
#  {'name': 'Pies-N-Thighs'},
#  {'name': 'The Vanderbilt'},
#  {'name': 'Dish Food & Events'},
#  {'name': 'South'},
#  {'name': 'Nu Hotel'},
#  {'name': 'Privilege Lounge'},
#  {'name': 'Peaches Market Table'},
#  {'name': 'Half Court Sports Bar'},
#  {'name': 'Checkers'},
#  {'name': 'The Counting Room'},
#  {'name': 'Night Of Joy'},
#  {'name': 'Knitting Factory'},
#  {'name': 'Roebling Inn'},
#  {'name': '706 Bar'},
#  {'name': 'Forbell Cafe (U.S. Post Office Cafeteria)'},
#  {'name': 'Mills Tavern'},
#  {'name': 'Woodwork'},
#  {'name': 'Studio Ten'},
#  {'name': 'Chance 11'},
#  {'name': 'Indie Screen'},
#  {'name': 'Urban Vintage'},
#  {'name': 'Dumbo Kitchen'},
#  {'name': 'Canteen'},
#  {'name': "Yoo'S Evergreen Salad Bar And Sandwiches"},
#  {'name': "Uncle Jimmy'S Backyard Bbq"},
#  {'name': 'Mission Dolores'},
#  {'name': 'Pinkerton Wine Bar'},
#  {'name': 'The Hen House'},
#  {'name': 'The Castello Plan'},
#  {'name': 'The Bodega'},
#  {'name': 'Saint Anselm'},
#  {'name': 'Traif'},
#  {'name': 'Custom Winebar'},
#  {'name': "Bklyn'S Tiki Bar"},
#  {'name': 'Brooklyn Pub'},
#  {'name': 'Milk And Roses'},
#  {'name': "Nature'S Grill Ii"},
#  {'name': 'Green Kitchen Cafe'},
#  {'name': 'Lowlands Bar'},
#  {'name': 'Hot Bird'},
#  {'name': "Grill'S Delight & Juice Bar"},
#  {'name': 'Crown Fried Chicken'},
#  {'name': 'Thistlehill Tavern'},
#  {'name': 'Fulton Grand'},
#  {'name': 'Outback Steakhouse'},
#  {'name': 'Good Co'},
#  {'name': 'Manhattan Beach Concession Stand/Carvel'},
#  {'name': 'Marine Park Gulf Course'},
#  {'name': 'Mega Bites Diner'},
#  {'name': 'Take Away & Cafe'},
#  {'name': 'Black Mountain'},
#  {'name': "David'S Brisket House"},
#  {'name': "Applebee'S Neighborhood Grill & Bar"},
#  {'name': 'The Commodore'},
#  {'name': 'Hom'},
#  {'name': 'Branded Saloon'},
#  {'name': 'Georges Restaurant'},
#  {'name': 'Midway Bar'},
#  {'name': 'B-Hive Lounge'},
#  {'name': 'Soho Cafe & Grill'},
#  {'name': 'Kennedy Fried Chicken'},
#  {'name': 'Brooklyn Farmacy And Soda Fountain'},
#  {'name': 'The Narrows'},
#  {'name': 'Nightingale 9'},
#  {'name': 'Brooklyn Bridge Garden Bar'},
#  {'name': 'Strong Place'},
#  {'name': 'Coney Island Bar & Grill'},
#  {'name': 'The Bedford'},
#  {'name': 'Station Cafe'},
#  {'name': 'Kennedy Fried Chicken'},
#  {'name': 'No Name Bar'},
#  {'name': 'The Fifth Estate'},
#  {'name': "Thee Seven Sister'S"},
#  {'name': 'Express Coffee Shop'},
#  {'name': 'Paerdegat Athletic Club'},
#  {'name': 'Pine Box Rock Shop'},
#  {'name': 'The Rock Shop'},
#  {'name': 'Barnes & Noble Cafe'},
#  {'name': "Lp 'N Harmony"},
#  {'name': 'La Slowteria'},
#  {'name': 'Bay Ridge Diner'},
#  {'name': 'Juventino'},
#  {'name': 'Georges Luncheonette'},
#  {'name': 'No Quarter'},
#  {'name': 'Bedford Hill'},
#  {'name': 'Brooklyn Winery'},
#  {'name': 'Subway, Pizza & Burger Ur Way'},
#  {'name': 'Checkers'},
#  {'name': 'Bad Burger'},
#  {'name': 'The Whiskey Brooklyn'},
#  {'name': 'The West Cafe'},
#  {'name': 'Post Office'},
#  {'name': 'Crif Dogs'},
#  {'name': "Zeke'S"},
#  {'name': 'Manhattan 3 Decker Restaurant'},
#  {'name': 'Kennedy Fried Chicken'},
#  {'name': "Courtney'S Rotisserie & Grill"},
#  {'name': 'Brooklyn Academy Of Music-Harvey'},
#  {'name': 'Brooklyn Stoops'},
#  {'name': 'Brooklyn Mac'},
#  {'name': 'The Way Station'},
#  {'name': "Anita'S Luncheonette"},
#  {'name': 'Tuffet'},
#  {'name': 'Brooklyn Oenology'},
#  {'name': 'Spritzenhaus'},
#  {'name': 'The Halcyon Gourmet Llc'},
#  {'name': 'Hanson Dry'},
#  {'name': 'Cedillos & Friends'},
#  {'name': 'Terrace Coffee Shop'},
#  {'name': 'The Emerson'},
#  {'name': 'Calexico'},
#  {'name': 'Ihop'},
#  {'name': 'Soigne'},
#  {'name': 'Maggie Brown'},
#  {'name': "Big John'S Coffee Shop & Grill"},
#  {'name': "Mable'S Smokehouse And Banquet Hall"},
#  {'name': 'Lone Wolf'},
#  {'name': 'Harbor Fitness Juice Bar'},
#  {'name': "Christie'S Pub"},
#  {'name': 'Juniper'},
#  {'name': 'Coffee Friends'},
#  {'name': '61 Local'},
#  {'name': 'Alameda'},
#  {'name': 'The Brooklyn Star'},
#  {'name': 'Dean Street'},
#  {'name': "Freddy'S Bar"},
#  {'name': 'Jack The Horse Tavern'},
#  {'name': 'Goodbye Blue Monday'},
#  {'name': 'Lighthouse'},
#  {'name': 'Colonie'},
#  {'name': 'The Drink'},
#  {'name': "Shane'S Cafe"},
#  {'name': 'Banter'},
#  {'name': "Maybelle'S Cafe"},
#  {'name': 'Van Horn Sandwich Shop'},
#  {'name': 'Hot Chix'},
#  {'name': 'Bamboo Lounge & Grill'},
#  {'name': 'Kennedy Fried Chicken & Pizza'},
#  {'name': 'Becec, Inc/ Bambi Day Care Center'},
#  {'name': "Dick And Jane'S"},
#  {'name': "Eve'S Lounge"},
#  {'name': 'The Lutheran Halal Cafe'},
#  {'name': 'Halyards'},
#  {'name': 'Cafe Ghia'},
#  {'name': 'The Anchored Inn'},
#  {'name': 'Green City Lounge'},
#  {'name': 'Windsor Cafe'},
#  {'name': 'Breukelen Bier Merchants'},
#  {'name': 'The Meatball Shop'},
#  {'name': 'Dunkin Donuts'},
#  {'name': 'Napoli Pizza'},
#  {'name': 'Burger It Up'},
#  {'name': 'Smokeshack'},
#  {'name': 'Two8Two Bar & Burger'},
#  {'name': 'Der Kommissar'},
#  {'name': "D'Jimmy'S Coffee Shop"},
#  {'name': 'Olde Brooklyn Bagel Shoppe'},
#  {'name': 'Bearded Lady'},
#  {'name': 'Hope & Anchor'},
#  {'name': 'Vodou Bar'},
#  {'name': 'Parkside Coffee Shop'},
#  {'name': 'Linden Boulevard Multiplex Cinema'},
#  {'name': 'Shake Shack'},
#  {'name': 'The Burger Guru'},
#  {'name': "Frank'S Lounge & Bar"},
#  {'name': 'Nostrand Express'},
#  {'name': 'Brooklyn  Cafe'},
#  {'name': 'Lobster Joint'},
#  {'name': 'Liberty Events Lcc'},
#  {'name': 'Crown Victoria Bar'},
#  {'name': "Nature'S Grill"},
#  {'name': 'No Bar'},
#  {'name': 'Pizzalicious'},
#  {'name': 'Two Door Tavern'},
#  {'name': 'Do Or Dine'},
#  {'name': "Pearl'S Social & Billy Club"},
#  {'name': 'Crown Fried Chicken'},
#  {'name': 'Nitehawk Cinema'},
#  {'name': 'Srb Brooklyn'},
#  {'name': 'Draft Barn'},
#  {'name': 'Strike 10 Lanes (Sports Bar)'},
#  {'name': 'Blueprint'},
#  {'name': "Daniela'S Cafe"},
#  {'name': 'Lavender Lake'},
#  {'name': 'Fairfield Inn & Suites'},
#  {'name': 'The Pavilion'},
#  {'name': "Cain'S Tavern"},
#  {'name': "Max'S Burgers And Steaks"},
#  {'name': 'Wolf And Deer Brooklyn'},
#  {'name': 'High Horse Saloon'},
#  {'name': 'Williams & Bailey'},
#  {'name': "Sam'S Restaurant"},
#  {'name': 'Aloft New York Brooklyn/Brooklyn Terrace'},
#  {'name': "Mo'S Bar"},
#  {'name': 'Club Republic'},
#  {'name': 'Full Moon Saloon'},
#  {'name': 'Bareburger'},
#  {'name': 'Livingston Diner'},
#  {'name': 'Subway'},
#  {'name': "Muchmore'S"},
#  {'name': 'Crown Fried Chicken'},
#  {'name': 'Subway'},
#  {'name': 'The Social Butterfly'},
#  {'name': 'Little Caesars'},
#  {'name': 'Lunchbox Brooklyn'},
#  {'name': 'Moo Burger'},
#  {'name': "Noorman'S Kil"},
#  {'name': 'Pier 53 Coffee & Sandwich Shop'},
#  {'name': "Delroy'S"},
#  {'name': "Jimmy'S"},
#  {'name': 'Greene Grape Annex'},
#  {'name': 'Woodland'},
#  {'name': 'Subway'},
#  {'name': 'Neptune Diner Ii'},
#  {'name': 'Subway'},
#  {'name': 'Isa'},
#  {'name': 'Rocco Pizza Iii'},
#  {'name': 'The Saint Austere'},
#  {'name': "Dunkin' Donuts"},
#  {'name': "Mary'S Coffee Shop  & Restaurant"},
#  {'name': 'Dunkin Donuts'},
#  {'name': 'Bar 483'},
#  {'name': "Mary'S Bar"},
#  {'name': 'Burnside'},
#  {'name': 'Brooklyn Mac'},
#  {'name': 'C.M. Coffee Shop'},
#  {'name': 'Sea Witch'},
#  {'name': 'At The Crown Inn'},
#  {'name': 'In And Out Chicken'},
#  {'name': 'Brooklyn Tap House'},
#  {'name': 'Battersby'},
#  {'name': 'New York Fried Chicken'},
#  {'name': "New York Nick'S Deli"},
#  {'name': 'Allswell'},
#  {'name': 'The Flat'},
#  {'name': 'Punto Bianco'},
#  {'name': "Walter'S"},
#  {'name': 'Happy Days Diner'},
#  {'name': "Ovi'S Place"},
#  {'name': 'Sips & Bites'},
#  {'name': 'Clow & Clover'},
#  {'name': 'One Stop Beer Shop'},
#  {'name': 'Rich Lane'},
#  {'name': 'Bergen Hill'},
#  {'name': 'The Shanty'},
#  {'name': 'R & D Restaurant'},
#  {'name': 'Twenty 3 Supper Club'},
#  {'name': 'The General Greene'},
#  {'name': 'Halal Pizza & Fried Chicken'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Mcdonalds (#11542)'},
#  {'name': 'Greenpoint Heights'},
#  {'name': 'Bar Corvo'},
#  {'name': 'Over The Eight'},
#  {'name': 'The Kent Ale House'},
#  {'name': 'Basik'},
#  {'name': 'New Bay Coffee Shop Luncheonette'},
#  {'name': 'Miles'},
#  {'name': 'Sidelines Luncheonette'},
#  {'name': 'Boat House & Cajun Cuisine'},
#  {'name': 'Backyard'},
#  {'name': 'Cascades Catering Hall'},
#  {'name': 'Pure Bistro'},
#  {'name': 'Bagels & Wraps'},
#  {'name': 'Tba'},
#  {'name': 'Jalopy Tavern'},
#  {'name': 'Tradesman'},
#  {'name': "John'S Deli"},
#  {'name': 'The Brooklyn Strategist'},
#  {'name': 'Full Circle Bar'},
#  {'name': 'St Mazie'},
#  {'name': 'Skylark'},
#  {'name': 'Potlikker'},
#  {'name': 'Egg'},
#  {'name': 'Skylight Cafe (Medgar Evers College)'},
#  {'name': 'The Burger Bistro'},
#  {'name': 'Beauty Bar'},
#  {'name': "Murette'S"},
#  {'name': 'The Treats Truck Stop'},
#  {'name': 'Del Rio Diner'},
#  {'name': 'The Paper Box'},
#  {'name': 'Knife'},
#  {'name': 'Reynards'},
#  {'name': 'Superstar Family Fun Center Inc'},
#  {'name': 'Panera Bread'},
#  {'name': "Lucey'S Lounge"},
#  {'name': "Nathan'S"},
#  {'name': "Miller'S Tavern Restaurant"},
#  {'name': "Dizzy'S On 5Th"},
#  {'name': "Andy'S Cafeteria"},
#  {'name': 'Popeyes Louisiana Kitchen'},
#  {'name': 'Lulu & Po'},
#  {'name': '2Fl'},
#  {'name': 'My Arena'},
#  {'name': "Ruby'S"},
#  {'name': "Alice'S Arbor"},
#  {'name': 'Crosby Coffee'},
#  {'name': 'Mac Shack'},
#  {'name': 'On Montrose Ave Eatery'},
#  {'name': 'The Harp'},
#  {'name': 'Best Luncheonette'},
#  {'name': 'Popeyes'},
#  {'name': 'Hbh Sandwiches'},
#  {'name': 'Donna'},
#  {'name': 'Beloved'},
#  {'name': 'The Custom House'},
#  {'name': 'Lotus Cafe & Bagels'},
#  {'name': 'Elberta'},
#  {'name': 'Xixa'},
#  {'name': 'Alaska Bar'},
#  {'name': 'Columbus Delicatessen'},
#  {'name': 'Tryst Lounge'},
#  {'name': 'The Cobra Club'},
#  {'name': 'Events At Stone Park'},
#  {'name': 'Puerto Viejo Restaurant'},
#  {'name': "Barcey'S Coffee"},
#  {'name': 'Bedford Baking Studio'},
#  {'name': 'Brooklyn Crepe And Juice'},
#  {'name': 'Puff Cafe'},
#  {'name': "Adelina'S"},
#  {'name': 'Prospect'},
#  {'name': 'Bergen Bagels'},
#  {'name': 'Greenwood Park'},
#  {'name': 'Tasty Chicken'},
#  {'name': 'Take Root'},
#  {'name': 'Bath Beach Diner'},
#  {'name': 'The Owl Farm'},
#  {'name': 'Exley'},
#  {'name': 'Shapeshifter Lab'},
#  {'name': 'Blue Collar Hamburgers'},
#  {'name': 'Bed-Stuy Fish Fry'},
#  {'name': 'Best Coffee Shop'},
#  {'name': 'Prospect'},
#  {'name': 'Tooker Alley'},
#  {'name': "Auntie Anne'S"},
#  {'name': 'Heavy Woods'},
#  {'name': 'Hope Garage'},
#  {'name': 'Cafe 58'},
#  {'name': 'Hollow Nickel'},
#  {'name': 'Red Star'},
#  {'name': 'Archway Cafe (Unit 114)'},
#  {'name': 'Burger Urway'},
#  {'name': 'Brooklyn Burger'},
#  {'name': 'The Joint On Myrtle'},
#  {'name': 'Connecticut Muffin'},
#  {'name': 'Terroir Park Slope'},
#  {'name': 'Pork Slope'},
#  {'name': '983 Bushwick Living Room'},
#  {'name': 'Cameo'},
#  {'name': 'The Pines'},
#  {'name': 'Crop To Cup Coffee Company'},
#  {'name': 'Rosamunde Sausage Grill'},
#  {'name': 'Calvin Klein Courtside Kitchen'},
#  {'name': 'Press Dining & Beer Room'},
#  {'name': 'Honda/Legends Lounge'},
#  {'name': 'Robert Mondavi Winery'},
#  {'name': 'Juniors'},
#  {'name': "Abigael'S Brooklyn"},
#  {'name': 'Lower Suites Stoli Bar South Club Lounge'},
#  {'name': 'Brooklyn Burger'},
#  {'name': 'Upper South Suite Stoli Bar'},
#  {'name': 'North Suite Stoli Bar'},
#  {'name': 'Calexico'},
#  {'name': '40/40 Club Bar'},
#  {'name': "David'S Brisket House"},
#  {'name': 'City Tech Cafe'},
#  {'name': 'Dining Room'},
#  {'name': "Tutu'S"},
#  {'name': 'Action Burger'},
#  {'name': 'Union Grounds'},
#  {'name': 'Runner & Stone'},
#  {'name': 'Sweet Chick'},
#  {'name': "Tom'S Restaurant"},
#  {'name': 'The Well'},
#  {'name': 'Burger King'},
#  {'name': 'Burger King'},
#  {'name': 'Burger King / Popeyes'},
#  {'name': 'The Wicked Monk'},
#  {'name': 'Krescendo'},
#  {'name': 'Number Seven'},
#  {'name': 'Breuckelen Colony'},
#  {'name': 'Subway'},
#  {'name': 'Mayfield'},
#  {'name': 'The Owl Juice Pub'},
#  {'name': 'Juice Pedaler'},
#  {'name': 'Move With Grace'},
#  {'name': 'Parlor Coffee'},
#  {'name': 'Hamiltons'},
#  {'name': 'Cotta Bene To Go'},
#  {'name': 'Videology'},
#  {'name': "Hunter'S"},
#  {'name': 'Golden Sphinx Bar & Lounge'},
#  {'name': 'Sunshine Co.'},
#  {'name': 'Blue Magic Lounge'},
#  {'name': 'Auntie Annes Pretzels'},
#  {'name': 'Gather'},
#  {'name': 'Passenger Bar'},
#  {'name': 'Papa Johns International'},
#  {'name': 'Gallery Bar'},
#  {'name': 'Eagle Trading Co'},
#  {'name': 'Simplicity Wine Bar & Cafe'},
#  {'name': 'Cafe Zona Sur'},
#  {'name': 'Crown Fried Chicken'},
#  {'name': 'Bloom Cafe'},
#  {'name': 'Crown Fried Chicken'},
#  {'name': 'Popeyes/Dunkin Donuts'},
#  {'name': 'Taco Bell And Pizza Hut'},
#  {'name': 'Energy Fuel Cafe'},
#  {'name': 'The Montrose'},
#  {'name': 'Achilles Heel'},
#  {'name': 'F&M Cafe & Restaurant'},
#  {'name': 'Output Club'},
#  {'name': 'Lone Star Bar & Grill'},
#  {'name': 'The Panther Room'},
#  {'name': 'Marietta'},
#  {'name': 'La Guira Restaurant'},
#  {'name': 'Dinosaur Bar-B-Que'},
#  {'name': "Indigo Murphy'S"},
#  {'name': 'Doo Wop Griddle'},
#  {'name': 'Windy City Ale House'},
#  {'name': 'Lincoln Station'},
#  {'name': 'Olympia Wine Bar'},
#  {'name': 'Kebeer Grill Bar'},
#  {'name': 'Crown Fried Chicken'},
#  {'name': 'Visions Bar And Lounge'},
#  {'name': 'The Grand Bar And Grill'},
#  {'name': "Clemente'S Maryland Crab House"},
#  {'name': 'Cafe Rue Dix'},
#  {'name': 'Balli Deli & Salad Bar'},
#  {'name': 'Supercollider'},
#  {'name': 'Teaffee'},
#  {'name': 'Skinny Dennis'},
#  {'name': "Frank And Eddie'S Butcher Bar"},
#  {'name': 'No 7 Sub'},
#  {'name': "Fritzl'S Lunch Box"},
#  {'name': 'On Track Bar (O.T.B.)'},
#  {'name': 'Q Train Deli'},
#  {'name': 'Dunkin Donuts/Baskin Robbins/Popeyes'},
#  {'name': 'Bench Sport Bar'},
#  {'name': 'Divine Bar & Grill'},
#  {'name': 'Marcus Vineyard'},
#  {'name': 'Taperia'},
#  {'name': 'Biblio'},
#  {'name': 'River Styx'},
#  {'name': "Glady'S"},
#  {'name': 'Brooklyn Fare Kitchen'},
#  {'name': 'Dynaco'},
#  {'name': 'Bay Bagels'},
#  {'name': 'Mikes Hinsch'},
#  {'name': "Theresa'S Place"},
#  {'name': 'Broken Land'},
#  {'name': 'The Plank'},
#  {'name': 'Sweet Science'},
#  {'name': 'Lake Street Bar'},
#  {'name': 'Nostrand Avenue Pub'},
#  {'name': 'Brooklyn Brewhouse'},
#  {'name': 'Checkers'},
#  {'name': 'Stocked'},
#  {'name': "Mara'S Cafe & Bakery"},
#  {'name': 'St. Gambrinus Beer Shoppe'},
#  ...]

# %%
cursor = collection.find({'name': {'$regex':"(?i)w(?-i)en"}},{'_id':0, 'borough':1, 'name':1})
#'$regex':"(?i) --starts case insensitive search
# (?-i) end case insensitive search
res = list(cursor)
res[:10]
# Out:
# [{'borough': 'Brooklyn', 'name': "Wendy'S"},
#  {'borough': 'Bronx', 'name': "Wendy'S"},
#  {'borough': 'Bronx', 'name': "Wendy'S"},
#  {'borough': 'Manhattan', 'name': "Wendy'S"},
#  {'borough': 'Queens', 'name': "Wendy'S"},
#  {'borough': 'Queens', 'name': "Wendy'S"},
#  {'borough': 'Queens', 'name': "Wendy'S"},
#  {'borough': 'Brooklyn', 'name': "Wendy'S"},
#  {'borough': 'Brooklyn', 'name': "Wendy'S"},
#  {'borough': 'Brooklyn', 'name': "Wendy'S"}]

# %%
cursor = collection.find({'borough':"Brooklyn", '$or':[
                                                        {'cuisine':"American"},
                                                        {'cuisine':"Hamburgers"}
                                                      ]
                         },{'_id':0, 'name':1})

res = list(cursor)
res[:10]
# Out:
# [{'name': "Wendy'S"},
#  {'name': 'Riviera Caterer'},
#  {'name': 'Regina Caterers'},
#  {'name': 'C & C Catering Service'},
#  {'name': 'The Movable Feast'},
#  {'name': 'White Castle'},
#  {'name': 'Mejlander & Mulgannon'},
#  {'name': "Sonny'S Heros"},
#  {'name': "Junior'S"},
#  {'name': 'Towne Cafe'}]

# %%
cursor = collection.find({'$or':[
                                 {'cuisine':"American"},
                                 {'cuisine':"Hamburgers"},
                                 {'borough':"Brooklyn"},
                                 {'borough':"Bronx"}
                                ]
                         },{'_id':0, 'name':1})
res = list(cursor)
res[:10]
# Out:
# [{'name': "Wendy'S"},
#  {'name': 'Morris Park Bake Shop'},
#  {'name': 'Riviera Caterer'},
#  {'name': 'Brunos On The Boulevard'},
#  {'name': 'Regina Caterers'},
#  {'name': "Wilken'S Fine Food"},
#  {'name': 'Taste The Tropics Ice Cream'},
#  {'name': 'Wild Asia'},
#  {'name': 'C & C Catering Service'},
#  {'name': 'May May Kitchen'}]

# %%
cursor = collection.find({'$or':[
                                 {'cuisine':"American"},
                                 {'cuisine':"Hamburgers"},
                                 {'borough':"Brooklyn"},
                                 {'borough':"Bronx"}
                                ],
                          
                          '$and':[
                                 {'address.coord': {'$gte': -73}},
                                 {'address.coord': {'$lt': 40}}
                                ]
                         },{'_id':0, 'name':1, 'cuisine':1, 'address.street':1})
res = list(cursor)
res
# Out:
# [{'address': {'street': 'Flatbush Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'address': {'street': 'Morris Park Ave'},
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop'},
#  {'address': {'street': 'Stillwell Avenue'},
#   'cuisine': 'American',
#   'name': 'Riviera Caterer'},
#  {'address': {'street': 'Astoria Boulevard'},
#   'cuisine': 'American',
#   'name': 'Brunos On The Boulevard'},
#  {'address': {'street': '11 Avenue'},
#   'cuisine': 'American',
#   'name': 'Regina Caterers'},
#  {'address': {'street': 'Avenue U'},
#   'cuisine': 'Delicatessen',
#   'name': "Wilken'S Fine Food"},
#  {'address': {'street': 'Nostrand Avenue'},
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Taste The Tropics Ice Cream'},
#  {'address': {'street': 'Southern Boulevard'},
#   'cuisine': 'American',
#   'name': 'Wild Asia'},
#  {'address': {'street': '18 Avenue'},
#   'cuisine': 'American',
#   'name': 'C & C Catering Service'},
#  {'address': {'street': 'Sutter Avenue'},
#   'cuisine': 'Chinese',
#   'name': 'May May Kitchen'},
#  {'address': {'street': 'East   66 Street'},
#   'cuisine': 'American',
#   'name': '1 East 66Th Street Kitchen'},
#  {'address': {'street': 'Church Avenue'},
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'address': {'street': 'Kings Highway'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Seuda Foods'},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'Delicatessen',
#   'name': 'Nordic Delicacies'},
#  {'address': {'street': 'East   74 Street'},
#   'cuisine': 'American',
#   'name': 'Glorious Food'},
#  {'address': {'street': 'Prospect Park West'},
#   'cuisine': 'American',
#   'name': 'The Movable Feast'},
#  {'address': {'street': 'West Houston Street'},
#   'cuisine': 'American',
#   'name': 'Angelika Film Center'},
#  {'address': {'street': 'Columbus Avenue'},
#   'cuisine': 'American',
#   'name': 'P & S Deli Grocery'},
#  {'address': {'street': 'Myrtle Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'East   56 Street'},
#   'cuisine': 'Caribbean',
#   'name': "Shashemene Int'L Restaura"},
#  {'address': {'street': 'Church Street'},
#   'cuisine': 'American',
#   'name': 'Downtown Deli'},
#  {'address': {'street': 'Court Street'},
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'address': {'street': 'East 233 Street'},
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'American',
#   'name': 'Mejlander & Mulgannon'},
#  {'address': {'street': '238 Spofford Ave'},
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden'},
#  {'address': {'street': '8 Avenue'},
#   'cuisine': 'American',
#   'name': 'Cafe Metro'},
#  {'address': {'street': 'Lefferts Boulevard'},
#   'cuisine': 'American',
#   'name': 'Snack Time Grill'},
#  {'address': {'street': 'Madison Avenue'},
#   'cuisine': 'American',
#   'name': 'Berkely'},
#  {'address': {'street': 'East   92 Street'},
#   'cuisine': 'American',
#   'name': "Sonny'S Heros"},
#  {'address': {'street': 'Rutland Road'},
#   'cuisine': 'Chinese',
#   'name': 'Golden Pavillion'},
#  {'address': {'street': 'West  110 Street'},
#   'cuisine': 'American',
#   'name': 'Spoon Bread Catering'},
#  {'address': {'street': 'Avenue J'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Bagel Hole'},
#  {'address': {'street': 'Guardia Airport Parking'},
#   'cuisine': 'American',
#   'name': 'Terminal Cafe/Yankee Clipper'},
#  {'address': {'street': 'East Kingsbridge Road'},
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden'},
#  {'address': {'street': '4 Avenue'},
#   'cuisine': 'Italian',
#   'name': 'Philadelhia Grille Express'},
#  {'address': {'street': 'East   60 Street'},
#   'cuisine': 'American',
#   'name': 'Metropolitan Club'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Steak',
#   'name': 'Peter Luger Steakhouse'},
#  {'address': {'street': 'West   52 Street'},
#   'cuisine': 'American',
#   'name': '21 Club'},
#  {'address': {'street': '2 Avenue'},
#   'cuisine': 'American',
#   'name': 'Palm Restaurant'},
#  {'address': {'street': 'Clarence Ave'},
#   'cuisine': 'American',
#   'name': 'Manhem Club'},
#  {'address': {'street': 'East   18 Street'},
#   'cuisine': 'American',
#   'name': 'Old Town Bar & Restaurant'},
#  {'address': {'street': 'Driggs Avenue'},
#   'cuisine': 'Polish',
#   'name': 'Polish National Home'},
#  {'address': {'street': 'Centre Street'},
#   'cuisine': 'American',
#   'name': 'Criminal Court Bldg Cafeteria'},
#  {'address': {'street': 'Central Park South'},
#   'cuisine': 'American',
#   'name': 'Nyac Main Dining Room'},
#  {'address': {'street': 'Avenue B'}, 'cuisine': 'American', 'name': '7B Bar'},
#  {'address': {'street': 'West 57 Street'},
#   'cuisine': 'American',
#   'name': 'Cafe Atelier (Art Students League)'},
#  {'address': {'street': 'Flatbush Avenue Extension'},
#   'cuisine': 'American',
#   'name': "Junior'S"},
#  {'address': {'street': 'Mansion Ave'},
#   'cuisine': 'American',
#   'name': 'Great Kills Yacht Club'},
#  {'address': {'street': 'East   15 Street'},
#   'cuisine': 'American',
#   'name': 'Towne Cafe'},
#  {'address': {'street': '9 Avenue'},
#   'cuisine': 'American',
#   'name': 'Old Homestead'},
#  {'address': {'street': 'West Drive'},
#   'cuisine': 'American',
#   'name': 'Douglaston Club'},
#  {'address': {'street': 'East   60 Street'},
#   'cuisine': 'American',
#   'name': 'Serendipity 3'},
#  {'address': {'street': '37 Street'},
#   'cuisine': 'American',
#   'name': 'Melody Lanes'},
#  {'address': {'street': 'Haviland Avenue'},
#   'cuisine': 'American',
#   'name': 'The New Starling Athletic Club Of The Bronx'},
#  {'address': {'street': 'Hudson Street'},
#   'cuisine': 'American',
#   'name': 'White Horse Tavern'},
#  {'address': {'street': 'Hylan Boulevard'},
#   'cuisine': 'American',
#   'name': "Labetti'S Post # 2159"},
#  {'address': {'street': 'Bouck Court'},
#   'cuisine': 'American',
#   'name': 'Shell Lanes'},
#  {'address': {'street': 'West    4 Street'},
#   'cuisine': 'American',
#   'name': 'Corner Bistro'},
#  {'address': {'street': 'Nostrand Avenue'},
#   'cuisine': 'Donuts',
#   'name': 'Nostrand Donut Shop'},
#  {'address': {'street': 'Hylan Boulevard'},
#   'cuisine': 'American',
#   'name': 'South Shore Swimming Club'},
#  {'address': {'street': '2 Avenue'},
#   'cuisine': 'American',
#   'name': 'Keats Restaurant'},
#  {'address': {'street': '8 Avenue'},
#   'cuisine': 'Italian',
#   'name': 'New Corner'},
#  {'address': {'street': 'West   43 Street'},
#   'cuisine': 'American',
#   'name': 'The Princeton Club'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': "Reynold'S Bar"},
#  {'address': {'street': 'Nassau Avenue'},
#   'cuisine': 'American',
#   'name': 'Palace Cafe'},
#  {'address': {'street': 'East  161 Street'},
#   'cuisine': 'American',
#   'name': 'Yankee Tavern'},
#  {'address': {'street': 'Havemeyer Street'},
#   'cuisine': 'American',
#   'name': 'Reben Luncheonette'},
#  {'address': {'street': '37 Avenue'},
#   'cuisine': 'American',
#   'name': "Jahn'S Restaurant"},
#  {'address': {'street': '18 Avenue'},
#   'cuisine': 'Pizza',
#   'name': 'J&V Famous Pizza'},
#  {'address': {'street': 'Seventh Avenue'},
#   'cuisine': 'American',
#   'name': 'La Parisienne Diner'},
#  {'address': {'street': 'West 46 Street'},
#   'cuisine': 'American',
#   'name': 'Joe Allen Restaurant'},
#  {'address': {'street': 'Richmond Avenue'},
#   'cuisine': 'American',
#   'name': "Joyce'S Tavern"},
#  {'address': {'street': 'West   15 Street'},
#   'cuisine': 'Italian',
#   'name': "Gargiulo'S Restaurant"},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': "Lavelle'S Admiral'S Club"},
#  {'address': {'street': 'East 57 Street'},
#   'cuisine': 'American',
#   'name': "Neary'S Pub"},
#  {'address': {'street': 'East  204 Street'},
#   'cuisine': 'Irish',
#   'name': 'Mcdwyers Pub'},
#  {'address': {'street': 'Jamaica Avenue'},
#   'cuisine': 'American',
#   'name': "Nancy'S Fire Side"},
#  {'address': {'street': 'Lispenard Street'},
#   'cuisine': 'American',
#   'name': 'Nancy Whiskey Pub'},
#  {'address': {'street': 'Jamaica Avenue'},
#   'cuisine': 'American',
#   'name': 'Blarney Bar'},
#  {'address': {'street': 'Rockaway Beach Boulevard'},
#   'cuisine': 'American',
#   'name': "Healy'S Pub"},
#  {'address': {'street': 'Avenue R'},
#   'cuisine': 'Italian',
#   'name': "Michael'S Restaurant"},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'American',
#   'name': 'Fifth Avenue Bingo'},
#  {'address': {'street': 'Atlantic Avenue'},
#   'cuisine': 'American',
#   'name': "Lenihan'S Saloon"},
#  {'address': {'street': 'Rockaway Point Boulevard'},
#   'cuisine': 'American',
#   'name': 'Blarney Castle'},
#  {'address': {'street': 'Avenue U'},
#   'cuisine': 'American',
#   'name': 'Three Star Restaurant'},
#  {'address': {'street': '1 Avenue'},
#   'cuisine': 'American',
#   'name': "Dangerfield'S Night Club"},
#  {'address': {'street': 'Park Avenue South'},
#   'cuisine': 'American',
#   'name': "Desmond'S Tavern"},
#  {'address': {'street': 'Emmons Avenue'},
#   'cuisine': 'American',
#   'name': 'Roll-N-Roaster'},
#  {'address': {'street': 'Nostrand Avenue'},
#   'cuisine': 'American',
#   'name': 'Brennan & Carr'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'The Punch Bowl'},
#  {'address': {'street': 'West    4 Street'},
#   'cuisine': 'American',
#   'name': 'The Riviera Cafe'},
#  {'address': {'street': 'Henry Street'},
#   'cuisine': 'Pizza/Italian',
#   'name': "Fascati'S Pizzeria"},
#  {'address': {'street': 'Ebony Court'},
#   'cuisine': 'American',
#   'name': 'Tamaqua'},
#  {'address': {'street': 'Forest Avenue'},
#   'cuisine': 'American',
#   'name': "Li Greci'S Staaten Restaurant"},
#  {'address': {'street': 'East  170 Street'},
#   'cuisine': 'American',
#   'name': 'Munchtime'},
#  {'address': {'street': 'Sutphin Boulevard'},
#   'cuisine': 'American',
#   'name': "Maloney'S Bar"},
#  {'address': {'street': 'Boston Road'},
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'address': {'street': 'Flagg Place'},
#   'cuisine': 'American',
#   'name': 'Richmond County Country Club'},
#  {'address': {'street': 'Jamaica Avenue'},
#   'cuisine': 'American',
#   'name': 'Little Brown Jug'},
#  {'address': {'street': 'Castle Hill Avenue'},
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop"},
#  {'address': {'street': 'Vanderbilt Avenue'},
#   'cuisine': 'Soul Food',
#   'name': "Mitchell'S Restaurant"},
#  {'address': {'street': 'First Avenue'},
#   'cuisine': 'American',
#   'name': "Finnegan'S Wake"},
#  {'address': {'street': '18 Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': 'Da Vinci Pizza'},
#  {'address': {'street': 'Schurz Ave'},
#   'cuisine': 'American',
#   'name': 'Marina Delray'},
#  {'address': {'street': 'Flatbush Avenue'},
#   'cuisine': 'American',
#   'name': 'New Floridian Diner'},
#  {'address': {'street': 'West Broadway'},
#   'cuisine': 'American',
#   'name': 'Broome Street Bar'},
#  {'address': {'street': '60Th St. - Store'},
#   'cuisine': 'American',
#   'name': 'Charlies Sports Bar'},
#  {'address': {'street': '4 Avenue'},
#   'cuisine': 'American',
#   'name': 'Narrows Coffee Shop'},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'American',
#   'name': 'Jg Melon Restaurant'},
#  {'address': {'street': 'Spring Street'},
#   'cuisine': 'American',
#   'name': 'Emerald Pub'},
#  {'address': {'street': 'Central Park South'},
#   'cuisine': 'American',
#   'name': 'Tap Room'},
#  {'address': {'street': 'Central Park South'},
#   'cuisine': 'American',
#   'name': 'Cocktail Room (Nyac)'},
#  {'address': {'street': 'East   64 Street'},
#   'cuisine': 'American',
#   'name': 'Jackson Hole'},
#  {'address': {'street': '9 Avenue'},
#   'cuisine': 'American',
#   'name': 'Flame Restaurant Coffee House'},
#  {'address': {'street': 'St Marks Place'},
#   'cuisine': 'American',
#   'name': 'Grassroot Tavern'},
#  {'address': {'street': 'Harrison Avenue'},
#   'cuisine': 'American',
#   'name': "Buddy'S Wonder Bar"},
#  {'address': {'street': 'Cooper Avenue'},
#   'cuisine': 'American',
#   'name': 'The Assembly Bar'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Capitol Restaurant'},
#  {'address': {'street': 'East   68 Street'},
#   'cuisine': 'American',
#   'name': 'Griffis Faculty Club'},
#  {'address': {'street': 'Flatbush Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Emmons Avenue'},
#   'cuisine': 'Greek',
#   'name': 'El Greco Diner'},
#  {'address': {'street': '101 Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': '86 Street'},
#   'cuisine': 'Pizza/Italian',
#   'name': 'Lb Spumoni Gardens'},
#  {'address': {'street': 'Katonah Ave'},
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest"},
#  {'address': {'street': 'Southern Boulevard'},
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe'},
#  {'address': {'street': 'Southern Boulevard'},
#   'cuisine': 'African',
#   'name': 'African Terrace'},
#  {'address': {'street': 'Southern Boulevard'},
#   'cuisine': 'American',
#   'name': 'Beaver Pond'},
#  {'address': {'street': 'Southern Boulevard'},
#   'cuisine': 'American',
#   'name': 'African Market (Baboon Cafe)'},
#  {'address': {'street': 'Southern Boulevard'},
#   'cuisine': 'American',
#   'name': 'Cool Zone'},
#  {'address': {'street': 'East 43 Street'},
#   'cuisine': 'American',
#   'name': 'Ford Foundation Cafeteria'},
#  {'address': {'street': 'Greenwich Avenue'},
#   'cuisine': 'American',
#   'name': 'Elephant & Castle'},
#  {'address': {'street': 'Avenue T'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Mill Basin Kosher Deli'},
#  {'address': {'street': 'East    6 Street'},
#   'cuisine': 'American',
#   'name': 'Cherry Tavern'},
#  {'address': {'street': 'Hylan Boulevard'},
#   'cuisine': 'American',
#   'name': 'Colonnade Diner'},
#  {'address': {'street': 'East   47 Street'},
#   'cuisine': 'American',
#   'name': 'Maggies Place'},
#  {'address': {'street': 'West   44 Street'},
#   'cuisine': 'American',
#   'name': 'Red Flame Diner'},
#  {'address': {'street': '2 Avenue'},
#   'cuisine': 'American',
#   'name': "Brady'S Bar"},
#  {'address': {'street': '2 Avenue'},
#   'cuisine': 'American',
#   'name': 'Benjamin'},
#  {'address': {'street': 'West   44 Street'},
#   'cuisine': 'American',
#   'name': "Jimmy'S Corner"},
#  {'address': {'street': 'Frost Street'},
#   'cuisine': 'Italian',
#   'name': 'Frost Restaurant'},
#  {'address': {'street': 'Beverly Road'},
#   'cuisine': 'American',
#   'name': "Denny'S Pub"},
#  {'address': {'street': 'Grove Street'},
#   'cuisine': 'American',
#   'name': 'Maries Crisis Cafe'},
#  {'address': {'street': 'Christopher Street'},
#   'cuisine': 'American',
#   'name': 'Boots & Saddle Bar'},
#  {'address': {'street': '13 Avenue'},
#   'cuisine': 'American',
#   'name': 'New Parkway Restaurant'},
#  {'address': {'street': 'Union Turnpike'},
#   'cuisine': 'American',
#   'name': "P.J.' S"},
#  {'address': {'street': 'East   54 Street'},
#   'cuisine': 'American',
#   'name': 'The Brook'},
#  {'address': {'street': '2 Avenue'},
#   'cuisine': 'American',
#   'name': 'Palm Too'},
#  {'address': {'street': 'Johnson Avenue'},
#   'cuisine': 'American',
#   'name': 'Blue Bay Restaurant'},
#  {'address': {'street': 'St Johns Place'},
#   'cuisine': 'American',
#   'name': 'The Hytes Bar'},
#  {'address': {'street': 'Forest Avenue'},
#   'cuisine': 'American',
#   'name': "Jody'S Club"},
#  {'address': {'street': 'East 92 Street'},
#   'cuisine': 'American',
#   'name': "Reif'S Tavern"},
#  {'address': {'street': 'Whitestone Expressway'},
#   'cuisine': 'American',
#   'name': 'Whitestone Lanes'},
#  {'address': {'street': 'City Island Ave'},
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant'},
#  {'address': {'street': 'Bridge Street'},
#   'cuisine': 'American',
#   'name': 'White Horse Tavern'},
#  {'address': {'street': 'Pennsylvania Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Armando'S Pizza"},
#  {'address': {'street': 'Flatbush Avenue Extension'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Graham Avenue'},
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Cafe Capri'},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'American',
#   'name': 'Bronx Grill'},
#  {'address': {'street': 'University Place'},
#   'cuisine': 'American',
#   'name': 'Knickerbocker Bar & Grill'},
#  {'address': {'street': 'Water Street'},
#   'cuisine': 'American',
#   'name': 'The River Cafe'},
#  {'address': {'street': 'Chambers Street'},
#   'cuisine': 'American',
#   'name': 'Mudville Saloon'},
#  {'address': {'street': 'City Island Ave'},
#   'cuisine': 'Seafood',
#   'name': "Johnny'S Reef Restaurant"},
#  {'address': {'street': 'Empire Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'Boston Post Road'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'Queens Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'Ft Hamilton Parkway'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'Union Street'},
#   'cuisine': 'Italian',
#   'name': "Ferdinando'S Restaurant"},
#  {'address': {'street': '71 Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Madison Avenue'},
#   'cuisine': 'American',
#   'name': 'Viand Cafe'},
#  {'address': {'street': 'West Broadway'},
#   'cuisine': 'American',
#   'name': 'The Cupping Room'},
#  {'address': {'street': 'Madison Avenue'},
#   'cuisine': 'American',
#   'name': 'Nectar Coffee Shop'},
#  {'address': {'street': 'Utica Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'East   18 Street'},
#   'cuisine': 'American',
#   'name': "Pete'S Tavern"},
#  {'address': {'street': 'West  231 Street'},
#   'cuisine': 'American',
#   'name': "P & K'S Grill"},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Reme Restaurant'},
#  {'address': {'street': 'Madison Avenue'},
#   'cuisine': 'American',
#   'name': 'The New Amity Restaurant'},
#  {'address': {'street': 'Parsons Boulevard'},
#   'cuisine': 'American',
#   'name': 'The Dart Inn'},
#  {'address': {'street': 'Withers Street'},
#   'cuisine': 'Italian',
#   'name': "Bamonte'S Restaurant"},
#  {'address': {'street': '10 Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Katonah Avenue'},
#   'cuisine': 'American',
#   'name': "John Mulligan'S Fireside Pub"},
#  {'address': {'street': 'Northern Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'address': {'street': 'Spring Street'},
#   'cuisine': 'American',
#   'name': 'Ear Inn'},
#  {'address': {'street': 'Northern Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'address': {'street': 'Northern Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'address': {'street': 'Bedford Avenue'},
#   'cuisine': 'American',
#   'name': 'Greenpoint Tavern'},
#  {'address': {'street': 'Richmond Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Knickerbocker Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizzeria"},
#  {'address': {'street': '30 Avenue'},
#   'cuisine': 'American',
#   'name': "Pat'S Stationary"},
#  {'address': {'street': 'Madison Avenue'},
#   'cuisine': 'American',
#   'name': "Three Guy'S Restaurant"},
#  {'address': {'street': 'Gramercy Park South'},
#   'cuisine': 'American',
#   'name': 'The Players Club'},
#  {'address': {'street': 'Francis Lewis Boulevard'},
#   'cuisine': 'American',
#   'name': 'Divers Cove'},
#  {'address': {'street': 'Horace Harding Boulevard'},
#   'cuisine': 'American',
#   'name': 'Tjk Cafe & Restaurant'},
#  {'address': {'street': 'East   49 Street'},
#   'cuisine': 'American',
#   'name': 'Smith & Wollensky'},
#  {'address': {'street': 'Willets Point Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Mac Dougal Street'},
#   'cuisine': 'American',
#   'name': 'Olive Tree Cafe & Comedy Cellar'},
#  {'address': {'street': 'Hillside Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'address': {'street': 'Forest Avenue'},
#   'cuisine': 'American',
#   'name': 'Perkins Family Restaurant & Bakery'},
#  {'address': {'street': 'Metropolitan Ave'},
#   'cuisine': 'American',
#   'name': 'Sizzler'},
#  {'address': {'street': 'Church Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'address': {'street': 'Foster Avenue'},
#   'cuisine': 'Italian',
#   'name': 'Mama Lucia'},
#  {'address': {'street': 'West   58 Street'},
#   'cuisine': 'American',
#   'name': 'Coliseum Bar Restaurant'},
#  {'address': {'street': 'Avenue J'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Delight'},
#  {'address': {'street': 'West   42 Street'},
#   'cuisine': 'American',
#   'name': 'West Bank Cafe'},
#  {'address': {'street': 'East   52 Street'},
#   'cuisine': 'American',
#   'name': 'The Four Seasons'},
#  {'address': {'street': '16 Avenue'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Dairy Luncheonette'},
#  {'address': {'street': 'Grand Street'},
#   'cuisine': 'American',
#   'name': "Zafi'S Luncheonette"},
#  {'address': {'street': 'Avenue O'},
#   'cuisine': 'Italian',
#   'name': 'La Palina Restaurant'},
#  {'address': {'street': 'Victory Boulevard'},
#   'cuisine': 'American',
#   'name': "Schaffer'S Tavern"},
#  {'address': {'street': 'Christopher Street'},
#   'cuisine': 'American',
#   'name': "Ty'S"},
#  {'address': {'street': 'Avenue S'},
#   'cuisine': 'American',
#   'name': 'Mariner Inn'},
#  {'address': {'street': 'Northern Blvd'},
#   'cuisine': 'American',
#   'name': 'North Shore Diner'},
#  {'address': {'street': 'Martling Ave'},
#   'cuisine': 'American',
#   'name': 'Exclusive Catering'},
#  {'address': {'street': 'Third Avenue'},
#   'cuisine': 'American',
#   'name': 'Green House Cafe'},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Borden Avenue'},
#   'cuisine': 'American',
#   'name': 'Water Front Crab House'},
#  {'address': {'street': 'Queens Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'address': {'street': 'West   54 Street'},
#   'cuisine': 'American',
#   'name': "Murals On 54/Randolphs'S"},
#  {'address': {'street': 'Gerritsen Avenue'},
#   'cuisine': 'American',
#   'name': 'Veterans Of Foreign Wars Post #107 Canteen'},
#  {'address': {'street': 'Schenectady Avenue'},
#   'cuisine': 'Bakery',
#   'name': 'Tropical House Baking Co.'},
#  {'address': {'street': 'Westchester Avenue'},
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza'},
#  {'address': {'street': 'Rockaway Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'address': {'street': 'Park Avenue'},
#   'cuisine': 'American',
#   'name': 'Racquet & Tennis Club'},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'American',
#   'name': 'The Greek Corner'},
#  {'address': {'street': 'Bayridge Avenue'},
#   'cuisine': 'Mexican',
#   'name': 'Casa Pepe'},
#  {'address': {'street': 'West 55 Street'},
#   'cuisine': 'American',
#   'name': 'Astro Restaurant'},
#  {'address': {'street': 'Richmond Avenue'},
#   'cuisine': 'American',
#   'name': 'Golden Dove Diner'},
#  {'address': {'street': 'Church Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': 'Korner Pizzeria'},
#  {'address': {'street': 'Henry Street'},
#   'cuisine': 'American',
#   'name': "Henry'S End"},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': 'Petes Pizzeria & Restaurant'},
#  {'address': {'street': '3 Avenue'}, 'cuisine': 'American', 'name': 'Bar 515'},
#  {'address': {'street': 'Clarendon Road'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'address': {'street': 'Third Avenue'},
#   'cuisine': 'American',
#   'name': 'Bridgeview Diner'},
#  {'address': {'street': 'Grand Avenue'},
#   'cuisine': 'American',
#   'name': 'Hill Tap Tavern'},
#  {'address': {'street': 'Grand Avenue'},
#   'cuisine': 'American',
#   'name': "Burke'S Pub"},
#  {'address': {'street': 'City Island Ave'},
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant"},
#  {'address': {'street': 'Westchester Avenue'},
#   'cuisine': 'American',
#   'name': 'Quality Cafe & Restaurant'},
#  {'address': {'street': '8 Avenue'},
#   'cuisine': 'American',
#   'name': 'Kasteli Ii'},
#  {'address': {'street': 'Gerritsen Avenue'},
#   'cuisine': 'Pizza',
#   'name': 'Victoria Pizza'},
#  {'address': {'street': 'Kissena Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Strickland Avenue'},
#   'cuisine': 'Italian',
#   'name': 'El Caribe'},
#  {'address': {'street': 'Court Street'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Sutphin Boulevard'},
#   'cuisine': 'American',
#   'name': 'Europa Go-Go Dancing'},
#  {'address': {'street': 'Warren Street'},
#   'cuisine': 'American',
#   'name': 'Raccoon Lodge'},
#  {'address': {'street': 'Castle Hill Avenue'},
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant'},
#  {'address': {'street': 'Bedford Avenue'},
#   'cuisine': 'American',
#   'name': "Turkey'S Nest Tavern"},
#  {'address': {'street': '7 Avenue'}, 'cuisine': 'American', 'name': "Lindy'S"},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'American',
#   'name': 'Paris Blues'},
#  {'address': {'street': 'Emmons Avenue'},
#   'cuisine': 'Italian',
#   'name': 'Maria Ristorante'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Cozy Soup & Burger'},
#  {'address': {'street': '18 Avenue'},
#   'cuisine': 'Italian',
#   'name': 'Villa Fiorita'},
#  {'address': {'street': '86 Street'},
#   'cuisine': 'American',
#   'name': 'Vegas Diner'},
#  {'address': {'street': '103 Avenue'},
#   'cuisine': 'American',
#   'name': 'Moms Luncheonette'},
#  {'address': {'street': 'Amsterdam Avenue'},
#   'cuisine': 'American',
#   'name': 'Candle Bar'},
#  {'address': {'street': 'West 3 Street'},
#   'cuisine': 'American',
#   'name': 'Blue Note Jazz'},
#  {'address': {'street': 'Forest Avenue'},
#   'cuisine': 'American',
#   'name': "King'S Arms Restaurant"},
#  {'address': {'street': 'Court Street'},
#   'cuisine': 'Italian',
#   'name': 'Marco Polo Ristorante'},
#  {'address': {'street': 'Grove Street'},
#   'cuisine': 'American',
#   'name': 'Manhattan Monster'},
#  {'address': {'street': 'Memorial Ice Skating'},
#   'cuisine': 'American',
#   'name': 'War Memorial Ice Skating Rink'},
#  {'address': {'street': 'W 79 Street'},
#   'cuisine': 'American',
#   'name': 'American Museum Of Natural History Food Court'},
#  {'address': {'street': 'Atlantic Avenue'},
#   'cuisine': 'Mediterranean',
#   'name': 'Tripoli Restaurant'},
#  {'address': {'street': '44 Drive Foot E.River'},
#   'cuisine': 'American',
#   'name': "Water'S Edge Club"},
#  {'address': {'street': 'Amsterdam Avenue'},
#   'cuisine': 'American',
#   'name': 'Amsterdam Restaurant & Tapas Lounge'},
#  {'address': {'street': 'Minnieford Ave'},
#   'cuisine': 'Seafood',
#   'name': "Jp'S Waterside Restaurant"},
#  {'address': {'street': 'Lydig Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': 'John & Joe Pizzeria & Restaurant'},
#  {'address': {'street': 'Copper Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Third Avenue'},
#   'cuisine': 'American',
#   'name': 'Jackson Hole'},
#  {'address': {'street': 'Amsterdam Avenue'},
#   'cuisine': 'American',
#   'name': 'Utopia Restaurant'},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': 'Vesuvio Restaurant & Pizza'},
#  {'address': {'street': 'Grandview Avenue'},
#   'cuisine': 'American',
#   'name': 'Windjammers Bar'},
#  {'address': {'street': 'Second Avenue'},
#   'cuisine': 'American',
#   'name': 'Johns Cafe & Resturant'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Broadway Restaurant'},
#  {'address': {'street': 'Smith Street'},
#   'cuisine': 'Italian',
#   'name': 'Red Rose'},
#  {'address': {'street': 'Avenue U'},
#   'cuisine': 'Italian',
#   'name': 'Fiorentino Ristorante'},
#  {'address': {'street': 'Longwood Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza"},
#  {'address': {'street': 'Woodhaven Boulevard'},
#   'cuisine': 'American',
#   'name': "Port O' Calls"},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'American',
#   'name': 'Andrews Coffee Shop'},
#  {'address': {'street': 'Fresh Pond Road'},
#   'cuisine': 'American',
#   'name': 'The Clubhouse'},
#  {'address': {'street': 'Jamaica Avenue'},
#   'cuisine': 'American',
#   'name': "Mike'S Pub"},
#  {'address': {'street': 'Grand Avenue'},
#   'cuisine': 'American',
#   'name': 'Fame Diner'},
#  {'address': {'street': 'Emmons Avenue'},
#   'cuisine': 'American',
#   'name': 'Knights Of Baron Dekalb'},
#  {'address': {'street': 'Henderson Avenue'},
#   'cuisine': 'American',
#   'name': 'Union Hall'},
#  {'address': {'street': 'Kings Highway'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Hut Of Brooklyn'},
#  {'address': {'street': 'Bleeker Street'},
#   'cuisine': 'American',
#   'name': 'Terra Blues'},
#  {'address': {'street': 'East   12 Street'},
#   'cuisine': 'American',
#   'name': 'Gotham Bar & Grill'},
#  {'address': {'street': 'Boston Post Road'},
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'address': {'street': 'West   36 Street'},
#   'cuisine': 'American',
#   'name': "Delmonico'S Kitchen"},
#  {'address': {'street': '1 Avenue'},
#   'cuisine': 'American',
#   'name': 'Cooper Town Diner'},
#  {'address': {'street': 'Chambers Street'},
#   'cuisine': 'American',
#   'name': 'Imperial Coffee House'},
#  {'address': {'street': 'Cedar Street'},
#   'cuisine': 'American',
#   'name': "O'Hara'S"},
#  {'address': {'street': 'Katonah Ave'},
#   'cuisine': 'Irish',
#   'name': 'Aqueduct North'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Madison Avenue'},
#   'cuisine': 'American',
#   'name': 'E.A.T. Cafe'},
#  {'address': {'street': 'Laguardia Airport Bldg'},
#   'cuisine': 'American',
#   'name': 'Yankee Clipper'},
#  {'address': {'street': '60 Street'},
#   'cuisine': 'American',
#   'name': 'Rex Manor'},
#  {'address': {'street': 'E. 188 Th St'},
#   'cuisine': 'Spanish',
#   'name': 'Cuchifritos'},
#  {'address': {'street': 'Park Avenue'},
#   'cuisine': 'American',
#   'name': 'Club 101'},
#  {'address': {'street': 'Kingsbridge Avenue'},
#   'cuisine': 'American',
#   'name': 'Riverdale Diner'},
#  {'address': {'street': 'Bleecker Street'},
#   'cuisine': 'American',
#   'name': 'The Bitter End'},
#  {'address': {'street': 'Flatbush Avenue'},
#   'cuisine': 'Japanese',
#   'name': 'Geido Restaurant'},
#  {'address': {'street': 'Amsterdam Avenue'},
#   'cuisine': 'American',
#   'name': 'Barney Greengrass'},
#  {'address': {'street': 'West 52 Nd Street'},
#   'cuisine': 'American',
#   'name': 'Supernova-Novotel Hotel'},
#  {'address': {'street': 'Atlantic Avenue'},
#   'cuisine': 'Bottled beverages, including water, sodas, juices, etc.',
#   'name': 'Montero Bar & Grill'},
#  {'address': {'street': 'Surf Avenue'},
#   'cuisine': 'Seafood',
#   'name': "Pete'S Clam Stop"},
#  {'address': {'street': 'West   27 Street'},
#   'cuisine': 'American',
#   'name': 'Fit Cafeteria (Building A)'},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'Pizza',
#   'name': 'Smiling Pizza'},
#  {'address': {'street': 'Vernon Boulevard'},
#   'cuisine': 'American',
#   'name': "Riverhead Gentlemen'S Club"},
#  {'address': {'street': 'Meeker Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': "Nina'S Restaurant Pizzeria"},
#  {'address': {'street': 'Clark Street'},
#   'cuisine': 'American',
#   'name': "Clark'S Restaurant"},
#  {'address': {'street': 'Lafayette Street'},
#   'cuisine': 'American',
#   'name': 'Noho Star Restaurant'},
#  {'address': {'street': 'Forest Avenue'},
#   'cuisine': 'American',
#   'name': "Duffy'S"},
#  {'address': {'street': 'Richmond Hill Road'},
#   'cuisine': 'American',
#   'name': 'Latourette Golf Course'},
#  {'address': {'street': '86Th Street'},
#   'cuisine': 'American',
#   'name': 'Dyker Beach Golf (Grill Room)'},
#  {'address': {'street': 'St Johns Place'},
#   'cuisine': 'Caribbean',
#   'name': "Glenda'S Restaurant"},
#  {'address': {'street': 'Cropsey Avenue'},
#   'cuisine': 'American',
#   'name': "My Father'S Place"},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'Tex-Mex',
#   'name': 'Santa Fe Grill & Bar'},
#  {'address': {'street': 'Avenue A'},
#   'cuisine': 'American',
#   'name': 'Sidewalk Bar & Restaurant'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': "Coogan'S"},
#  {'address': {'street': '4 Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Bronxdale Avenue'},
#   'cuisine': 'American',
#   'name': 'Castlehill Diner'},
#  {'address': {'street': 'Park Avenue'},
#   'cuisine': 'American',
#   'name': 'Regency Hotel'},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Tommy'S Pizza"},
#  {'address': {'street': '4 Avenue'},
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Fe Restaurant'},
#  {'address': {'street': 'East  167 Street'},
#   'cuisine': 'Chicken',
#   'name': "Mom'S Fried Chicken"},
#  {'address': {'street': 'Queens Boulevard'},
#   'cuisine': 'American',
#   'name': 'Cobblestone Pub'},
#  {'address': {'street': 'East   53 Street'},
#   'cuisine': 'American',
#   'name': "Parnell'S Pub"},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'American',
#   'name': "O'Sullivan'S Pub"},
#  {'address': {'street': 'Spring Street'},
#   'cuisine': 'American',
#   'name': 'Spring St. Natural Restaurant'},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'Pizza',
#   'name': 'Pizza Wagon'},
#  {'address': {'street': 'Cornelia Street'},
#   'cuisine': 'American',
#   'name': 'Cornelia Street Cafe'},
#  {'address': {'street': 'East   84 Street'},
#   'cuisine': 'American',
#   'name': "Brandy'S Piano Bar"},
#  {'address': {'street': 'St Johns Place'},
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizzeria"},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'Bakery',
#   'name': "Cousin John'S Cafe And Bakery"},
#  {'address': {'street': 'Columbus Avenue'},
#   'cuisine': 'American',
#   'name': 'Jackson Hole'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Short Stop Restaurant'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Flash Dancers'},
#  {'address': {'street': 'Pennsylvania Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Amsterdam Avenue'},
#   'cuisine': 'American',
#   'name': "Josie'S Restaurant"},
#  {'address': {'street': 'Irving Place'},
#   'cuisine': 'American',
#   'name': 'Friend Of A Farmer'},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'Spanish',
#   'name': "Sancho'S Restaurant"},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'Indian',
#   'name': 'India Passage Restaurant'},
#  {'address': {'street': 'White Plains Road'},
#   'cuisine': 'American',
#   'name': 'Burger Barn Restaurant'},
#  {'address': {'street': 'Manhattan Avenue'},
#   'cuisine': 'Polish',
#   'name': "Irene'S Place"},
#  {'address': {'street': 'College Point Boulevard'},
#   'cuisine': 'American',
#   'name': 'Kanes Deli Diner'},
#  {'address': {'street': 'Pennsylvania Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'Kings Highway'},
#   'cuisine': 'Pizza',
#   'name': 'J & R Pizza'},
#  {'address': {'street': 'Ft Hamilton Parkway'},
#   'cuisine': 'Italian',
#   'name': "Rocco'S Calamari"},
#  {'address': {'street': 'West   47 Street'},
#   'cuisine': 'American',
#   'name': 'Cafe Edison'},
#  {'address': {'street': 'Montague Street'},
#   'cuisine': 'American',
#   'name': 'Grand Canyon'},
#  {'address': {'street': 'Washington Street'},
#   'cuisine': 'American',
#   'name': 'Automatic Slims'},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'American',
#   'name': 'Cappuccino Cafe'},
#  {'address': {'street': 'East    9 Street'},
#   'cuisine': 'American',
#   'name': 'Cloister Cafe'},
#  {'address': {'street': 'First Avenue'},
#   'cuisine': 'American',
#   'name': "Jimbo'S Hamburger Place"},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'American',
#   'name': '200 Fifth Avenue Restaurant & Sports Bar'},
#  {'address': {'street': 'Lafayette Avenue'},
#   'cuisine': 'American',
#   'name': 'Academy Restauraunt'},
#  {'address': {'street': 'Eastchester Road'},
#   'cuisine': 'American',
#   'name': 'Eastwood Manor'},
#  {'address': {'street': 'Cadman Plaza West'},
#   'cuisine': 'American',
#   'name': 'Park Plaza Restaurant'},
#  {'address': {'street': 'Fourth Avenue'},
#   'cuisine': 'Steak',
#   'name': "Hunter'S Steak & Ale House"},
#  {'address': {'street': 'Westchester Square'},
#   'cuisine': 'Pizza/Italian',
#   'name': "Ljubo'S Pizzeria"},
#  {'address': {'street': 'Richmond Avenue'},
#   'cuisine': 'American',
#   'name': 'Dakota Diner'},
#  {'address': {'street': 'Boston Road'},
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'address': {'street': 'Third Avenue'},
#   'cuisine': 'Middle Eastern',
#   'name': "Sally & George'S Place"},
#  {'address': {'street': 'Skillman Avenue'},
#   'cuisine': 'American',
#   'name': 'Jacks Ale House'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Doral Donuts'},
#  {'address': {'street': 'Unionport Road'},
#   'cuisine': 'Pizza',
#   'name': 'Venice Pizza'},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'American',
#   'name': 'Niles Restaurant'},
#  {'address': {'street': 'Seventh Avenue'},
#   'cuisine': 'Pizza',
#   'name': 'Pizza Plus'},
#  {'address': {'street': '56 Avenue'},
#   'cuisine': 'American',
#   'name': 'Oakland Cafeteria/Queensborough Community College'},
#  {'address': {'street': 'Myrtle Avenue'},
#   'cuisine': 'American',
#   'name': "Tasty'S"},
#  {'address': {'street': '56 Avenue'},
#   'cuisine': 'American',
#   'name': 'Q.B.Comm.College-Main Kitchen/Tiger Bites Pizza Section'},
#  {'address': {'street': 'West Third Street'},
#   'cuisine': 'American',
#   'name': 'New York University - Law School'},
#  {'address': {'street': 'Flushing Avenue'},
#   'cuisine': 'American',
#   'name': "Tina'S Restaurant"},
#  {'address': {'street': 'Northern Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': "Rocco'S Pizzeria"},
#  {'address': {'street': 'West   57 Street'},
#   'cuisine': 'American',
#   'name': 'Club Metropolitan'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Westside Restaurant'},
#  {'address': {'street': 'Bronxwood Avenue'},
#   'cuisine': 'Caribbean',
#   'name': "Frank'S Soup Bowl"},
#  {'address': {'street': 'Skillman Avenue'},
#   'cuisine': 'American',
#   'name': 'Copper Kettle'},
#  {'address': {'street': '56 Avenue'},
#   'cuisine': 'American',
#   'name': 'Science Cafe (Queensborough  Community College)'},
#  {'address': {'street': 'Atlantic Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'East   53 Street'},
#   'cuisine': 'American',
#   'name': "T & G Whitney'S"},
#  {'address': {'street': 'Bruckner Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'East Fordham Road'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'Berry Street'},
#   'cuisine': 'American',
#   'name': "Teddy'S Bar And Grill"},
#  {'address': {'street': 'East   23 Street'},
#   'cuisine': 'American',
#   'name': 'Live Bait Bar & Restaurant'},
#  {'address': {'street': 'Watchogue Road'},
#   'cuisine': 'American',
#   'name': 'Jimmy Max Restaurant'},
#  {'address': {'street': '8 Avenue'},
#   'cuisine': 'American',
#   'name': "T.G.I. Friday'S"},
#  {'address': {'street': 'Bleecker Street'},
#   'cuisine': 'American',
#   'name': 'Peculiar Pub'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Pizza',
#   'name': "Arturo'S Pizza"},
#  {'address': {'street': 'Nostrand Avenue'},
#   'cuisine': 'Caribbean',
#   'name': 'Nostrand Island Eatery'},
#  {'address': {'street': 'East  149 Street'},
#   'cuisine': 'Italian',
#   'name': 'Venice Restaurant'},
#  {'address': {'street': 'East  134 Street'},
#   'cuisine': 'American',
#   'name': 'Walnut Bus Stop'},
#  {'address': {'street': '41 Avenue'},
#   'cuisine': 'American',
#   'name': "Kelly'S Pub"},
#  {'address': {'street': 'Bay Street'},
#   'cuisine': 'American',
#   'name': 'Rosebank Tavern'},
#  {'address': {'street': '20 -3Rd Avenue'},
#   'cuisine': 'Italian',
#   'name': 'Areo Restaurant'},
#  {'address': {'street': '18 Avenue'},
#   'cuisine': 'American',
#   'name': 'Green Pavilion Restaurant & Sports Lounge'},
#  {'address': {'street': '9 Avenue'},
#   'cuisine': 'American',
#   'name': 'Westway Diner'},
#  {'address': {'street': 'Lexington Avenue'},
#   'cuisine': 'American',
#   'name': 'Lenox Hill Grill/Pizza'},
#  {'address': {'street': 'Broadway @ Trinity Pl'},
#   'cuisine': 'American',
#   'name': "T.G.I. Friday'S"},
#  {'address': {'street': 'Westchester Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'address': {'street': 'Hillel Place'},
#   'cuisine': 'Pizza',
#   'name': "Luigi'S Pizza"},
#  {'address': {'street': 'No Moore Street'},
#   'cuisine': 'American',
#   'name': "Walker'S Restaurant"},
#  {'address': {'street': '9 Avenue'},
#   'cuisine': 'American',
#   'name': 'Holland Bar'},
#  {'address': {'street': '13 Avenue'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Amnon Kosher Pizza'},
#  {'address': {'street': 'Metropolitan Avenue'},
#   'cuisine': 'Pizza',
#   'name': 'The Pizza Place'},
#  {'address': {'street': 'Boston Road'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'American',
#   'name': "T.G.I. Friday'S"},
#  {'address': {'street': 'Lawrence Street'},
#   'cuisine': 'Chinese',
#   'name': "Lee'S Villa Chinese Restaurant"},
#  {'address': {'street': 'Willis Avenue'},
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Isla Restauraunt'},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'Italian',
#   'name': "Spoto'S Restaurant"},
#  {'address': {'street': 'Amsterdam Avenue'},
#   'cuisine': 'American',
#   'name': 'Dive Bar'},
#  {'address': {'street': 'Washington Avenue'},
#   'cuisine': 'American',
#   'name': 'Brooklyn Botanic Catering Hall'},
#  {'address': {'street': 'Church Avenue'},
#   'cuisine': 'American',
#   'name': "Queen Bee'S Tavern"},
#  {'address': {'street': 'East   44 Street'},
#   'cuisine': 'American',
#   'name': 'The Cornell Center Of New York'},
#  {'address': {'street': 'Madison Avenue'},
#   'cuisine': 'American',
#   'name': 'Nectar Of 82Nd Street'},
#  {'address': {'street': 'East 42 Street'},
#   'cuisine': 'American',
#   'name': "T.G.I. Friday'S"},
#  {'address': {'street': 'Metropolitan Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'Avenue A'}, 'cuisine': 'American', 'name': '2A'},
#  {'address': {'street': 'Montague Street'},
#   'cuisine': 'Eastern European',
#   'name': "Teresa'S Resturant"},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'American',
#   'name': "Chadwick'S"},
#  {'address': {'street': 'West   40 Street'},
#   'cuisine': 'American',
#   'name': 'Pax Wholesome Foods'},
#  {'address': {'street': 'Bartow Ave'},
#   'cuisine': 'Delicatessen',
#   'name': 'Bagel Cafe'},
#  {'address': {'street': 'Pennplaza E, Penn Sta'},
#   'cuisine': 'American',
#   'name': 'T.G.I. Fridays'},
#  {'address': {'street': 'Pennsylvania Avenue'},
#   'cuisine': 'Pizza',
#   'name': 'Royal Pizza'},
#  {'address': {'street': '108 Street'},
#   'cuisine': 'American',
#   'name': 'Ideal Donut'},
#  {'address': {'street': 'Grand Street'},
#   'cuisine': 'American',
#   'name': 'Lucky Strike'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': "Tom'S Restaurant"},
#  {'address': {'street': 'Grand Concourse'},
#   'cuisine': 'Pizza',
#   'name': "Vinny'S Famous Pizza"},
#  {'address': {'street': 'East   58 Street'},
#   'cuisine': 'American',
#   'name': 'Townhouse Of Ny'},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'Italian',
#   'name': "Rino'S"},
#  {'address': {'street': 'Kent Avenue'},
#   'cuisine': 'Italian',
#   'name': 'Giando'},
#  {'address': {'street': 'Broad Street'},
#   'cuisine': 'American',
#   'name': 'Champ Gourmet'},
#  {'address': {'street': 'Austin Street'},
#   'cuisine': 'American',
#   'name': 'Austin House'},
#  {'address': {'street': 'Beach  116 Street'},
#   'cuisine': 'American',
#   'name': 'Wharf Bar And Grill'},
#  {'address': {'street': 'Court Street'},
#   'cuisine': 'Italian',
#   'name': 'Queen'},
#  {'address': {'street': '3 Avenue'}, 'cuisine': 'American', 'name': 'Barfly'},
#  {'address': {'street': '1 Avenue'},
#   'cuisine': 'American',
#   'name': "O'Flanagan'S"},
#  {'address': {'street': 'Throgs Neck Expressway'},
#   'cuisine': 'American',
#   'name': 'Villa Barone Manor'},
#  {'address': {'street': 'Amsterdam Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "The Famous Jimbo'S Hamburger Palace"},
#  {'address': {'street': 'Myrtle Avenue'},
#   'cuisine': 'Chinese',
#   'name': 'Kum Kau Kitchen'},
#  {'address': {'street': 'Bay Street'},
#   'cuisine': 'American',
#   'name': 'Danny Blaine'},
#  {'address': {'street': 'Springfield Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'Seafood',
#   'name': 'Loui Seafood'},
#  {'address': {'street': 'East    3 Street'},
#   'cuisine': 'American',
#   'name': 'The Edge Bar'},
#  {'address': {'street': 'Pitkin Avenue'},
#   'cuisine': 'American',
#   'name': "Dennis' Place"},
#  {'address': {'street': 'Lexington Avenue'},
#   'cuisine': 'American',
#   'name': "Scotty'S Diner"},
#  {'address': {'street': 'Fifth Avenue'},
#   'cuisine': 'Irish',
#   'name': "Killarney'S Pub"},
#  {'address': {'street': 'Third Avenue'},
#   'cuisine': 'American',
#   'name': "Luke'S Bar & Grill"},
#  {'address': {'street': 'East   71 Street'},
#   'cuisine': 'American',
#   'name': 'Belaire Cafe'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'The Palace Theater'},
#  {'address': {'street': '21 Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': 'Grotto Azzura Pizzeria'},
#  {'address': {'street': 'West 44 Street'},
#   'cuisine': 'American',
#   'name': 'Bar Association Of The City Of Ny Kitchen'},
#  {'address': {'street': '76 Street'},
#   'cuisine': 'American',
#   'name': 'Bay Ridge Manor Catering'},
#  {'address': {'street': 'Madison Avenue'},
#   'cuisine': 'American',
#   'name': '3 Guys'},
#  {'address': {'street': 'Eastchester Road'},
#   'cuisine': 'American',
#   'name': "Gleason'S Cafe"},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'Chinese',
#   'name': 'Szechuan Delight Restaurant'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Collado Restaurant'},
#  {'address': {'street': 'Bruckner Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'East 58 Street'},
#   'cuisine': 'American',
#   'name': 'Tokya'},
#  {'address': {'street': '6 Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Northern Boulevard'},
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'address': {'street': 'Lexington Avenue'},
#   'cuisine': 'American',
#   'name': "Lily'S Bar @ Roger Smith Hotel"},
#  {'address': {'street': 'Signs Road'},
#   'cuisine': 'American',
#   'name': 'Hillside Swimming Club'},
#  {'address': {'street': 'Grand Concourse'},
#   'cuisine': 'American',
#   'name': 'Fordham Seafood And Chicken'},
#  {'address': {'street': 'First Avenue'},
#   'cuisine': 'American',
#   'name': 'Sutton Cafe Restaurant'},
#  {'address': {'street': 'Main Street'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'West   38 Street'},
#   'cuisine': 'American',
#   'name': 'Cambridge Caterers'},
#  {'address': {'street': 'Park Avenue'},
#   'cuisine': 'Spanish',
#   'name': "Charle'S Corner Restaurant & Deli"},
#  {'address': {'street': '34 Avenue'},
#   'cuisine': 'American',
#   'name': 'B.Q.E. Cafe Billiards'},
#  {'address': {'street': 'Hudson Street'},
#   'cuisine': 'American',
#   'name': 'Henrietta Hudson'},
#  {'address': {'street': 'Lorimer Street'},
#   'cuisine': 'Pizza/Italian',
#   'name': "Sal'S Pizzeria"},
#  {'address': {'street': 'Avenue A'}, 'cuisine': 'American', 'name': 'Lucys'},
#  {'address': {'street': 'Avenue U'},
#   'cuisine': 'American',
#   'name': 'Bergen Beach Cafe'},
#  {'address': {'street': 'Brighton Beach Avenue'},
#   'cuisine': 'Russian',
#   'name': 'National Restaurant & Catering'},
#  {'address': {'street': 'Varick Street'},
#   'cuisine': 'American',
#   'name': "Amelia'S Restaurant"},
#  {'address': {'street': 'East   43 Street'},
#   'cuisine': 'American',
#   'name': 'Patrick Conways'},
#  {'address': {'street': 'Queens Boulevard'},
#   'cuisine': 'American',
#   'name': 'Georgia Diner'},
#  {'address': {'street': 'Jay Street'},
#   'cuisine': 'American',
#   'name': 'Metrostar Cafe'},
#  {'address': {'street': '4 Avenue'},
#   'cuisine': 'American',
# ...
#   'name': 'White Castle'},
#  {'address': {'street': 'Heyward Street'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Bais Rochel'},
#  {'address': {'street': 'East  161 Street'},
#   'cuisine': 'American',
#   'name': 'Crown Diner'},
#  {'address': {'street': '2 Avenue'},
#   'cuisine': 'American',
#   'name': 'Doc Watsons'},
#  {'address': {'street': 'Utica Avenue'},
#   'cuisine': 'Caribbean',
#   'name': 'Blue Mountain Restaurant & Jerk Center'},
#  {'address': {'street': 'Columbus Avenue'},
#   'cuisine': 'American',
#   'name': 'Firehouse'},
#  {'address': {'street': 'Fifth Avenue'},
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Continental Restaurant'},
#  {'address': {'street': 'West 55 Street'},
#   'cuisine': 'American',
#   'name': 'Mcgees Pub'},
#  {'address': {'street': 'East    5 Street'},
#   'cuisine': 'American',
#   'name': 'Ace Bar'},
#  {'address': {'street': 'Flushing Avenue'},
#   'cuisine': 'Bakery',
#   'name': 'Los Angeles Bakery'},
#  {'address': {'street': 'New Utrecht Ave'},
#   'cuisine': 'Russian',
#   'name': 'B66 Club'},
#  {'address': {'street': 'Jewett Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'address': {'street': 'West   34 Street'},
#   'cuisine': 'American',
#   'name': 'Skylight Diner'},
#  {'address': {'street': '51 Street'},
#   'cuisine': 'Mexican',
#   'name': 'Piaxtla Es Mexico Deli'},
#  {'address': {'street': 'West Broadway'},
#   'cuisine': 'American',
#   'name': 'Soho Grand Hotel'},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'American',
#   'name': 'Anopoli Family Restaurant'},
#  {'address': {'street': 'Barrow Street'},
#   'cuisine': 'American',
#   'name': 'Creative Edge Caterers'},
#  {'address': {'street': 'St Marks Place'},
#   'cuisine': 'American',
#   'name': 'St. Marks Ale House'},
#  {'address': {'street': 'Graham Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza"},
#  {'address': {'street': 'Jerome Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'City Island Avenue'},
#   'cuisine': 'Italian',
#   'name': "Artie'S"},
#  {'address': {'street': 'Bruckner Boulevard'},
#   'cuisine': 'American',
#   'name': 'Crosstown Diner'},
#  {'address': {'street': 'Foster Avenue'},
#   'cuisine': 'American',
#   'name': 'Atlantis Diner'},
#  {'address': {'street': 'Victory Boulevard'},
#   'cuisine': 'American',
#   'name': 'Campus Center Cafeteria'},
#  {'address': {'street': 'West Broadway'},
#   'cuisine': 'American',
#   'name': 'The Bubble Lounge'},
#  {'address': {'street': 'Francis Lewis Boulevard'},
#   'cuisine': 'American',
#   'name': 'Blue Bay Diner'},
#  {'address': {'street': 'Utica Avenue'},
#   'cuisine': 'Caribbean',
#   'name': 'Topaze Restaurant & Jerk Chicken'},
#  {'address': {'street': 'Forest Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Arthur Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Catania'S Pizza Cafe"},
#  {'address': {'street': 'East   82 Street'},
#   'cuisine': 'American',
#   'name': 'Kings Carriage House'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts Baskin Robbins"},
#  {'address': {'street': '63 Drive'},
#   'cuisine': 'American',
#   'name': 'Rego Park Cafe'},
#  {'address': {'street': '11 Avenue'},
#   'cuisine': 'American',
#   'name': 'Mcquaids Public House'},
#  {'address': {'street': 'Middletown Road'},
#   'cuisine': 'American',
#   'name': "Jimmy Ryan'S"},
#  {'address': {'street': 'Church Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'White Plains Road'},
#   'cuisine': 'American',
#   'name': 'Park Billiards'},
#  {'address': {'street': 'Castle Hill Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': '150 Street'},
#   'cuisine': 'American',
#   'name': "Shenanigan'S"},
#  {'address': {'street': 'East  187 Street'},
#   'cuisine': 'Pizza',
#   'name': 'Full Moon Pizza'},
#  {'address': {'street': 'Avenue Z'},
#   'cuisine': 'American',
#   'name': 'The Bras & Pail Bar'},
#  {'address': {'street': 'Dreiser Loop'},
#   'cuisine': 'Pizza',
#   'name': 'Capri Ii Pizza'},
#  {'address': {'street': 'East   63 Street'},
#   'cuisine': 'American',
#   'name': 'Club Macanudo (Cigar Bar)'},
#  {'address': {'street': 'Varick Street'},
#   'cuisine': 'American',
#   'name': "Deb'S"},
#  {'address': {'street': 'Ninth Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': 'Island Burgers And Shakes'},
#  {'address': {'street': 'Meserole Avenue'},
#   'cuisine': 'American',
#   'name': 'Pit Stop Bar'},
#  {'address': {'street': 'Nelson Avenue'},
#   'cuisine': 'American',
#   'name': 'Grand Plaza'},
#  {'address': {'street': 'East    4 Street'},
#   'cuisine': 'American',
#   'name': 'Swift'},
#  {'address': {'street': 'Amboy Road'},
#   'cuisine': 'American',
#   'name': 'Perkins Family Restaurant & Bakery'},
#  {'address': {'street': 'Bartow Ave'},
#   'cuisine': 'Chinese',
#   'name': 'Dragon City'},
#  {'address': {'street': '86 Street'},
#   'cuisine': 'Bakery',
#   'name': 'Your Bakery'},
#  {'address': {'street': 'Hanover Square'},
#   'cuisine': 'American',
#   'name': 'Cafe Bravo'},
#  {'address': {'street': 'Avenue Of The Americas'},
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'address': {'street': 'Avenue B'}, 'cuisine': 'American', 'name': "Mona'S"},
#  {'address': {'street': 'West Broadway'},
#   'cuisine': 'American',
#   'name': 'Corner Gourmet Ii'},
#  {'address': {'street': 'Westchester Avenue'},
#   'cuisine': 'Bakery',
#   'name': 'Nacional Bakery #1'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Tap-A-Keg'},
#  {'address': {'street': 'Sullivan Street'},
#   'cuisine': 'American',
#   'name': 'The Room'},
#  {'address': {'street': '82 Street'},
#   'cuisine': 'American',
#   'name': 'Burger King'},
#  {'address': {'street': 'Avenue A'}, 'cuisine': 'American', 'name': 'Odessa'},
#  {'address': {'street': '18 Avenue'},
#   'cuisine': 'Italian',
#   'name': 'La Cucina'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Crown Gourmet Deli'},
#  {'address': {'street': '4 Avenue'},
#   'cuisine': 'Spanish',
#   'name': 'Don Paco  Lopez Panderia'},
#  {'address': {'street': 'Fulton Street'},
#   'cuisine': 'Caribbean',
#   'name': 'Brooklyn Moon Cafe'},
#  {'address': {'street': 'Rossville Avenue'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': '86 Street'},
#   'cuisine': 'Delicatessen',
#   'name': 'Dyker Park Bagels'},
#  {'address': {'street': 'Northern Boulevard'},
#   'cuisine': 'American',
#   'name': 'Adria Hotel'},
#  {'address': {'street': 'Bleecker Street'},
#   'cuisine': 'American',
#   'name': 'Von'},
#  {'address': {'street': 'Flatbush Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Antonio'S Pizza"},
#  {'address': {'street': 'West   52 Street'},
#   'cuisine': 'American',
#   'name': 'Neil Simon Theatre'},
#  {'address': {'street': 'Westchester Avenue'},
#   'cuisine': 'Chinese/Cuban',
#   'name': 'New Pabellon De Oro Restaurant'},
#  {'address': {'street': 'Nostrand Avenue'},
#   'cuisine': 'Caribbean',
#   'name': "Vee'S Restaurant"},
#  {'address': {'street': 'Flatbush Avenue'},
#   'cuisine': 'Spanish',
#   'name': 'La Cabana Restaurant'},
#  {'address': {'street': '31 Avenue'},
#   'cuisine': 'American',
#   'name': "Cassidy'S Ale House"},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Connecticut Muffin'},
#  {'address': {'street': 'Quentin Road'},
#   'cuisine': 'American',
#   'name': "Nora'S Park Bench Cafe"},
#  {'address': {'street': 'East   84 Street'},
#   'cuisine': 'American',
#   'name': 'Trinity Pub'},
#  {'address': {'street': 'West   35 Street'},
#   'cuisine': 'American',
#   'name': 'Anesis Cafe'},
#  {'address': {'street': 'Avenue N'},
#   'cuisine': 'Italian',
#   'name': 'Pinocchios'},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'American',
#   'name': '810 Deli & Cafe'},
#  {'address': {'street': '86 Street'},
#   'cuisine': 'Chinese',
#   'name': "New Ruan'S Restaurant"},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'Spanish',
#   'name': 'Cosmos Restaurant'},
#  {'address': {'street': 'West Broadway'},
#   'cuisine': 'American',
#   'name': "Edward'S"},
#  {'address': {'street': 'East   57 Street'},
#   'cuisine': 'American',
#   'name': 'Four Seasons Hotel'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': '7 Avenue'},
#   'cuisine': 'American',
#   'name': 'Red Eye Grill'},
#  {'address': {'street': 'East   57 Street'},
#   'cuisine': 'American',
#   'name': 'Four Seasons Hotel'},
#  {'address': {'street': 'Grand Central Parkway'},
#   'cuisine': 'American',
#   'name': 'Towers Restaurant'},
#  {'address': {'street': 'Seventh Avenue'},
#   'cuisine': 'American',
#   'name': "Mustang Harry'S"},
#  {'address': {'street': 'East 40Th Street'},
#   'cuisine': 'American',
#   'name': 'Food Merchants'},
#  {'address': {'street': 'Amboy Road'},
#   'cuisine': 'American',
#   'name': "W'S Bar & Restaurant"},
#  {'address': {'street': 'East   35 Street'},
#   'cuisine': 'Caribbean',
#   'name': 'Bake And Things Restaurant'},
#  {'address': {'street': 'Chrystie Street'},
#   'cuisine': 'American',
#   'name': "Neuman'S"},
#  {'address': {'street': 'New Utrecht Avenue'},
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Shemtov Manor'},
#  {'address': {'street': 'Hollers Avenue'},
#   'cuisine': 'American',
#   'name': 'Bowler Land'},
#  {'address': {'street': 'Lincoln Avenue'},
#   'cuisine': 'American',
#   'name': 'The Corner House'},
#  {'address': {'street': '9 Avenue'},
#   'cuisine': 'American',
#   'name': 'Renaissance Restaurant Bar And Garden Diner'},
#  {'address': {'street': 'Gerard Avenue'},
#   'cuisine': 'Caribbean',
#   'name': 'Feeding Tree Style West Indian Restaurant'},
#  {'address': {'street': 'West   39 Street'},
#   'cuisine': 'American',
#   'name': 'Escuelita Club'},
#  {'address': {'street': 'Steinway Street'},
#   'cuisine': 'American',
#   'name': 'Mini Star Restaurant'},
#  {'address': {'street': 'Avenue X'},
#   'cuisine': 'Bakery',
#   'name': 'Cuccios Bakery'},
#  {'address': {'street': 'Calloway Street'},
#   'cuisine': 'American',
#   'name': 'Forest Hills Spa'},
#  {'address': {'street': 'Avenue U'}, 'cuisine': 'Italian', 'name': 'Il Posto'},
#  {'address': {'street': '130 Street'},
#   'cuisine': 'American',
#   'name': 'Nix Mix Coffee Shop'},
#  {'address': {'street': 'Newkirk Plaza'},
#   'cuisine': 'Pizza',
#   'name': "Loduca'S Pizza"},
#  {'address': {'street': '20 Avenue'},
#   'cuisine': 'Bakery',
#   'name': 'Mondial Bakery'},
#  {'address': {'street': '30 Avenue'},
#   'cuisine': 'American',
#   'name': 'Crescent Corner'},
#  {'address': {'street': 'Mcdonald Avenue'},
#   'cuisine': 'Pizza/Italian',
#   'name': "Vinnie'S Pizzeria/ Luncheonette"},
#  {'address': {'street': '13 Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Benny'S Famous Pizza"},
#  {'address': {'street': '24 Avenue'},
#   'cuisine': 'American',
#   'name': "Riccardo'S"},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'American',
#   'name': 'City Market Cafe'},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'American',
#   'name': 'Speedy Deli'},
#  {'address': {'street': 'Columbus Avenue'},
#   'cuisine': 'American',
#   'name': 'Prohibition'},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'American',
#   'name': "Pc'S Bar And Grill"},
#  {'address': {'street': 'West 31 Street'},
#   'cuisine': 'American',
#   'name': 'Cafe 31'},
#  {'address': {'street': 'Astoria Boulevard'},
#   'cuisine': 'American',
#   'name': 'The Neptune Diner'},
#  {'address': {'street': 'Riverside Drive'},
#   'cuisine': 'American',
#   'name': 'Internationalhouse'},
#  {'address': {'street': 'Whiteplains Road'},
#   'cuisine': 'Caribbean',
#   'name': 'Rio Cobre Restaurant'},
#  {'address': {'street': 'East   52 Street'},
#   'cuisine': 'American',
#   'name': 'Fireside'},
#  {'address': {'street': 'Williamsbridge Road'},
#   'cuisine': 'Italian',
#   'name': 'Pasta Pasta Restaurant'},
#  {'address': {'street': 'Gravesend Neck Road'},
#   'cuisine': 'American',
#   'name': "Jp'S Bar"},
#  {'address': {'street': '30 Avenue'},
#   'cuisine': 'American',
#   'name': 'Tastee Corner'},
#  {'address': {'street': 'West   19 Street'},
#   'cuisine': 'American',
#   'name': 'G'},
#  {'address': {'street': 'Bedford Avenue'},
#   'cuisine': 'American',
#   'name': 'Metropolitan Food Cafe Of Brooklyn College'},
#  {'address': {'street': '3 Avenue'},
#   'cuisine': 'Mediterranean',
#   'name': 'Omonia Cafe'},
#  {'address': {'street': '4 Avenue'},
#   'cuisine': 'Mexican',
#   'name': "Isabela'S Mexican Cuisine"},
#  {'address': {'street': 'Fresh Pond Road'},
#   'cuisine': 'American',
#   'name': 'Glenlo Tavern'},
#  {'address': {'street': 'Van Brunt Street'},
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Red Hook Coffee Shop'},
#  {'address': {'street': 'East    6 Street'},
#   'cuisine': 'American',
#   'name': 'Death & Co'},
#  {'address': {'street': 'Avenue U'},
#   'cuisine': 'American',
#   'name': 'Paradise Caterers'},
#  {'address': {'street': 'Dekalb Avenue'},
#   'cuisine': 'American',
#   'name': 'Alibi Club'},
#  {'address': {'street': 'Cross Bay Boulevard'},
#   'cuisine': 'American',
#   'name': 'Roma View Catering'},
#  {'address': {'street': 'East  138 Street'},
#   'cuisine': 'Pizza',
#   'name': "Ray'S Pizza Restuarant"},
#  {'address': {'street': 'Broadway'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Castleton Avenue'},
#   'cuisine': 'American',
#   'name': 'Blue & Gray Inn'},
#  {'address': {'street': 'West  231 Street'},
#   'cuisine': 'American',
#   'name': "Louie'Sdale Diner"},
#  {'address': {'street': 'West Kingsbridge Road'},
#   'cuisine': 'Mexican',
#   'name': 'Montezuma Restaurant'},
#  {'address': {'street': 'White Plains Road'},
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'address': {'street': 'Victory Boulevard'},
#   'cuisine': 'American',
#   'name': 'Mug Shots'},
#  {'address': {'street': 'East   46 Street'},
#   'cuisine': 'American',
#   'name': "Aretsky'S Patroon"},
#  {'address': {'street': 'East Houston Street'},
#   'cuisine': 'American',
#   'name': 'Lite Delights'},
#  {'address': {'street': 'Sheepshead Bay Road'},
#   'cuisine': 'American',
#   'name': 'Night Light Cafe'},
#  {'address': {'street': 'Flatbush Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Gino'S Pizza"},
#  {'address': {'street': 'Castle Hill Ave'},
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'address': {'street': 'Amsterdam Avenue'},
#   'cuisine': 'American',
#   'name': 'The Gin Mill'},
#  {'address': {'street': 'Johnson Avenue'},
#   'cuisine': 'Chinese',
#   'name': 'Hunan Balcony'},
#  {'address': {'street': 'East  187 Street'},
#   'cuisine': 'Chinese',
#   'name': 'Great Wall Restaurant'},
#  {'address': {'street': 'Post Avenue'},
#   'cuisine': 'American',
#   'name': 'Ground Level Beer Pub'},
#  {'address': {'street': 'Manhattan Avenue'},
#   'cuisine': 'Mexican',
#   'name': 'Acapulco Deli & Restaurant'},
#  {'address': {'street': 'West Broadway'},
#   'cuisine': 'American',
#   'name': 'Distilled'},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'Chicken',
#   'name': 'Boston Market'},
#  {'address': {'street': '5 Avenue'},
#   'cuisine': 'Pizza',
#   'name': "Lenny'S Pizza"},
#  {'address': {'street': 'East Tremont Avenue'},
#   'cuisine': 'Bakery',
#   'name': 'La Bella Rosa Bakery'},
#  {'address': {'street': '4 Avenue'},
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Familia Restaurant'},
#  {'address': {'street': 'West   44 Street'},
#   'cuisine': 'American',
#   'name': 'Birdland'},
#  {'address': {'street': '3 Avenue'}, 'cuisine': 'American', 'name': 'Am'},
#  {'address': {'street': 'Wall Street'},
#   'cuisine': 'American',
#   'name': 'Bank Of New York'},
#  {'address': {'street': 'Allerton Avenue'},
#   'cuisine': 'Chicken',
#   'name': 'Kennedy Fried Chicken'},
#  {'address': {'street': 'East   60 Street'},
#   'cuisine': 'American',
#   'name': "Sunberry'S"},
#  {'address': {'street': '31 Street'},
#   'cuisine': 'American',
#   'name': 'Last Stop Restaurant'},
#  {'address': {'street': 'Westchester Avenue'},
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Isla Cuchifritos'},
#  {'address': {'street': 'Broadway'}, 'cuisine': 'American', 'name': 'Keenans'},
#  {'address': {'street': 'Avenue Of The Americas'},
#   'cuisine': 'American',
#   'name': 'Flik International'},
#  ...]

# %%
cursor = collection.aggregate(
                              [
                                {'$match':{'address.zipcode': '10452'}},
                                {'$project':{'_id':0, 'name':1}}
                              ])
res = list(cursor)
res [:3]
# Out:
# [{'name': 'Munchtime'},
#  {'name': 'Feeding Tree Style West Indian Restaurant'},
#  {'name': 'La Sabrosura'}]

# %%
cursor = collection.aggregate([
    
    {'$match':{'cuisine': 'American'}},
    {'$group':{'_id': '$borough', 'American restaurants':{'$sum': 1}}},
      
])
"""When used in the $group stage, $sum has the following syntax and returns the collective sum of all 
the numeric values that result from applying a specified expression to each document in a group of 
documents that share the same group by key:"""


results = list(cursor)
results[:]
# Out:
# [{'_id': 'Queens', 'American restaurants': 1040},
#  {'_id': 'Manhattan', 'American restaurants': 3205},
#  {'_id': 'Bronx', 'American restaurants': 411},
#  {'_id': 'Staten Island', 'American restaurants': 244},
#  {'_id': 'Missing', 'American restaurants': 10},
#  {'_id': 'Brooklyn', 'American restaurants': 1273}]

# %%
cursor = collection.aggregate([
    
    {'$match':{'cuisine': 'American'}},
    {'$group':{'_id': '$borough', 'American restaurants':{'$sum': 1}}},
    {'$sort': {'American restaurants':-1}}
      
])
"""sort("name", 1) #ascending
sort("name", -1) #descending"""
results = list(cursor)
results[:]
# Out:
# [{'_id': 'Manhattan', 'American restaurants': 3205},
#  {'_id': 'Brooklyn', 'American restaurants': 1273},
#  {'_id': 'Queens', 'American restaurants': 1040},
#  {'_id': 'Bronx', 'American restaurants': 411},
#  {'_id': 'Staten Island', 'American restaurants': 244},
#  {'_id': 'Missing', 'American restaurants': 10}]

# %%
cursor = collection.aggregate([
    
    {'$match':{'cuisine': 'American'}},
    {'$group':{'_id': '$borough', 'American restaurants':{'$sum': 1}}}, #εδώ χρειάζεται το $borough. Γιατί όχι σκέτο;
    {'$sort': {'American restaurants':-1}},
    {'$limit': 3}
      
])

results = list(cursor)
results[:]
# Out:
# [{'_id': 'Manhattan', 'American restaurants': 3205},
#  {'_id': 'Brooklyn', 'American restaurants': 1273},
#  {'_id': 'Queens', 'American restaurants': 1040}]

# %%
cursor = collection.aggregate([
    
    {'$match':{'cuisine': 'American'}},
    {'$sample': { 'size': 1 }}

])
"""$sample
Randomly selects the specified number of documents from the input documents."""
results = list(cursor)
results
# Out:
# [{'_id': ObjectId('6049400f32c9cd22009c9686'),
#   'address': {'building': '1055',
#    'coord': [-73.96064299999999, 40.772188],
#    'street': 'Lexington Avenue',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'American',
#   'grades': [{'date': datetime.datetime(2014, 9, 4, 0, 0),
#     'grade': 'A',
#     'score': 13},
#    {'date': datetime.datetime(2014, 1, 15, 0, 0), 'grade': 'A', 'score': 10},
#    {'date': datetime.datetime(2013, 6, 13, 0, 0), 'grade': 'B', 'score': 17},
#    {'date': datetime.datetime(2012, 12, 17, 0, 0), 'grade': 'B', 'score': 20},
#    {'date': datetime.datetime(2012, 5, 14, 0, 0), 'grade': 'B', 'score': 18}],
#   'name': 'Eats',
#   'restaurant_id': '41572551'}]

# %%
cursor = collection.aggregate([
    
    {'$match':{'cuisine': 'American'}},
    {'$unwind': '$grades'},
    {'$group': {'_id': '$_id', 'name': {"$max":"$name"}, 'Average raiting': {'$avg': '$grades.score'}}},
    {'$project': {'name':1, 'Average raiting':{ '$round': [ "$Average raiting", 2 ] }, '_id':0}}
      
])

results = list(cursor)
results[:]
# Out:
# [{'name': '3Rd & 7', 'Average raiting': 12.5},
#  {'name': 'Sidewalk Bar & Restaurant', 'Average raiting': 9.0},
#  {'name': 'Cafe Hanover', 'Average raiting': 13.0},
#  {'name': 'Worth Cafe', 'Average raiting': 13.83},
#  {'name': 'Cafe Sfa Nyc', 'Average raiting': 11.33},
#  {'name': "Sotheby'S", 'Average raiting': 4.0},
#  {'name': 'Bateaux New York', 'Average raiting': 9.25},
#  {'name': "Popeye'S Chicken & Biscuits", 'Average raiting': 8.5},
#  {'name': '9Th Ave Saloon', 'Average raiting': 13.0},
#  {'name': "Teresa'S Gourmet", 'Average raiting': 12.5},
#  {'name': 'Planet Hollywood', 'Average raiting': 12.33},
#  {'name': 'Johnny Foxes', 'Average raiting': 10.17},
#  {'name': 'Amc Theatres 84Th Street', 'Average raiting': 11.6},
#  {'name': 'Packard  Cafe', 'Average raiting': 10.2},
#  {'name': 'Big Nose Kates', 'Average raiting': 14.0},
#  {'name': 'Julius', 'Average raiting': 14.83},
#  {'name': 'Amc/Lowes Theatres Kips Bay', 'Average raiting': 12.4},
#  {'name': 'Pandora', 'Average raiting': 11.0},
#  {'name': 'Bagels On The Island', 'Average raiting': 26.5},
#  {'name': 'Prospect', 'Average raiting': 15.0},
#  {'name': "Auntie Anne'S", 'Average raiting': 9.0},
#  {'name': 'The Bread Factory Cafe', 'Average raiting': 12.8},
#  {'name': 'Morgan Stanley Cafeteria', 'Average raiting': 4.25},
#  {'name': 'Gastronomie 491', 'Average raiting': 14.4},
#  {'name': 'Au Bon Pain', 'Average raiting': 2.0},
#  {'name': 'Azylum Bar & Lounge', 'Average raiting': 8.5},
#  {'name': 'Taco Bell', 'Average raiting': 6.5},
#  {'name': "John'S Bar", 'Average raiting': 12.0},
#  {'name': 'Temptations', 'Average raiting': 5.67},
#  {'name': '1 Oak', 'Average raiting': 9.67},
#  {'name': 'Coliseum Bar Restaurant', 'Average raiting': 11.4},
#  {'name': 'Stk', 'Average raiting': 22.0},
#  {'name': 'Water Front Crab House', 'Average raiting': 8.75},
#  {'name': 'Bean Post Pub', 'Average raiting': 17.4},
#  {'name': 'Belasco Theatre', 'Average raiting': 6.0},
#  {'name': 'Golden Eagle Restaurant', 'Average raiting': 15.33},
#  {'name': 'San Marzano', 'Average raiting': 23.0},
#  {'name': 'Uno Cafe & Billiards', 'Average raiting': 15.25},
#  {'name': "Lets Get Juiced Lucky'S Juice Bar", 'Average raiting': 12.25},
#  {'name': 'R Bar', 'Average raiting': 15.0},
#  {'name': '706 Bar', 'Average raiting': 15.8},
#  {'name': 'Hero Express & Grocery', 'Average raiting': 7.0},
#  {'name': 'Brooklyn Law School', 'Average raiting': 10.5},
#  {'name': 'Donna', 'Average raiting': 7.0},
#  {'name': 'Field Level In Seat Kitchen', 'Average raiting': 6.33},
#  {'name': "Chic-Fil-A, Quiznos Subs, Jw'S, Tossed", 'Average raiting': 7.0},
#  {'name': 'Potlikker', 'Average raiting': 15.67},
#  {'name': 'Cinema Cafe & Bar', 'Average raiting': 13.0},
#  {'name': 'Ruby Falls Nightlife Cafe', 'Average raiting': 14.33},
#  {'name': 'The Neptune Diner', 'Average raiting': 8.25},
#  {'name': 'Glen Terrace', 'Average raiting': 11.0},
#  {'name': 'Flik International', 'Average raiting': 7.33},
#  {'name': 'Ciao For Now', 'Average raiting': 11.5},
#  {'name': 'Subway Inn', 'Average raiting': 9.4},
#  {'name': 'Crown Fried Chicken', 'Average raiting': 9.0},
#  {'name': 'B&W Deli Grocery', 'Average raiting': 6.0},
#  {'name': "Baby'S All Right", 'Average raiting': 10.0},
#  {'name': 'Bar Prima', 'Average raiting': 11.0},
#  {'name': 'Brooklyn Crepe And Juice', 'Average raiting': 9.0},
#  {'name': "Beecher'S Handmade Cheese", 'Average raiting': 10.0},
#  {'name': 'Corbet & Conley', 'Average raiting': 18.0},
#  {'name': 'New Parkway Restaurant', 'Average raiting': 10.33},
#  {'name': 'Potbelly Sandwich Shop', 'Average raiting': 8.25},
#  {'name': 'The Paper Box', 'Average raiting': 16.0},
#  {'name': "Jimbo'S Hamburger Place", 'Average raiting': 10.2},
#  {'name': "Manny'S On Second", 'Average raiting': 14.0},
#  {'name': 'Siglo 21 Lounge', 'Average raiting': 10.0},
#  {'name': 'The New Maspeth Diner', 'Average raiting': 11.0},
#  {'name': "South'S", 'Average raiting': 11.4},
#  {'name': 'Strike 10 Lanes (Sports Bar)', 'Average raiting': 7.2},
#  {'name': 'Martinique Cafe', 'Average raiting': 10.2},
#  {'name': 'The Social Butterfly', 'Average raiting': 7.75},
#  {'name': 'Bar Corvo', 'Average raiting': 18.75},
#  {'name': 'Ann Taylor', 'Average raiting': 8.75},
#  {'name': "Shorty'S", 'Average raiting': 4.5},
#  {'name': 'The Capital Grille', 'Average raiting': 9.2},
#  {'name': 'Butterfield Cafe', 'Average raiting': 8.0},
#  {'name': "Murette'S", 'Average raiting': 7.0},
#  {'name': 'Hillside', 'Average raiting': 2.0},
#  {'name': 'Tbsp', 'Average raiting': 10.17},
#  {'name': 'New York Dolls', 'Average raiting': 15.6},
#  {'name': 'Crown Fried Chicken', 'Average raiting': 14.0},
#  {'name': 'Little Park', 'Average raiting': 7.0},
#  {'name': "Burke'S Pub", 'Average raiting': 12.17},
#  {'name': 'La Verite Restaurant Bar', 'Average raiting': 11.5},
#  {'name': 'Carlyle Green  Pool Stand', 'Average raiting': 7.75},
#  {'name': 'Bean N Bean Corp.', 'Average raiting': 6.8},
#  {'name': 'Admirals Club Conc C', 'Average raiting': 19.4},
#  {'name': 'Richmond County Yacht Club', 'Average raiting': 9.0},
#  {'name': "Dunkin' Donuts/Baskin Robbins", 'Average raiting': 5.2},
#  {'name': 'Bar 483', 'Average raiting': 10.25},
#  {'name': 'Cafe Pick Me Up', 'Average raiting': 17.17},
#  {'name': 'Gyro Corner', 'Average raiting': 12.0},
#  {'name': 'Manon', 'Average raiting': 30.5},
#  {'name': 'Brasserie 8 1/2', 'Average raiting': 14.4},
#  {'name': 'The Madelyn', 'Average raiting': 18.67},
#  {'name': "Theresa'S Place", 'Average raiting': 9.33},
#  {'name': 'Rego Park Cafe', 'Average raiting': 17.6},
#  {'name': 'One Mile House', 'Average raiting': 10.25},
#  {'name': 'Thomas Preti Caterers', 'Average raiting': 10.4},
#  {'name': 'Jr & Son', 'Average raiting': 8.67},
#  {'name': 'Cafe Mae Mae', 'Average raiting': 10.25},
#  {'name': 'Busters Nyc', 'Average raiting': 8.75},
#  {'name': 'Penny Farthing Restaurant', 'Average raiting': 9.0},
#  {'name': 'Vinateria', 'Average raiting': 11.0},
#  {'name': 'Don Pedro Restaurant', 'Average raiting': 23.8},
#  {'name': 'Dyre Avenue Diner', 'Average raiting': 12.0},
#  {'name': 'Connecticut Muffin', 'Average raiting': 7.8},
#  {'name': 'Studio Twenty One', 'Average raiting': 7.5},
#  {'name': 'Stand 312', 'Average raiting': 6.33},
#  {'name': 'Guy & Gallard', 'Average raiting': 10.83},
#  {'name': 'The General Greene', 'Average raiting': 15.0},
#  {'name': 'Playwrights Horizons', 'Average raiting': 0.0},
#  {'name': 'Dean & Deluca', 'Average raiting': 23.2},
#  {'name': 'Lobster Joint', 'Average raiting': 8.71},
#  {'name': 'The Skyview Restaurant', 'Average raiting': 11.0},
#  {'name': 'Dimes', 'Average raiting': 19.0},
#  {'name': 'Kennedy Fried Chicken', 'Average raiting': 10.75},
#  {'name': 'Townhouse Of Ny', 'Average raiting': 12.5},
#  {'name': 'Stand 404', 'Average raiting': 0.67},
#  {'name': "Duff'S Brooklyn", 'Average raiting': 8.0},
#  {'name': 'The Manhattan Inn', 'Average raiting': 40.0},
#  {'name': 'Village Pourhouse', 'Average raiting': 17.33},
#  {'name': 'Royalton Hotel', 'Average raiting': 11.67},
#  {'name': 'Fordham University - Mcginley Center', 'Average raiting': 11.0},
#  {'name': 'Johnny Rockets', 'Average raiting': 10.17},
#  {'name': 'Farrells', 'Average raiting': 7.75},
#  {'name': 'Celebrate At Snug Harbor', 'Average raiting': 39.0},
#  {'name': 'Day Break Cafe Restaurant', 'Average raiting': 8.5},
#  {'name': 'Silo Cafe', 'Average raiting': 19.0},
#  {'name': 'Rathbones Pub', 'Average raiting': 15.4},
#  {'name': 'Room Service Kitchen', 'Average raiting': 8.5},
#  {'name': 'Arena Lounge', 'Average raiting': 14.0},
#  {'name': 'Triomphe', 'Average raiting': 7.2},
#  {'name': 'Room Mate Grace Hotel', 'Average raiting': 20.0},
#  {'name': 'Allure', 'Average raiting': 10.67},
#  {'name': 'Proletariat Ny', 'Average raiting': 13.25},
#  {'name': 'Subway', 'Average raiting': 7.0},
#  {'name': 'Appetite Nyc Llc', 'Average raiting': 7.25},
#  {'name': 'Nevada Diner', 'Average raiting': 14.25},
#  {'name': "Bloom'S Tavern", 'Average raiting': 11.5},
#  {'name': 'The Brothers Cafe', 'Average raiting': 14.17},
#  {'name': "Pete'S Cafe", 'Average raiting': 7.33},
#  {'name': 'Broadway Theatre', 'Average raiting': 10.17},
#  {'name': 'Stillwater Bar & Grill', 'Average raiting': 11.33},
#  {'name': 'Lyceum Theatre', 'Average raiting': 4.67},
#  {'name': '3 Deli & Grill', 'Average raiting': 9.67},
#  {'name': 'Rojas Coffee Shop', 'Average raiting': 17.5},
#  {'name': 'The Parlour', 'Average raiting': 13.25},
#  {'name': "Benateri'S At Edgewater", 'Average raiting': 8.5},
#  {'name': 'Momofuku Ko', 'Average raiting': 5.75},
#  {'name': 'The Jake Walk', 'Average raiting': 8.33},
#  {'name': 'Lit Lounge Nyc', 'Average raiting': 15.4},
#  {'name': 'Paramount Bar & Grill', 'Average raiting': 12.4},
#  {'name': 'Doma Na Rohu', 'Average raiting': 10.5},
#  {'name': 'The New Amity Restaurant', 'Average raiting': 8.4},
#  {'name': 'Morgan Stanley Conference Center', 'Average raiting': 5.0},
#  {'name': 'Juventino', 'Average raiting': 12.2},
#  {'name': 'Stand 335 Beverages & Snacks', 'Average raiting': 1.33},
#  {'name': 'Manhattan West', 'Average raiting': 7.75},
#  {'name': 'Park Central Hotel Kitchen', 'Average raiting': 13.0},
#  {'name': 'Stand 216B Delta Suite', 'Average raiting': 6.0},
#  {'name': 'Picket Fence', 'Average raiting': 15.0},
#  {'name': 'The Ambassador Grill And Lounge', 'Average raiting': 12.25},
#  {'name': 'G.P. Diner', 'Average raiting': 11.0},
#  {'name': 'The One', 'Average raiting': 12.0},
#  {'name': 'Hom', 'Average raiting': 7.5},
#  {'name': 'The Usual Restaurant', 'Average raiting': 11.25},
#  {'name': 'Pier 79/Ny Waterway Seattle Cafe', 'Average raiting': 12.67},
#  {'name': 'Sips & Bites', 'Average raiting': 11.8},
#  {'name': '940 Flushing Lounge/Arancini Bros', 'Average raiting': 18.25},
#  {'name': 'Roebling Sporting Club', 'Average raiting': 10.2},
#  {'name': 'Between The Bun', 'Average raiting': 7.5},
#  {'name': 'Colors Restaurant', 'Average raiting': 20.0},
#  {'name': 'Wei West/Beans & Greens', 'Average raiting': 7.67},
#  {'name': 'Chicken House', 'Average raiting': 8.25},
#  {'name': 'Pure Bistro', 'Average raiting': 9.5},
#  {'name': 'Circle Of Fun', 'Average raiting': 11.6},
#  {'name': 'Rego Bagel', 'Average raiting': 13.67},
#  {'name': 'City Gourmet', 'Average raiting': 12.67},
#  {'name': 'Riverdale Yacht Club', 'Average raiting': 12.0},
#  {'name': 'Inwood Local Wine Bar & Beer Garden', 'Average raiting': 11.4},
#  {'name': 'Tri Tip Grill', 'Average raiting': 9.4},
#  {'name': 'Blue Bottle Coffee', 'Average raiting': 9.0},
#  {'name': 'Cafe Hestia', 'Average raiting': 12.0},
#  {'name': 'Calexico', 'Average raiting': 9.4},
#  {'name': '16 Handles Frozen Yogurt', 'Average raiting': 8.33},
#  {'name': 'Elan', 'Average raiting': 13.0},
#  {'name': 'Bergen Beach Cafe', 'Average raiting': 12.0},
#  {'name': "Hunter'S", 'Average raiting': 11.0},
#  {'name': "Gracie'S Corner Coffee Shop", 'Average raiting': 7.0},
#  {'name': 'Urbo', 'Average raiting': 7.0},
#  {'name': 'Clock Work', 'Average raiting': 13.8},
#  {'name': 'Nyu Sidestein Market', 'Average raiting': 2.0},
#  {'name': "The Johnson'S", 'Average raiting': 8.0},
#  {'name': 'Soul Of The Sea', 'Average raiting': 10.0},
#  {'name': 'Google-Truck Pit', 'Average raiting': 5.25},
#  {'name': 'Jou Jou Cafe', 'Average raiting': 6.25},
#  {'name': 'American Airlines Admirals Club', 'Average raiting': 15.0},
#  {'name': 'Sustainable Nyc', 'Average raiting': 3.5},
#  {'name': 'Tim Hortons & Cold Stoms Creamery', 'Average raiting': 4.0},
#  {'name': 'Crown Fried Chicken', 'Average raiting': 9.0},
#  {'name': 'Stands 303 And 301 Pepsi Porch', 'Average raiting': 7.67},
#  {'name': 'Bushwick Country Club', 'Average raiting': 11.8},
#  {'name': '241St Cafe Restaurant', 'Average raiting': 10.0},
#  {'name': 'Met Life', 'Average raiting': 8.0},
#  {'name': 'Bar Pelham', 'Average raiting': 7.0},
#  {'name': 'Blue Hill Restaurant', 'Average raiting': 7.75},
#  {'name': 'The Sackett', 'Average raiting': 7.0},
#  {'name': 'The Leadbelly', 'Average raiting': 15.25},
#  {'name': 'Metropolitan Museum Of Art', 'Average raiting': 11.75},
#  {'name': 'Ifc Center', 'Average raiting': 10.67},
#  {'name': 'Manhattan Brew House', 'Average raiting': 13.33},
#  {'name': "Londel'S Supper Club", 'Average raiting': 11.8},
#  {'name': 'City Tech Cafe', 'Average raiting': 6.33},
#  {'name': 'Kennedy Fried Chicken & Pizza', 'Average raiting': 10.0},
#  {'name': 'Nomura Cafeteria( 25 Th Floor)', 'Average raiting': 9.5},
#  {'name': 'Green City Lounge', 'Average raiting': 14.5},
#  {'name': 'Subway', 'Average raiting': 10.5},
#  {'name': 'Vanga', 'Average raiting': 10.0},
#  {'name': 'Cue Bar', 'Average raiting': 13.6},
#  {'name': 'Strong Place', 'Average raiting': 10.75},
#  {'name': 'Fairfield Inn B', 'Average raiting': 10.0},
#  {'name': 'The Sandwich Bar', 'Average raiting': 11.5},
#  {'name': 'Canteen', 'Average raiting': 8.75},
#  {'name': 'Pret A Manger', 'Average raiting': 8.5},
#  {'name': 'Antler Beer & Wine Dispensary', 'Average raiting': 19.0},
#  {'name': 'Nourish Kitchen + Table', 'Average raiting': 10.5},
#  {'name': 'Good Dish Cafe', 'Average raiting': 8.8},
#  {'name': 'Lavender Lake', 'Average raiting': 18.0},
#  {'name': 'Super Tiger Deli', 'Average raiting': 14.5},
#  {'name': 'Berry Park', 'Average raiting': 10.4},
#  {'name': "Flb'S Pub", 'Average raiting': 4.0},
#  {'name': "Erv'S", 'Average raiting': 11.0},
#  {'name': 'Epazote', 'Average raiting': 12.75},
#  {'name': 'Island Coffee Shop', 'Average raiting': 11.8},
#  {'name': "Lucy'S Whey", 'Average raiting': 8.5},
#  {'name': 'The National', 'Average raiting': 12.25},
#  {'name': 'Xes Lounge', 'Average raiting': 8.2},
#  {'name': 'Delish By Amerivents', 'Average raiting': 6.0},
#  {'name': 'Kingsland', 'Average raiting': 14.0},
#  {'name': 'Cafe 101', 'Average raiting': 4.5},
#  {'name': 'Maggie Brown', 'Average raiting': 13.0},
#  {'name': 'Viand Cafe', 'Average raiting': 16.4},
#  {'name': 'Cafeteria (Usps Bldng)', 'Average raiting': 24.6},
#  {'name': 'Left Field Concession Stand', 'Average raiting': 9.33},
#  {'name': 'Manhem Club', 'Average raiting': 7.5},
#  {'name': "Flannery'S Bar", 'Average raiting': 9.0},
#  {'name': 'Toasties', 'Average raiting': 11.0},
#  {'name': 'Crown Gourmet Deli', 'Average raiting': 11.57},
#  {'name': 'Habana Outpost', 'Average raiting': 13.0},
#  {'name': "Applebee'S Neighborhood Grill & Bar", 'Average raiting': 7.5},
#  {'name': 'Tir Na Nog', 'Average raiting': 8.83},
#  {'name': 'Franklin Hotel', 'Average raiting': 9.25},
#  {'name': "Mom'S Cooking", 'Average raiting': 9.0},
#  {'name': 'Studio 54 (Theatre)', 'Average raiting': 2.0},
#  {'name': 'Felice', 'Average raiting': 10.0},
#  {'name': 'Daily Burger ( 10Th Floor)', 'Average raiting': 0.0},
#  {'name': 'D Elici', 'Average raiting': 8.0},
#  {'name': 'Fantasia & Perfection', 'Average raiting': 10.5},
#  {'name': 'Academy Restauraunt', 'Average raiting': 17.6},
#  {'name': 'Forty Eight Lounge', 'Average raiting': 2.8},
#  {'name': 'Dreamers Coffee Shop', 'Average raiting': 8.5},
#  {'name': "Ludwig'S At The Yacht Club", 'Average raiting': 3.0},
#  {'name': 'Bloomberg 731 Lex', 'Average raiting': 10.0},
#  {'name': 'Vino 313', 'Average raiting': 10.75},
#  {'name': "Ellen'S Stardust Diner", 'Average raiting': 10.0},
#  {'name': 'Crystal Lounge', 'Average raiting': 16.0},
#  {'name': "Gleason'S", 'Average raiting': 18.4},
#  {'name': 'Mmm...Thats A Wrap', 'Average raiting': 9.6},
#  {'name': 'Chadbourne & Parke', 'Average raiting': 10.0},
#  {'name': "''W'' Cafe", 'Average raiting': 43.0},
#  {'name': "Whitman'S", 'Average raiting': 12.67},
#  {'name': 'Simple Pleasures Caf', 'Average raiting': 4.0},
#  {'name': 'Jays Restaurant', 'Average raiting': 8.5},
#  {'name': 'Events At Stone Park', 'Average raiting': 8.0},
#  {'name': 'Crown Victoria Bar', 'Average raiting': 10.5},
#  {'name': 'Rockway Beach Club', 'Average raiting': 17.0},
#  {'name': 'Court Order', 'Average raiting': 9.6},
#  {'name': 'Liberty Events Lcc', 'Average raiting': 7.5},
#  {'name': "Sarabeth'S Kitchen", 'Average raiting': 11.0},
#  {'name': 'Yellow Hook Grille', 'Average raiting': 14.5},
#  {'name': 'Astra', 'Average raiting': 10.75},
#  {'name': 'Terminal Cafe/Yankee Clipper', 'Average raiting': 15.0},
#  {'name': 'Red Eye Grill', 'Average raiting': 8.5},
#  {'name': "Bobby Van'S Grill", 'Average raiting': 13.0},
#  {'name': 'Taszo Coffee', 'Average raiting': 8.5},
#  {'name': 'The Ginger Man', 'Average raiting': 7.25},
#  {'name': 'Bullpen Deli Twin Donuts', 'Average raiting': 7.0},
#  {'name': 'Tal Bagels', 'Average raiting': 8.67},
#  {'name': 'Bay Ridge Manor Catering', 'Average raiting': 10.8},
#  {'name': 'Reade Street Pub & Kitchen', 'Average raiting': 10.75},
#  {'name': 'Au Bon Pain', 'Average raiting': 7.4},
#  {'name': "Stella'S Coffee Shop", 'Average raiting': 11.5},
#  {'name': 'Simply Food', 'Average raiting': 6.0},
#  {'name': 'The Lexington Hotel New York', 'Average raiting': 6.75},
#  {'name': 'Beach Street Eatery', 'Average raiting': 24.0},
#  {'name': 'Continental', 'Average raiting': 12.4},
#  {'name': '525 Lex Restaurant & Bar', 'Average raiting': 20.83},
#  {'name': 'American Museum Of Natural History Food Court',
#   'Average raiting': 10.4},
#  {'name': 'Studio Square Event Hall', 'Average raiting': 8.67},
#  {'name': "Uncle Jimmy'S Backyard Bbq", 'Average raiting': 15.0},
#  {'name': 'Soho Cafe And Grill', 'Average raiting': 8.5},
#  {'name': 'Marshall Stack', 'Average raiting': 11.75},
#  {'name': 'Beer Authority', 'Average raiting': 17.2},
#  {'name': 'Marche Madison', 'Average raiting': 11.6},
#  {'name': 'Pee Dee', 'Average raiting': 14.2},
#  {'name': 'Balli Deli & Salad Bar', 'Average raiting': 8.75},
#  {'name': 'Aloft Harlem Wxyz Refuel', 'Average raiting': 8.67},
#  {'name': 'Dtut', 'Average raiting': 16.0},
#  {'name': 'Short Right Field Concession Stand', 'Average raiting': 3.5},
#  {'name': 'The Canal Park Playhouse, Inc', 'Average raiting': 7.5},
#  {'name': 'Ale House City Island', 'Average raiting': 16.25},
#  {'name': 'Xixa', 'Average raiting': 9.0},
#  {'name': 'Hooters Of Fresh Meadows', 'Average raiting': 12.0},
#  {'name': 'Pig & Whistle', 'Average raiting': 7.0},
#  {'name': 'Hellgate On The Park', 'Average raiting': 10.5},
#  {'name': "Gracie'S On 2Nd", 'Average raiting': 10.0},
#  {'name': 'Bloomberg', 'Average raiting': 2.5},
#  {'name': 'The New York Palace Hotel (4Th Floor Kitchen)',
#   'Average raiting': 11.0},
#  {'name': "Zafi'S Luncheonette", 'Average raiting': 6.8},
#  {'name': 'Underground Lounge', 'Average raiting': 16.75},
#  {'name': 'Camilles', 'Average raiting': 12.0},
#  {'name': 'Beacon Theatre', 'Average raiting': 1.0},
#  {'name': "My Belly'S Playlist", 'Average raiting': 9.0},
#  {'name': 'Cafe Pedlar', 'Average raiting': 9.25},
#  {'name': 'El Colmado', 'Average raiting': 12.0},
#  {'name': 'Brooklyn Mac', 'Average raiting': 5.25},
#  {'name': 'The Monarch Room', 'Average raiting': 7.0},
#  {'name': 'D-Lite Donuts', 'Average raiting': 11.0},
#  {'name': 'Spirit Of New York', 'Average raiting': 12.75},
#  {'name': 'Uglyducking', 'Average raiting': 10.0},
#  {'name': 'Blue Ribbon Bar', 'Average raiting': 2.75},
#  {'name': 'Healthy Bite', 'Average raiting': 26.0},
#  {'name': 'Fried Frank Cafeteria', 'Average raiting': 6.75},
#  {'name': 'White Horse Tavern', 'Average raiting': 4.4},
#  {'name': 'Black Mountain', 'Average raiting': 9.2},
#  {'name': 'Costco Wholesale', 'Average raiting': 8.25},
#  {'name': 'Bar 131', 'Average raiting': 9.0},
#  {'name': 'Rock Center Cafe', 'Average raiting': 10.75},
#  {'name': 'Zablozkis', 'Average raiting': 7.17},
#  {'name': 'Gracie-Mews Restaurant', 'Average raiting': 12.5},
#  {'name': 'Tasty Fried Chicken', 'Average raiting': 7.0},
#  {'name': "Mike'S Coffee Shop", 'Average raiting': 9.75},
#  {'name': 'Darkhorse', 'Average raiting': 13.0},
#  {'name': 'Perilla', 'Average raiting': 9.0},
#  {'name': 'Bisoux Market/World Bean', 'Average raiting': 6.5},
#  {'name': 'El Patron Nightclub Cabaret-Restaurant', 'Average raiting': 8.5},
#  {'name': 'Jg Melon Restaurant', 'Average raiting': 13.75},
#  {'name': 'Westside Brewhouse', 'Average raiting': 10.4},
#  {'name': 'Serai', 'Average raiting': 2.25},
#  {'name': 'Pit Stop Bar', 'Average raiting': 4.67},
#  {'name': 'Bella Giornata', 'Average raiting': 10.67},
#  {'name': 'Blackthorn 51', 'Average raiting': 6.0},
#  {'name': 'Tko Chicken & Ribs', 'Average raiting': 9.33},
#  {'name': 'The Movable Feast', 'Average raiting': 9.25},
#  {'name': 'Scores', 'Average raiting': 9.75},
#  {'name': 'Kentucky Fried Chicken', 'Average raiting': 2.0},
#  {'name': "B.B'S Pub And Grill", 'Average raiting': 9.33},
#  {'name': 'Gossips', 'Average raiting': 10.0},
#  {'name': 'Bisoux Restaurant', 'Average raiting': 11.0},
#  {'name': 'Concrete Restaurant', 'Average raiting': 34.75},
#  {'name': 'Hilton Garden Inn New York/Times Square Central',
#   'Average raiting': 2.0},
#  {'name': 'Pair Wine And Cheese', 'Average raiting': 15.0},
#  {'name': 'Union Pool', 'Average raiting': 14.5},
#  {'name': 'Moca Bar & Lounge', 'Average raiting': 13.5},
#  {'name': 'East 86 Cinemas', 'Average raiting': 8.67},
#  {'name': 'Stop Inn Restaurant & Cafe', 'Average raiting': 9.67},
#  {'name': "T.G.I. Friday'S", 'Average raiting': 11.17},
#  {'name': 'Soho Grand Hotel', 'Average raiting': 11.0},
#  {'name': "Applebee'S Neighborhood Grill & Bar", 'Average raiting': 7.25},
#  {'name': 'Flavors', 'Average raiting': 9.25},
#  {'name': '1001 Nights Cafe', 'Average raiting': 12.5},
#  {'name': "Rab'S Country Lane", 'Average raiting': 9.0},
#  {'name': 'Bistro Caterers', 'Average raiting': 10.0},
#  {'name': 'The Big Apple (Ritz Carlton Hotel Employee Cafeteria)',
#   'Average raiting': 9.33},
#  {'name': 'Robert Mondavi Winery', 'Average raiting': 9.0},
#  {'name': 'Oakland Cafeteria/Queensborough Community College',
#   'Average raiting': 11.75},
#  {'name': 'Cravath Cafe', 'Average raiting': 8.25},
#  {'name': 'Paradise Alley Bar', 'Average raiting': 9.8},
#  {'name': 'Central Diner', 'Average raiting': 8.0},
#  {'name': 'Kentucky Fried Chicken', 'Average raiting': 5.75},
#  {'name': 'The Wheelhouse', 'Average raiting': 7.0},
#  {'name': 'Food For Thought Catered Events', 'Average raiting': 12.14},
#  {'name': 'Arrow', 'Average raiting': 13.6},
#  {'name': 'Feel Food', 'Average raiting': 0.0},
#  {'name': 'Fuel Energy Grill', 'Average raiting': 10.43},
#  {'name': 'Bowery Meat Company', 'Average raiting': 34.0},
#  {'name': 'Stand 324', 'Average raiting': 7.5},
#  {'name': 'Joseph Leonard', 'Average raiting': 13.2},
#  {'name': 'Industry', 'Average raiting': 9.0},
#  {'name': "John John'S Bar & Grill", 'Average raiting': 12.67},
#  {'name': 'Roxy Diner', 'Average raiting': 18.0},
#  {'name': 'Boss Bar & Lounge', 'Average raiting': 8.67},
#  {'name': "Tom'S Restaurant", 'Average raiting': 9.67},
#  {'name': 'Ted & Honey', 'Average raiting': 16.6},
#  {'name': "Mcdonald'S", 'Average raiting': 13.0},
#  {'name': 'The Shadow Boxers', 'Average raiting': 11.0},
#  {'name': 'Global Kitchen', 'Average raiting': 23.0},
#  {'name': 'Smithfield Hall', 'Average raiting': 4.0},
#  {'name': "A.R'S Tavern", 'Average raiting': 9.75},
#  {'name': 'H & R Gourmet Deli & Grocery', 'Average raiting': 12.0},
#  {'name': 'Barleycorn', 'Average raiting': 23.0},
#  {'name': 'The Sweet Shop Nyc', 'Average raiting': 2.0},
#  {'name': 'The Ridge Bar And Grill', 'Average raiting': 4.0},
#  {'name': 'Comfort Inn', 'Average raiting': 6.0},
#  {'name': 'The Shanty', 'Average raiting': 5.0},
#  {'name': 'Kennedy Fried Chicken', 'Average raiting': 15.5},
#  {'name': 'Ing Forman Selz', 'Average raiting': 7.5},
#  {'name': 'C & C Italian Deli', 'Average raiting': 11.2},
#  {'name': "Cassidy'S Ale House", 'Average raiting': 12.0},
#  {'name': 'Keuka Kafe', 'Average raiting': 9.67},
#  {'name': 'Joes Coffee Shop', 'Average raiting': 8.0},
#  {'name': 'Morrell Wine Bar & Cafe', 'Average raiting': 8.5},
#  {'name': 'Pyramids Hookah And Bar', 'Average raiting': 19.0},
#  {'name': 'Ruddy And Dean', 'Average raiting': 9.25},
#  {'name': 'Johnny Utahs', 'Average raiting': 18.0},
#  {'name': 'Sycamore', 'Average raiting': 9.75},
#  {'name': 'Smith Tavern', 'Average raiting': 8.2},
#  {'name': 'Americas Burger And Wraps', 'Average raiting': 11.0},
#  {'name': 'The Jeffrey', 'Average raiting': 24.0},
#  {'name': 'Comfort Inn & Suites', 'Average raiting': 12.25},
#  {'name': "Finnegan'S Wake", 'Average raiting': 9.25},
#  {'name': 'Amsterdam Ale House', 'Average raiting': 25.5},
#  {'name': 'Ainsworth Park', 'Average raiting': 14.5},
#  {'name': 'Rpm', 'Average raiting': 10.0},
#  {'name': 'The Three Monkeys', 'Average raiting': 7.5},
#  {'name': 'Silver Lounge', 'Average raiting': 10.0},
#  {'name': 'Tooker Alley', 'Average raiting': 12.5},
#  {'name': 'Concorde Room', 'Average raiting': 5.75},
#  {'name': 'Adventures Amusement Park', 'Average raiting': 9.0},
#  {'name': 'Stand 435', 'Average raiting': 5.33},
#  {'name': 'Subway', 'Average raiting': 8.0},
#  {'name': "Logan'S Cafe", 'Average raiting': 12.0},
#  {'name': 'Bull Head Tavern', 'Average raiting': 5.8},
#  {'name': 'Little Collins', 'Average raiting': 9.5},
#  {'name': 'Uptown Brasserie', 'Average raiting': 11.67},
#  {'name': 'Nix Mix', 'Average raiting': 13.0},
#  {'name': 'Blenheim', 'Average raiting': 14.4},
#  {'name': 'Mullanes Bar & Grill', 'Average raiting': 9.0},
#  {'name': 'Baba Cool', 'Average raiting': 16.0},
#  {'name': "Mother'S", 'Average raiting': 15.0},
#  {'name': 'South Shore Little League Concesion Stand',
#   'Average raiting': 8.25},
#  {'name': 'Sky Room', 'Average raiting': 17.6},
#  {'name': 'Grey Bar & Restaurant', 'Average raiting': 7.0},
#  {'name': 'Blue Magic Lounge', 'Average raiting': 7.0},
#  {'name': 'The Palm', 'Average raiting': 20.33},
#  {'name': 'Chicken & Fries ( 10Th Floor)', 'Average raiting': 0.0},
#  {'name': 'Frere De Lys', 'Average raiting': 16.0},
#  {'name': 'Danny Supper Club', 'Average raiting': 6.0},
#  {'name': "44 & X Hell'S Kitchen", 'Average raiting': 9.5},
#  {'name': 'The Friedman Theatre', 'Average raiting': 10.75},
#  {'name': 'Mcdonalds', 'Average raiting': 6.0},
#  {'name': 'Playwrights Horizons', 'Average raiting': 6.25},
#  {'name': 'Cafe Forte', 'Average raiting': 8.0},
#  {'name': 'Dunkin Donuts', 'Average raiting': 12.0},
#  {'name': "Monique'S Lounge 108", 'Average raiting': 15.5},
#  {'name': 'Noshborough', 'Average raiting': 7.0},
#  {'name': 'Pizza Bagel Burger', 'Average raiting': 15.2},
#  {'name': 'Doo Wop Griddle', 'Average raiting': 10.0},
#  {'name': 'Maoz Vegetarian', 'Average raiting': 10.4},
#  {'name': 'Von', 'Average raiting': 12.25},
#  {'name': 'Laguardia Courtyard Hotel By Marriott', 'Average raiting': 16.0},
#  {'name': 'Feile', 'Average raiting': 11.75},
#  {'name': 'Kentucky Fried Chicken', 'Average raiting': 10.5},
#  {'name': "Berg'N Beer Hall", 'Average raiting': 9.0},
#  {'name': 'Soho Cafe', 'Average raiting': 10.75},
#  {'name': 'Bagel Time', 'Average raiting': 23.0},
#  {'name': 'Gigi Cafe', 'Average raiting': 8.5},
#  {'name': 'The Slaughtered Lamb', 'Average raiting': 8.0},
#  {'name': 'Back Forty', 'Average raiting': 14.25},
#  {'name': "Rusty'S Bar", 'Average raiting': 14.0},
#  {'name': 'Pop@Pod', 'Average raiting': 10.0},
#  {'name': 'Lydig Coffee Shop', 'Average raiting': 9.0},
#  {'name': 'Rich Lane', 'Average raiting': 8.0},
#  {'name': 'Days Inn', 'Average raiting': 7.0},
#  {'name': 'Dessert Palace', 'Average raiting': 13.0},
#  {'name': 'Seasons Restaurant', 'Average raiting': 12.25},
#  {'name': 'Rocco Pizza Iii', 'Average raiting': 9.33},
#  {'name': 'Tandem', 'Average raiting': 8.6},
#  {'name': 'Q Train Deli', 'Average raiting': 6.33},
#  {'name': 'The Roosevelt Hotel', 'Average raiting': 22.17},
#  {'name': 'The Cherry Tree Bar/ South Brooklyn Pizza',
#   'Average raiting': 15.17},
#  {'name': 'Convene At 32 Old Slip', 'Average raiting': 6.0},
#  {'name': 'Regency Whist Club', 'Average raiting': 12.0},
#  {'name': 'Lucky Pizzeria & Cafe', 'Average raiting': 10.0},
#  {'name': 'C & B Luncheonette', 'Average raiting': 9.8},
#  {'name': 'Checkers', 'Average raiting': 2.0},
#  {'name': "Mrs. Dorsey'S Kitchen", 'Average raiting': 4.0},
#  {'name': 'Maloney & Porcelli', 'Average raiting': 10.0},
#  {'name': "Paddy G'S", 'Average raiting': 8.0},
#  {'name': 'Roebling Tea Room', 'Average raiting': 11.4},
#  {'name': "Applebee'S Neighborhood Grill & Bar", 'Average raiting': 9.33},
#  {'name': 'Dig Inn', 'Average raiting': 9.75},
#  {'name': "Kelly'S Pub", 'Average raiting': 11.0},
#  {'name': 'Cafe Tallulah', 'Average raiting': 11.25},
#  {'name': 'Clifford Chance Cafeteria', 'Average raiting': 7.0},
#  {'name': 'Two-Bits Retro Arcade', 'Average raiting': 17.0},
#  {'name': 'Cypress Inn Cafe', 'Average raiting': 3.5},
#  {'name': 'Excelsior Catering', 'Average raiting': 8.0},
#  {'name': 'Fresh Pond Tavern', 'Average raiting': 6.5},
#  {'name': 'Lyric Theatre', 'Average raiting': 11.0},
#  {'name': 'Quality Cafe & Restaurant', 'Average raiting': 16.67},
#  {'name': 'Jp Morgan Chase Bank Cafeteria', 'Average raiting': 10.75},
#  {'name': 'Taco Bell, Au Bon Pain', 'Average raiting': 10.0},
#  {'name': 'H.Q. Lounge', 'Average raiting': 19.6},
#  {'name': 'Burger King', 'Average raiting': 7.67},
#  {'name': "O'Keefes Bar & Grill", 'Average raiting': 9.2},
#  {'name': 'Home Sweet Harlem', 'Average raiting': 7.0},
#  {'name': 'Nicotra Ballroom // Employee Cafeteria', 'Average raiting': 9.75},
#  {'name': 'Bay Street Luncheonette & Soda Fountain', 'Average raiting': 9.25},
#  {'name': 'The Lutheran Halal Cafe', 'Average raiting': 15.0},
#  {'name': 'Ave Coffee House', 'Average raiting': 15.8},
#  {'name': 'Village 38', 'Average raiting': 10.5},
#  {'name': 'American Cheez', 'Average raiting': 7.0},
#  {'name': 'Ge Financial Cafe', 'Average raiting': 6.5},
#  {'name': 'Kennedy Fried Chicken', 'Average raiting': 9.4},
#  {'name': "Mcdonald'S", 'Average raiting': 3.6},
#  {'name': 'Bell Diner', 'Average raiting': 11.83},
#  {'name': 'Cafe Express', 'Average raiting': 8.33},
#  {'name': 'Concessions Stand Gac', 'Average raiting': 5.5},
#  {'name': 'Bond Street Chocolate', 'Average raiting': 5.33},
#  {'name': 'Dock Street Bar & Grill', 'Average raiting': 18.4},
#  {'name': 'The Grand Prospect Hall', 'Average raiting': 12.0},
#  {'name': 'Summer Garden', 'Average raiting': 10.0},
#  {'name': 'The Emerson', 'Average raiting': 5.2},
#  {'name': 'Hudson Station', 'Average raiting': 9.57},
#  {'name': 'Crown Fried Chicken', 'Average raiting': 12.33},
#  {'name': "Circle'S Grill", 'Average raiting': 10.33},
#  {'name': 'Shapeshifter Lab', 'Average raiting': 10.0},
#  {'name': 'The Sea Fire Grill', 'Average raiting': 15.0},
#  {'name': 'Equinox', 'Average raiting': 10.2},
#  {'name': "Glady'S", 'Average raiting': 10.5},
#  {'name': 'Flatiron Hall', 'Average raiting': 7.0},
#  {'name': 'The Mug Cafe', 'Average raiting': 11.5},
#  {'name': 'Lucky 13 Saloon', 'Average raiting': 31.0},
#  {'name': 'The Roof', 'Average raiting': 13.0},
#  {'name': 'Circle Line Xii', 'Average raiting': 11.0},
#  {'name': '7B Bar', 'Average raiting': 13.2},
#  {'name': "Karl'S Klipper", 'Average raiting': 16.67},
#  {'name': 'Macmenamins Nyc Hells Kitchen', 'Average raiting': 12.75},
#  {'name': 'Perfecto Pizza & Coffee Shop', 'Average raiting': 10.67},
#  {'name': 'Parish', 'Average raiting': 10.0},
#  {'name': 'Reviver', 'Average raiting': 9.0},
#  {'name': "Westin Hotel Shula'S Steak And Bar 10", 'Average raiting': 12.0},
#  {'name': 'The Winslow', 'Average raiting': 4.0},
#  {'name': "Ashby'S Specialty", 'Average raiting': 10.0},
#  {'name': 'Perdition', 'Average raiting': 11.8},
#  {'name': 'Alphabet Lounge', 'Average raiting': 11.6},
#  {'name': 'Ranch One', 'Average raiting': 12.0},
#  {'name': 'Dunkin Donuts', 'Average raiting': 6.25},
#  {'name': 'Nyu - Torch Club', 'Average raiting': 11.0},
#  {'name': 'Hanson Restaurant And Pizzeria', 'Average raiting': 10.5},
#  {'name': '10Th Avenue Cookshop', 'Average raiting': 13.8},
#  {'name': "Kid'S Funhouse", 'Average raiting': 7.25},
#  {'name': 'Lea Wine Bar', 'Average raiting': 7.0},
#  {'name': 'Allerton Diner', 'Average raiting': 14.5},
#  {'name': 'Cafe Frederick Harlem Parlor', 'Average raiting': 23.0},
#  {'name': 'Penelope', 'Average raiting': 9.14},
#  {'name': "Duke'S", 'Average raiting': 9.8},
#  {'name': 'Runner & Stone', 'Average raiting': 7.67},
#  {'name': 'Blk Mkt', 'Average raiting': 15.0},
#  {'name': 'Kwik Stop Cafe', 'Average raiting': 16.33},
#  {'name': 'Sankeys Nyc', 'Average raiting': 7.0},
#  {'name': 'Lucky Deli', 'Average raiting': 8.8},
#  {'name': 'Green Cafe', 'Average raiting': 10.8},
#  {'name': 'Chickpea', 'Average raiting': 12.0},
#  {'name': 'Taperia', 'Average raiting': 8.0},
#  {'name': 'Devon & Blakely', 'Average raiting': 11.0},
#  {'name': 'Westside Theatre', 'Average raiting': 6.0},
#  {'name': "T.G.I. Friday'S", 'Average raiting': 6.67},
#  {'name': 'View Of The World Terrace Club', 'Average raiting': 12.6},
#  {'name': 'My Cooking Party', 'Average raiting': 8.0},
#  {'name': 'Elizabeths Neighborhood Table', 'Average raiting': 7.5},
#  {'name': 'Evolve', 'Average raiting': 14.17},
#  {'name': "Mario'S Snack Shop", 'Average raiting': 8.0},
#  {'name': 'Legendary Bar & Restaurant', 'Average raiting': 12.17},
#  {'name': 'Essen', 'Average raiting': 10.6},
#  {'name': 'Larchmont Hotel', 'Average raiting': 9.4},
#  {'name': 'Greenpoint Tavern', 'Average raiting': 12.0},
#  {'name': 'Glaze', 'Average raiting': 8.5},
#  {'name': 'Colgate Palmolive', 'Average raiting': 20.4},
#  {'name': 'Press 195', 'Average raiting': 11.0},
#  {'name': 'Spritzenhaus', 'Average raiting': 14.75},
#  {'name': "Denny'S", 'Average raiting': 10.0},
#  {'name': 'The Half King', 'Average raiting': 9.25},
#  {'name': 'Niles Restaurant', 'Average raiting': 9.2},
#  {'name': 'Fruitilicious Caffe And Grocery', 'Average raiting': 5.0},
#  {'name': "Nelly'S Corner Pizzeria Restaurant", 'Average raiting': 10.67},
#  {'name': 'Vip Club', 'Average raiting': 13.8},
#  {'name': 'Bar Chord', 'Average raiting': 10.5},
#  {'name': "Lenihan'S Saloon", 'Average raiting': 15.4},
#  {'name': 'Green Cafe', 'Average raiting': 10.33},
#  {'name': 'Chelsea Papaya', 'Average raiting': 6.6},
#  {'name': 'Glorietta Baldy', 'Average raiting': 11.0},
#  {'name': 'Sparta Deli And Restuarant', 'Average raiting': 13.33},
#  {'name': "Dizzy'S On 5Th", 'Average raiting': 14.0},
#  {'name': "Mckenna'S Pub", 'Average raiting': 10.6},
#  {'name': "Ashton'S Alley", 'Average raiting': 8.33},
#  {'name': 'Hells Kitchen Cafe/Hk Lounge', 'Average raiting': 18.33},
#  {'name': 'Bread Market Cafe', 'Average raiting': 10.0},
#  {'name': 'Littlefield', 'Average raiting': 11.25},
#  {'name': 'Virgin Atlantic Club House', 'Average raiting': 8.25},
#  {'name': "Vicky'S", 'Average raiting': 10.33},
#  {'name': 'Tracks Raw Bar & Grill', 'Average raiting': 9.5},
#  {'name': 'Dram', 'Average raiting': 11.75},
#  {'name': 'Cappuccino Cafe', 'Average raiting': 7.8},
#  {'name': 'Dovetail', 'Average raiting': 14.2},
#  {'name': 'Checkers', 'Average raiting': 12.0},
#  {'name': 'Soho Cafe & Grill', 'Average raiting': 9.25},
#  {'name': 'Kennedy Fried Chicken', 'Average raiting': 7.5},
#  {'name': 'Sky Bar & Grill', 'Average raiting': 3.0},
#  {'name': 'Eleven Madison Park', 'Average raiting': 10.0},
#  {'name': 'Flight 151', 'Average raiting': 9.2},
#  {'name': 'Chalk Point Kitchen', 'Average raiting': 9.0},
#  {'name': 'Kitchenette Uptown', 'Average raiting': 10.25},
#  {'name': 'Soho Bistro', 'Average raiting': 13.6},
#  {'name': 'Concession # 120/ The Bullpen', 'Average raiting': 3.0},
#  {'name': 'Marm Cafe', 'Average raiting': 12.0},
#  {'name': 'Between The Bread', 'Average raiting': 11.5},
#  {'name': 'Mercy College', 'Average raiting': 16.33},
#  {'name': "Daddy'S Cafe", 'Average raiting': 8.6},
#  {'name': 'Desmonds Steakhouse And Grill', 'Average raiting': 21.5},
#  {'name': 'Cocoa Bar', 'Average raiting': 12.0},
#  {'name': 'The Spot', 'Average raiting': 13.17},
#  {'name': "Tower'S Cafe", 'Average raiting': 14.33},
#  {'name': "Mcdonald'S", 'Average raiting': 5.75},
#  {'name': 'Olmsted Cafeteria', 'Average raiting': 9.4},
#  {'name': 'The Lambs Club -- Banquet Kitchen', 'Average raiting': 7.75},
#  {'name': 'Smokeshack', 'Average raiting': 5.5},
#  {'name': 'Citigroup Executive Dining Room', 'Average raiting': 8.0},
#  {'name': 'Popeyes Chicken & Biscuits', 'Average raiting': 5.67},
#  {'name': "Michael'S", 'Average raiting': 12.8},
#  {'name': 'Coco 66', 'Average raiting': 12.0},
#  {'name': 'Wahi Diner', 'Average raiting': 9.0},
#  {'name': 'Chartwells At College Of Mount St. Vincent-Benedict',
#   'Average raiting': 3.25},
#  {'name': 'Court Square Diner', 'Average raiting': 11.14},
#  {'name': '876 Market Deli', 'Average raiting': 8.2},
#  {'name': 'Five Guys Burgers And Fries', 'Average raiting': 8.25},
#  {'name': 'Crown Fried Chicken', 'Average raiting': 16.0},
#  {'name': "Wendy'S", 'Average raiting': 6.0},
#  {'name': 'Rippers', 'Average raiting': 9.67},
#  {'name': 'Key Bar', 'Average raiting': 13.83},
#  {'name': "Tutu'S", 'Average raiting': 10.0},
#  {'name': 'Esquire Diner', 'Average raiting': 9.6},
#  {'name': 'Diamond Club', 'Average raiting': 10.0},
#  {'name': 'The Bowery Diner', 'Average raiting': 11.8},
#  {'name': 'Mooks', 'Average raiting': 10.0},
#  {'name': 'Brass Monkey', 'Average raiting': 10.6},
#  {'name': "Lenny'S", 'Average raiting': 9.33},
#  {'name': "Wendy'S", 'Average raiting': 11.0},
#  {'name': 'Timescare Bar Lounge', 'Average raiting': 19.0},
#  {'name': 'Dorian Cafe', 'Average raiting': 10.17},
#  {'name': 'Lucys', 'Average raiting': 7.6},
#  {'name': 'Smash Burger', 'Average raiting': 9.75},
#  {'name': 'Atrium', 'Average raiting': 9.0},
#  {'name': "Wendy'S", 'Average raiting': 2.0},
#  {'name': 'Chef Driven Market Llc', 'Average raiting': 7.0},
#  {'name': '337 - Burgers & Dogs', 'Average raiting': 7.33},
#  {'name': "Applebee'S Neighborhood Grill & Bar", 'Average raiting': 5.8},
#  {'name': 'Ulysses', 'Average raiting': 10.6},
#  {'name': 'Randalls Island Golf Center', 'Average raiting': 11.0},
#  {'name': 'Emerald Inn', 'Average raiting': 8.5},
#  {'name': 'Yankee Tavern', 'Average raiting': 14.0},
#  {'name': 'Gemini Diner', 'Average raiting': 12.25},
#  {'name': 'Elephant & Castle', 'Average raiting': 12.0},
#  {'name': 'Above Ballroom', 'Average raiting': 5.0},
#  {'name': 'Hanson Gourmet Deli & Cafe', 'Average raiting': 21.5},
#  {'name': 'Press Cafe', 'Average raiting': 12.0},
#  {'name': 'Alobar Restaurant', 'Average raiting': 15.2},
#  {'name': 'Panera Bread', 'Average raiting': 10.25},
#  {'name': 'Blue Parrot Bar', 'Average raiting': 29.0},
#  {'name': 'Diwine', 'Average raiting': 11.0},
#  {'name': "Andrew'S Diner", 'Average raiting': 9.86},
#  {'name': 'Black And White', 'Average raiting': 9.0},
#  {'name': 'Central Station', 'Average raiting': 13.0},
#  {'name': 'The Royal Restaurant', 'Average raiting': 13.6},
#  {'name': 'Concourse Plaza Multiplex Cinemas', 'Average raiting': 9.75},
#  {'name': 'The Michelangelo', 'Average raiting': 11.0},
#  {'name': 'Ma Dukes', 'Average raiting': 11.0},
#  {'name': 'Amc Theatres Fresh Meadows 7', 'Average raiting': 24.83},
#  {'name': 'Liberty Bar', 'Average raiting': 6.0},
#  {'name': "Jimbo'S Hamburger Palace", 'Average raiting': 11.4},
#  {'name': 'Tavern On The Third', 'Average raiting': 14.67},
#  {'name': 'Pax', 'Average raiting': 10.4},
#  {'name': 'Candle Bar', 'Average raiting': 12.83},
#  {'name': "Dunkin' Donuts", 'Average raiting': 8.0},
#  {'name': "T.J.'S Sports Bar", 'Average raiting': 11.5},
#  {'name': 'Grand Cafe (Metropolitan Hospital)', 'Average raiting': 10.0},
#  {'name': 'Water Taxi Beach', 'Average raiting': 8.75},
#  {'name': 'Barnes & Noble Cafe', 'Average raiting': 5.4},
#  {'name': 'Dugout Pub South', 'Average raiting': 10.25},
#  {'name': 'Unique Lounge', 'Average raiting': 11.0},
#  {'name': 'Prb 24-7', 'Average raiting': 17.8},
#  {'name': "Glen Patrick'S Pub", 'Average raiting': 8.0},
#  {'name': "Ritmo'S 60", 'Average raiting': 5.33},
#  {'name': 'Regal Entertainment Group', 'Average raiting': 7.0},
#  {'name': 'Kennedy Fried Chicken', 'Average raiting': 11.33},
#  {'name': 'The Bar Room', 'Average raiting': 5.5},
#  {'name': 'Vinus And Marc', 'Average raiting': 11.5},
#  {'name': "Nathan'S", 'Average raiting': 11.0},
#  {'name': 'Muscle Maker Grill', 'Average raiting': 12.0},
#  {'name': 'United Airlines Red Carpet Club', 'Average raiting': 4.0},
#  {'name': 'The Pulpit Inc', 'Average raiting': 13.0},
#  {'name': 'Aged', 'Average raiting': 10.0},
#  {'name': 'Union Hall', 'Average raiting': 12.75},
#  {'name': 'The Ding Dong Lounge', 'Average raiting': 7.0},
#  {'name': 'Telegraphe Cafe', 'Average raiting': 7.0},
#  {'name': 'Cake Ambiance', 'Average raiting': 12.2},
#  {'name': 'Dish Food & Events', 'Average raiting': 8.67},
#  {'name': 'Punch / Wined Up', 'Average raiting': 13.0},
#  {'name': "Friedman'S Lunch", 'Average raiting': 11.2},
#  {'name': 'Asia Dog', 'Average raiting': 7.17},
#  {'name': 'Tribeca Tavern', 'Average raiting': 13.0},
#  {'name': 'The Cobra Club', 'Average raiting': 12.33},
#  {'name': "Toshi'S Living Room", 'Average raiting': 11.8},
#  {'name': 'Brooklyn Bridge Garden Bar', 'Average raiting': 5.67},
#  {'name': 'Resto', 'Average raiting': 10.2},
#  {'name': "Petey'S Burger", 'Average raiting': 8.0},
#  {'name': "John'S Deli", 'Average raiting': 11.6},
#  {'name': "Back To John'S  Deli", 'Average raiting': 7.5},
#  {'name': 'Nyc Fried Chicken', 'Average raiting': 11.0},
#  {'name': "Buddy'S Wonder Bar", 'Average raiting': 15.25},
#  {'name': 'Wheelers', 'Average raiting': 9.8},
#  {'name': "Mcdonald'S", 'Average raiting': 13.29},
#  {'name': 'St. Balmain', 'Average raiting': 26.5},
#  {'name': 'Tower Cafe', 'Average raiting': 8.75},
#  {'name': 'Jimmy Deli Grill', 'Average raiting': 8.0},
#  {'name': 'Green Pavilion Restaurant & Sports Lounge',
#   'Average raiting': 14.62},
#  {'name': "Caroline'S On Broadway", 'Average raiting': 9.0},
#  {'name': 'Internationalhouse', 'Average raiting': 7.67},
#  {'name': "Gracie'S Cafe", 'Average raiting': 19.6},
#  {'name': 'Mumbles', 'Average raiting': 10.83},
#  {'name': 'Rosens Cafe', 'Average raiting': 8.67},
#  {'name': 'The Penn Club', 'Average raiting': 8.5},
#  {'name': 'Hero Champ', 'Average raiting': 8.0},
#  {'name': 'Main Street Cinema', 'Average raiting': 7.75},
#  {'name': 'Raines Law Room', 'Average raiting': 13.0},
#  {'name': '49 Grove', 'Average raiting': 4.75},
#  {'name': "Lily'S Bar @ Roger Smith Hotel", 'Average raiting': 19.2},
#  {'name': 'Bowler Land', 'Average raiting': 11.0},
#  {'name': 'Lollipops', 'Average raiting': 9.25},
#  {'name': 'Brooklyn Label', 'Average raiting': 14.33},
#  {'name': 'Ceol', 'Average raiting': 17.2},
#  {'name': 'Molly Pitchers Ale House', 'Average raiting': 15.0},
#  {'name': 'Phillip Morris International', 'Average raiting': 10.75},
#  {'name': "S'Mac", 'Average raiting': 9.33},
#  {'name': 'Jack Studios', 'Average raiting': 9.5},
#  {'name': 'Alta', 'Average raiting': 10.6},
#  {'name': 'Atera', 'Average raiting': 19.25},
#  {'name': "Daniela'S Cafe", 'Average raiting': 7.0},
#  {'name': 'Odessa', 'Average raiting': 9.2},
#  {'name': 'Bedford Baking Studio', 'Average raiting': 8.75},
#  {'name': 'Harlow', 'Average raiting': 7.5},
#  {'name': 'Ra @ Barclays', 'Average raiting': 5.0},
#  {'name': 'La Bonbonniere', 'Average raiting': 11.29},
#  {'name': 'Hilton Times Square', 'Average raiting': 11.0},
#  {'name': 'Garrett Popcorn Shops', 'Average raiting': 13.25},
#  {'name': 'Sparkles Bar & Lounge', 'Average raiting': 11.67},
#  {'name': 'East River', 'Average raiting': 9.0},
#  {'name': 'John Jay Dining Hall', 'Average raiting': 11.67},
#  {'name': 'Signature Cafe And Bar', 'Average raiting': 7.25},
#  {'name': 'Blazin Burgers & Rotisserie Chicken', 'Average raiting': 10.0},
#  {'name': "Ellie'S Diner", 'Average raiting': 7.25},
#  {'name': 'Pfizer', 'Average raiting': 12.0},
#  {'name': "Mcdonald'S", 'Average raiting': 9.0},
#  {'name': 'Pennylane Coffee', 'Average raiting': 5.5},
#  {'name': 'Brassierie 1605/Broadway 49 Bar & Lounge (Main Kitchen)',
#   'Average raiting': 11.33},
#  {'name': 'Sweet Spot', 'Average raiting': 4.0},
#  {'name': 'Trump Soho Main Kitchen Cafeteria', 'Average raiting': 11.0},
#  {'name': 'D.B.A', 'Average raiting': 10.0},
#  {'name': 'Criminal Court Bldg Cafeteria', 'Average raiting': 11.25},
#  {'name': 'Old Carriage Inn', 'Average raiting': 11.8},
#  {'name': 'Coyote Ugly', 'Average raiting': 15.5},
#  {'name': 'Trinity Pub', 'Average raiting': 12.5},
#  {'name': 'Hanks Saloon', 'Average raiting': 10.0},
#  {'name': 'The Diner', 'Average raiting': 8.0},
#  {'name': 'Bakeri', 'Average raiting': 14.75},
#  {'name': 'Peculiar Pub', 'Average raiting': 15.0},
#  {'name': 'Trend Diner', 'Average raiting': 24.5},
#  {'name': "Fitzgerald'S Pub", 'Average raiting': 11.4},
#  {'name': "Betty Ann'S Place", 'Average raiting': 10.5},
#  {'name': '777 Theater Bar', 'Average raiting': 4.0},
#  {'name': 'Old Homestead', 'Average raiting': 11.8},
#  {'name': 'Jeromes', 'Average raiting': 12.0},
#  {'name': 'Pickles', 'Average raiting': 10.0},
#  {'name': 'Fraiche Maxx', 'Average raiting': 23.0},
#  {'name': 'Slick Willie', 'Average raiting': 10.0},
#  {'name': 'Brooks Atkinson Theater', 'Average raiting': 8.67},
#  {'name': 'Delicatessen Macbar', 'Average raiting': 11.83},
#  {'name': 'Sea Witch', 'Average raiting': 7.67},
#  {'name': 'M&G Restaurant', 'Average raiting': 11.5},
#  {'name': 'Untamed Sandwiches', 'Average raiting': 10.5},
#  {'name': 'Dig Inn Seasonal Market', 'Average raiting': 12.0},
#  {'name': 'Disney Abc Cafeteria', 'Average raiting': 9.0},
#  {'name': 'Greensquare Tavern', 'Average raiting': 18.33},
#  {'name': "Heidi'S House By The Side Of The Road", 'Average raiting': 7.67},
#  {'name': 'Bridgeview Diner', 'Average raiting': 10.67},
#  {'name': "Just Lorraine'S Place", 'Average raiting': 13.17},
#  {'name': 'Little Caesars', 'Average raiting': 5.25},
#  {'name': 'Davidovich Bakery', 'Average raiting': 9.5},
#  {'name': 'Island Rage', 'Average raiting': 7.5},
#  {'name': "Moody'S Cafeteria", 'Average raiting': 11.17},
#  {'name': 'Wafels & Dinges', 'Average raiting': 12.33},
#  {'name': 'Group M', 'Average raiting': 8.25},
#  {'name': 'Moonstruck East', 'Average raiting': 17.29},
#  {'name': 'Cafe On 5Th/Sterling Affair', 'Average raiting': 9.5},
#  {'name': 'The Gorbals', 'Average raiting': 10.0},
#  {'name': 'Build-A-Bear Workshop Lower Level', 'Average raiting': 11.0},
#  {'name': 'Creative Caterers / Artistry', 'Average raiting': 11.0},
#  {'name': 'Five Guys Burgers And Fries', 'Average raiting': 3.5},
#  {'name': "Li Greci'S Staaten Restaurant", 'Average raiting': 17.0},
#  {'name': 'Willburg Cafe', 'Average raiting': 19.17},
#  {'name': 'Medina Fried Chicken & Indian Cuisine', 'Average raiting': 21.75},
#  {'name': 'Stand 110', 'Average raiting': 4.33},
#  {'name': "Dillinger'S", 'Average raiting': 13.5},
#  {'name': 'Rollin Greens', 'Average raiting': 8.5},
#  {'name': 'The Blvd Restaurant And Lounge', 'Average raiting': 13.0},
#  {'name': "Peter'S Since 1969", 'Average raiting': 14.0},
#  {'name': 'Euro Grill & Salad Bar', 'Average raiting': 12.25},
#  {'name': 'Dunkin Donuts & Baskin Robbins', 'Average raiting': 11.5},
#  {'name': "Lucky'S Cafe", 'Average raiting': 15.0},
#  {'name': 'Museum Of Sex/Play', 'Average raiting': 14.67},
#  {'name': 'Cafe Bravo/ Pomodoro Pizza/Planet Gyro', 'Average raiting': 14.43},
#  {'name': 'Mc Donalds', 'Average raiting': 5.0},
#  {'name': "Applebee'S Neighborhood Grill & Bar", 'Average raiting': 8.0},
#  {'name': 'Equinox Sports Club', 'Average raiting': 20.0},
#  {'name': "Three Guy'S Restaurant", 'Average raiting': 10.75},
#  {'name': 'Dyckman Bar', 'Average raiting': 13.4},
#  {'name': 'Sweet & Vicious', 'Average raiting': 11.83},
#  {'name': 'One Last Shag', 'Average raiting': 11.4},
#  {'name': 'Nono', 'Average raiting': 2.4},
#  {'name': 'Cotta Bene To Go', 'Average raiting': 7.25},
#  {'name': 'Fd8030 Chicken/Fries Concession', 'Average raiting': 0.0},
#  {'name': "Mickey Spillane'S Hell'S Kitchen Nyc", 'Average raiting': 10.33},
#  {'name': 'Barfly', 'Average raiting': 8.5},
#  {'name': 'Cafe De Broadway', 'Average raiting': 5.0},
#  {'name': 'Brooklyn Z', 'Average raiting': 2.0},
#  {'name': "Halal Ny Kennedy'S Chicken & Pizza", 'Average raiting': 18.0},
#  {'name': "Applebee'S Neighborhood Grill & Bar", 'Average raiting': 7.5},
#  {'name': 'Chickpea', 'Average raiting': 10.67},
#  {'name': 'O Cafe', 'Average raiting': 10.75},
#  {'name': 'Fourth Avenue Pub', 'Average raiting': 12.2},
#  {'name': 'World Pizza & Fried Chicken', 'Average raiting': 20.0},
#  {'name': 'Ground Support Cafe', 'Average raiting': 3.6},
#  {'name': 'The Williams Memorial Residence', 'Average raiting': 17.57},
#  {'name': 'De Ja Vu', 'Average raiting': 10.0},
#  {'name': "Sammie'S To Go", 'Average raiting': 6.0},
#  {'name': 'Theater Row Diner', 'Average raiting': 10.2},
#  {'name': 'Station Cafe', 'Average raiting': 9.0},
#  {'name': 'Kismet Caterers', 'Average raiting': 11.75},
#  {'name': "T.G.I. Friday'S", 'Average raiting': 8.2},
#  {'name': 'The Dutch', 'Average raiting': 11.5},
#  {'name': "Roman'S", 'Average raiting': 12.2},
#  {'name': 'Towers Restaurant', 'Average raiting': 10.83},
#  {'name': 'Club Glazz', 'Average raiting': 14.0},
#  {'name': 'Anassa Taverna', 'Average raiting': 12.33},
#  {'name': 'Blt Prime', 'Average raiting': 12.0},
#  {'name': 'Meltkraft', 'Average raiting': 26.67},
#  {'name': 'The Wheeltapper', 'Average raiting': 10.5},
#  {'name': 'Park Hyatt New York', 'Average raiting': 7.0},
#  {'name': 'The Woods', 'Average raiting': 10.33},
#  {'name': 'Tick Tock Diner', 'Average raiting': 11.0},
#  {'name': 'Pax Wholesome Foods', 'Average raiting': 6.6},
#  {'name': 'North Star Cafe', 'Average raiting': 8.8},
#  {'name': 'Towne Cafe', 'Average raiting': 17.0},
#  {'name': 'Salud Y Estilo De Vida', 'Average raiting': 5.0},
#  {'name': 'City Island Yacht Club', 'Average raiting': 8.25},
#  {'name': 'Dean Street', 'Average raiting': 13.4},
#  {'name': 'The West Cafe', 'Average raiting': 12.0},
#  {'name': 'Rare Bar & Grill', 'Average raiting': 12.33},
#  {'name': 'South 4Th Bar & Cafe', 'Average raiting': 9.0},
#  {'name': 'U Way', 'Average raiting': 23.17},
#  {'name': 'Fulton Grill', 'Average raiting': 23.33},
#  {'name': 'Club Bar & Grill', 'Average raiting': 2.33},
#  {'name': 'Circle Line Xvi', 'Average raiting': 6.25},
#  {'name': "Locke'S Loft", 'Average raiting': 11.33},
#  {'name': 'La Guira Restaurant', 'Average raiting': 7.5},
#  {'name': "Bfb @ Malt'N  Mash", 'Average raiting': 13.0},
#  {'name': 'Cafe 52 Restaurant', 'Average raiting': 12.0},
#  {'name': 'Birds & Bubbles', 'Average raiting': 12.0},
#  {'name': 'Burger Heaven', 'Average raiting': 5.0},
#  {'name': 'Dunkin Donuts', 'Average raiting': 8.5},
#  {'name': 'Westside Tavern', 'Average raiting': 7.4},
#  {'name': "Mike'S Tavern", 'Average raiting': 9.0},
#  {'name': 'Barking Dog', 'Average raiting': 10.43},
#  {'name': '67 Orange Street', 'Average raiting': 11.4},
#  {'name': 'Nations Cafe', 'Average raiting': 8.17},
#  {'name': 'Pioneers Bar & Lounge', 'Average raiting': 15.67},
#  {'name': 'Lincoln Tech Cafeteria', 'Average raiting': 7.5},
#  {'name': "Nick'S Gourmet Deli", 'Average raiting': 15.0},
#  {'name': 'Station Lic', 'Average raiting': 2.0},
#  {'name': '4Th Floor Cafe', 'Average raiting': 3.5},
#  {'name': 'Better Gourmet Health Kitchen', 'Average raiting': 8.75},
#  {'name': 'Carousell Grill', 'Average raiting': 8.0},
#  {'name': 'Relish Caterers', 'Average raiting': 11.5},
#  {'name': 'Kmr', 'Average raiting': 9.25},
#  {'name': 'Kennedy Deli', 'Average raiting': 13.33},
#  {'name': 'Fresh', 'Average raiting': 1.33},
#  {'name': 'Mikes Olympic Grill', 'Average raiting': 15.6},
#  {'name': "Sheppard'S Place  Press Kitchen", 'Average raiting': 2.0},
#  {'name': 'Dunkin Donuts', 'Average raiting': 2.0},
#  {'name': 'The Harrison', 'Average raiting': 9.6},
#  {'name': 'Terrace Diner', 'Average raiting': 8.86},
#  {'name': 'Legacy Bar', 'Average raiting': 15.75},
#  {'name': 'Jalopy Tavern', 'Average raiting': 8.67},
#  {'name': 'Bronx Chicken & Pizza Inc', 'Average raiting': 7.0},
#  {'name': 'Kennedy Fried Chicken & Biscuits', 'Average raiting': 9.5},
#  {'name': 'Anchor Winebar Llc', 'Average raiting': 8.0},
#  {'name': 'Egg Shop', 'Average raiting': 10.0},
#  {'name': 'Acme Bar & Grill', 'Average raiting': 14.75},
#  {'name': 'Whiskey Town', 'Average raiting': 13.17},
#  {'name': 'Blue Note Jazz', 'Average raiting': 14.6},
#  {'name': '15 Central Park West Restaurant', 'Average raiting': 7.0},
#  {'name': 'Privilege Lounge', 'Average raiting': 7.67},
#  {'name': 'Lincoln Plaza Cinemas', 'Average raiting': 21.5},
#  {'name': 'The Whiskey Brooklyn', 'Average raiting': 7.25},
#  {'name': 'Julliard & S.A.B. Cafeteria', 'Average raiting': 2.67},
#  {'name': 'Chelsea Hilton Garden Inn', 'Average raiting': 15.0},
#  {'name': 'Simplicity Wine Bar & Cafe', 'Average raiting': 6.5},
#  {'name': "David Burke At Bloomingdale'S", 'Average raiting': 9.25},
#  {'name': 'Lox', 'Average raiting': 8.75},
#  {'name': 'Dudleys', 'Average raiting': 11.6},
#  {'name': 'Rogue', 'Average raiting': 9.2},
#  {'name': 'Pick & Pay Gyro & Pizza', 'Average raiting': 9.0},
#  {'name': 'Salt And Fat', 'Average raiting': 14.4},
#  {'name': "Freddy'S Bar", 'Average raiting': 10.0},
#  {'name': "Shane'S Cafe", 'Average raiting': 14.71},
#  {'name': 'Crown Chicken & Pizza', 'Average raiting': 10.0},
#  {'name': 'Burger Barn Restaurant', 'Average raiting': 12.6},
#  {'name': 'Kfc', 'Average raiting': 6.5},
#  {'name': 'Subway', 'Average raiting': 8.0},
#  {'name': 'Remix', 'Average raiting': 15.0},
#  {'name': 'Hilton Hotel Jfk Airport', 'Average raiting': 18.86},
#  {'name': 'Pork Slope', 'Average raiting': 11.33},
#  {'name': "Peet'S Coffee/Tea", 'Average raiting': 14.0},
#  {'name': 'The Bitter End', 'Average raiting': 11.4},
#  {'name': 'Pumps Exotic Bar', 'Average raiting': 6.25},
#  {'name': "V.I.P.'S Cafe", 'Average raiting': 12.67},
#  {'name': 'Harefield Road Pub', 'Average raiting': 8.0},
#  {'name': 'Bite', 'Average raiting': 11.0},
#  {'name': "Richie'S Place", 'Average raiting': 16.5},
#  {'name': "P.D. O'Hurley'S", 'Average raiting': 18.5},
#  {'name': "J.D.'S Saloon Bar", 'Average raiting': 11.0},
#  {'name': "Gallagher'S 2000", 'Average raiting': 10.6},
#  {'name': 'World Market', 'Average raiting': 5.5},
#  {'name': 'Giacomo Fine Foods', 'Average raiting': 11.75},
#  {'name': 'American Express', 'Average raiting': 5.75},
#  {'name': 'Georges Restaurant', 'Average raiting': 31.33},
#  {'name': 'Cafeone', 'Average raiting': 20.4},
#  {'name': 'New York Yacht Club', 'Average raiting': 10.67},
#  {'name': 'Egg', 'Average raiting': 9.25},
#  {'name': 'Crown Fried Chicken & Pizza', 'Average raiting': 2.0},
#  {'name': 'Soups,Salads & Beyond', 'Average raiting': 12.0},
#  {'name': "Mike'S Unicorn Diner", 'Average raiting': 12.75},
#  {'name': 'Paradis To Go', 'Average raiting': 10.33},
#  {'name': 'Greenpoint Deli', 'Average raiting': 10.0},
#  {'name': 'Tsq Brasserie', 'Average raiting': 10.5},
#  {'name': 'New York University - Kimmel Student Center (Catering Kitchen)',
#   'Average raiting': 9.5},
#  {'name': 'The Comfort Diner', 'Average raiting': 13.17},
#  {'name': "Gloria Jean'S Coffees", 'Average raiting': 12.0},
#  {'name': "G. Lee'S Smokin Bbq", 'Average raiting': 14.5},
#  {'name': 'Marymount College Nugents Cafe', 'Average raiting': 10.5},
#  {'name': 'Best Deli', 'Average raiting': 17.0},
#  {'name': 'Five Napkin Burger', 'Average raiting': 8.25},
#  {'name': "Sapito'S Sports Bar & Grill", 'Average raiting': 13.6},
#  {'name': 'The East Pole', 'Average raiting': 10.0},
#  {'name': 'Tost Cafe', 'Average raiting': 13.0},
#  {'name': 'Dunkin Donuts/Baskin Robbins', 'Average raiting': 5.75},
#  {'name': 'Audi Yankee Club', 'Average raiting': 7.0},
#  {'name': 'The Local Nyc', 'Average raiting': 6.0},
#  {'name': 'Sin City', 'Average raiting': 17.0},
#  {'name': "Epstein'S Bar", 'Average raiting': 10.0},
#  {'name': 'Rosamunde Sausage Grill', 'Average raiting': 8.5},
#  {'name': 'Conrad New York', 'Average raiting': 8.67},
#  {'name': 'Cosi', 'Average raiting': 8.0},
#  {'name': 'Brown Brothers Cafeteria', 'Average raiting': 8.5},
#  {'name': 'Express Coffee Shop', 'Average raiting': 10.33},
#  {'name': 'Amc Theatres Empire 25', 'Average raiting': 3.0},
#  {'name': 'Lounge 247 I M O K', 'Average raiting': 12.67},
#  {'name': 'Glacken Bar', 'Average raiting': 4.25},
#  {'name': 'Four Seasons Hotel', 'Average raiting': 5.5},
#  {'name': 'Nostrand Express', 'Average raiting': 10.14},
#  {'name': 'Hampton Inn Empire State Building', 'Average raiting': 9.0},
#  {'name': 'Singas Pizza/Mni Burger', 'Average raiting': 10.75},
#  {'name': 'City Perk', 'Average raiting': 8.33},
#  {'name': 'Idlewild Wine Bar', 'Average raiting': 6.0},
#  {'name': "Mug-Z'S Sports Bar", 'Average raiting': 11.5},
#  {'name': "Tommy'S Tavern", 'Average raiting': 17.17},
#  {'name': 'Herald Square Market', 'Average raiting': 14.33},
#  {'name': 'Beacon Theatre', 'Average raiting': 3.5},
#  {'name': 'Mariott Marquis/Crossroads Bar', 'Average raiting': 8.0},
#  {'name': 'Land & Sea Restaurant', 'Average raiting': 14.2},
#  {'name': 'The Williamsbridge Tavern', 'Average raiting': 11.33},
#  {'name': 'Croissanteria', 'Average raiting': 7.0},
#  {'name': 'Fb9110 Hot Dog Concession', 'Average raiting': 1.0},
#  {'name': "Crif Dogs / Please Don'T Tell", 'Average raiting': 13.75},
#  {'name': 'Cafe Hestia', 'Average raiting': 15.0},
#  {'name': '729 Bar & Grill', 'Average raiting': 10.0},
#  {'name': 'Cove Lounge', 'Average raiting': 9.0},
#  ...]
